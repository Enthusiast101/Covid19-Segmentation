# %%
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras.metrics import Precision, Recall
from keras_flops import get_flops

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Add, Conv2D, Input, MaxPooling2D, Dropout, concatenate, UpSampling2D, BatchNormalization, Activation, Conv2DTranspose
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import gc

# %%
# Read and examine metadata
#raw_data = pd.read_csv(r"D:\NITK\COVID-19 Lung CT Scan Segmentation\COVID-19 Lung CT Scan Segmentation\metadata.csv")
raw_data = pd.read_csv(r'../COVID-19 Lung CT Scan Segmentation/COVID-19 Lung CT Scan Segmentation/metadata_temp.csv')
raw_data.sample(5)
# Out:
#                                               ct_scan  \
# 13  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...
#
#                                             lung_mask  \
# 13  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...
#
#                                        infection_mask  \
# 13  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...
#
#                               lung_and_infection_mask
# 13  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
# Read sample
sample_ct   = read_nii(raw_data.loc[1,'ct_scan'])
sample_lung = read_nii(raw_data.loc[1,'lung_mask'])
sample_infe = read_nii(raw_data.loc[1,'infection_mask'])
sample_all  = read_nii(raw_data.loc[1,'lung_and_infection_mask'])

# Examine Shape
sample_ct.shape
# Out:
# (512, 512, 200)

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %%
IMG_SIZE = 128
IMG_HEIGHT = IMG_SIZE
IMG_WIDTH = IMG_SIZE
IMG_CHANNELS = 1

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

def get_data():
    lungs_data = []
    infections_data  = []

    for row in range(len(raw_data)):
        lungs_image = read_nii(raw_data['ct_scan'][row])
        infection_image = read_nii(raw_data['infection_mask'][row])

        for slice_no in range(lungs_image.shape[2]):
            lung_slice = cv2.resize(lungs_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA)
            infection_slice = cv2.resize(infection_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')

            lung_slice_temp = lung_slice.reshape(-1, 2)
            lung_slice_temp = scaler.fit_transform(lung_slice_temp)
            lung_slice = lung_slice_temp.reshape(lung_slice.shape)
            lungs_data.append(lung_slice[..., np.newaxis])

            infections_data.append(infection_slice[..., np.newaxis])
    return lungs_data, infections_data

# %%
data = get_data()
lungs = np.array(data[0])
infections = np.array(data[1])

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,2,1)
plt.imshow(lungs[451], cmap = 'bone')
plt.title('Transformed Image')

plt.subplot(1,2,2)
plt.imshow(lungs[451], cmap = 'bone')
plt.imshow(infections[451],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Transformed Infection Mask')
# Out:
# Text(0.5, 1.0, 'Transformed Infection Mask')

# %%
# Split the data into train and test sets
lung_train, lung_test, infect_train, infect_test = train_test_split(lungs, infections, test_size=0.1, shuffle=True)

# %%
def res_conv_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    conv1 = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size), kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)

    # second layer
    conv1 = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size), kernel_initializer = 'he_normal', padding = 'same')(conv1)
    if batchnorm:
        conv1 = BatchNormalization()(conv1)

    conv2 = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size), kernel_initializer = 'he_normal', padding = 'same')(conv1)
    if batchnorm:
        conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    
    res_path = Add()([conv1, conv2])
    res_path = Activation('relu')(res_path)
    
    return res_path

# %%
"""Modified"""
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, RandomContrast, RandomCrop, GaussianNoise

# %%
def ResUnet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = res_conv_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = res_conv_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = res_conv_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = res_conv_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = res_conv_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = res_conv_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = res_conv_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = res_conv_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = res_conv_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
import tensorflow.keras.backend as K

def jaccard_loss(y_true, y_pred, smooth=1e-7):
    y_true = K.cast(y_true, dtype='float32')  # Cast y_true to float32
    intersection = K.sum(y_true * y_pred, axis=(1, 2, 3))
    union = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3)) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    return 1 - jaccard

# %%
from keras import backend as K
K.clear_session()

# Define the UNET model with TensorFlow's MeanIoU metric
input_img = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), name='img')
model = ResUnet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
metrics = ["accuracy", 
           tf.keras.metrics.AUC(), 
           tf.keras.metrics.SensitivityAtSpecificity(0.5), 
           tf.keras.metrics.SpecificityAtSensitivity(0.5),
           tf.keras.metrics.MeanIoU(num_classes=2)]  # Use MeanIoU as the Jaccard Index metric
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=metrics)  # Use custom Jaccard loss

gc.collect()
# Out:
# 114

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 16  160         ['img[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 16  2320        ['batch_normalization_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  add (Add)                      (None, 128, 128, 16  0           ['batch_normalization_1[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 128, 128, 16  0           ['add[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['activation_2[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 16)   0           ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   4640        ['dropout[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 32)   9248        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 32)   9248        ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_5[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 32)   0           ['batch_normalization_4[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 64, 64, 32)   0           ['add_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['activation_5[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 32)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 64)   18496       ['dropout_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 64)   36928       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 64)   36928       ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_8[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 64)   0           ['batch_normalization_7[0][0]',
#                                                                   'activation_7[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 64)   0           ['add_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['activation_8[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 64)   0           ['max_pooling2d_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 128)  73856       ['dropout_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 16, 16, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  147584      ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_11[0][0]']
#
#  add_3 (Add)                    (None, 16, 16, 128)  0           ['batch_normalization_10[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 16, 16, 128)  0           ['add_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['activation_11[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 128)    0           ['max_pooling2d_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 256)    295168      ['dropout_3[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 256)    590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 256)    590080      ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_14[0][0]']
#
#  add_4 (Add)                    (None, 8, 8, 256)    0           ['batch_normalization_13[0][0]',
#                                                                   'activation_13[0][0]']
#
#  activation_14 (Activation)     (None, 8, 8, 256)    0           ['add_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  295040     ['activation_14[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'activation_11[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 256)  0           ['concatenate[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 128)  295040      ['dropout_4[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 128)  147584      ['batch_normalization_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 128)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_17[0][0]']
#
#  add_5 (Add)                    (None, 16, 16, 128)  0           ['batch_normalization_16[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 16, 16, 128)  0           ['add_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  73792       ['activation_17[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_8[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['concatenate_1[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_5[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 64)   36928       ['batch_normalization_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_20[0][0]']
#
#  add_6 (Add)                    (None, 32, 32, 64)   0           ['batch_normalization_19[0][0]',
#                                                                   'activation_19[0][0]']
#
#  activation_20 (Activation)     (None, 32, 32, 64)   0           ['add_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  18464       ['activation_20[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'activation_5[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 64)   0           ['concatenate_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_6[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 32)  128         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 32)  128         ['conv2d_22[0][0]']
#  ormalization)
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 32)   9248        ['batch_normalization_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 32)  128         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_23[0][0]']
#
#  add_7 (Add)                    (None, 64, 64, 32)   0           ['batch_normalization_22[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_23 (Activation)     (None, 64, 64, 32)   0           ['add_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  4624       ['activation_23[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'activation_2[0][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 16  4624        ['dropout_7[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 16  64         ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  activation_24 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_24[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 16  2320        ['activation_24[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 16  64         ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 16  2320        ['batch_normalization_25[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 16  64         ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  add_8 (Add)                    (None, 128, 128, 16  0           ['batch_normalization_25[0][0]',
#                                 )                                 'activation_25[0][0]']
#
#  activation_26 (Activation)     (None, 128, 128, 16  0           ['add_8[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 1)  17          ['activation_26[0][0]']
#
# ==================================================================================================
# Total params: 3,149,489
# Trainable params: 3,145,073
# Non-trainable params: 4,416
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_dtype=True)

# %%
# Define callbacks
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-resUnet.h5', verbose=1, save_best_only=True, save_weights_only=True),
]

# %%
results = model.fit(lung_train, infect_train, batch_size=8, epochs=50, callbacks=callbacks, validation_data=(lung_test, infect_test), use_multiprocessing=True)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 results = model.fit(lung_train, infect_train, batch_size=8, epochs=50, callbacks=callbacks, validation_data=(lung_test, infect_test), use_multiprocessing=True)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\def_function.py:963, in Function._call(self, *args, **kwds)
#     960 try:
#     961   # This is the first call of __call__, so we have to initialize.
#     962   initializers = []
# --> 963   self._initialize(args, kwds, add_initializers_to=initializers)
#     964 finally:
#     965   # At this point we know that the initialization is complete (or less
#     966   # interestingly an exception was raised) so we no longer need a lock.
#     967   self._lock.release()
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\def_function.py:785, in Function._initialize(self, args, kwds, add_initializers_to)
#     782 self._lifted_initializer_graph = lifted_initializer_graph
#     783 self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     784 self._concrete_stateful_fn = (
# --> 785     self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     786         *args, **kwds))
#     788 def invalid_creator_scope(*unused_args, **unused_kwds):
#     789   """Disables variable creation."""
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\function.py:2983, in Function._get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2981   args, kwargs = None, None
#    2982 with self._lock:
# -> 2983   graph_function, _ = self._maybe_define_function(args, kwargs)
#    2984 return graph_function
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\function.py:3292, in Function._maybe_define_function(self, args, kwargs)
#    3288   return self._define_function_with_shape_relaxation(
#    3289       args, kwargs, flat_args, filtered_flat_args)
#    3291 self._function_cache.add_call_context(cache_key.call_context)
# -> 3292 graph_function = self._create_graph_function(args, kwargs)
#    3293 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                          graph_function)
#    3296 return graph_function, filtered_flat_args
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\function.py:3130, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3125 missing_arg_names = [
#    3126     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3127 ]
#    3128 arg_names = base_arg_names + missing_arg_names
#    3129 graph_function = ConcreteFunction(
# -> 3130     func_graph_module.func_graph_from_py_func(
#    3131         self._name,
#    3132         self._python_function,
#    3133         args,
#    3134         kwargs,
#    3135         self.input_signature,
#    3136         autograph=self._autograph,
#    3137         autograph_options=self._autograph_options,
#    3138         arg_names=arg_names,
#    3139         override_flat_arg_shapes=override_flat_arg_shapes,
#    3140         capture_by_value=self._capture_by_value),
#    3141     self._function_attributes,
#    3142     function_spec=self.function_spec,
#    3143     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3144     # scope. This is not the default behavior since it gets used in some
#    3145     # places (like Keras) where the FuncGraph lives longer than the
#    3146     # ConcreteFunction.
#    3147     shared_func_graph=False)
#    3148 return graph_function
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\func_graph.py:1161, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1158 else:
#    1159   _, original_func = tf_decorator.unwrap(python_func)
# -> 1161 func_outputs = python_func(*func_args, **func_kwargs)
#    1163 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1164 # TensorArrays and `None`s.
#    1165 func_outputs = nest.map_structure(convert, func_outputs,
#    1166                                   expand_composites=True)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\def_function.py:677, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     673 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     674   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     675   # the function a weak reference to itself to avoid a reference cycle.
#     676   with OptionalXlaContext(compile_with_xla):
# --> 677     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678   return out
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\func_graph.py:1136, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1134 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1135 try:
# -> 1136   return autograph.converted_call(
#    1137       original_func,
#    1138       args,
#    1139       kwargs,
#    1140       options=autograph.ConversionOptions(
#    1141           recursive=True,
#    1142           optional_features=autograph_options,
#    1143           user_requested=True,
#    1144       ))
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filewzhowsx2.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\training.py:1010, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1007   run_step = tf.function(
#    1008       run_step, jit_compile=True, experimental_relax_shapes=True)
#    1009 data = next(iterator)
# -> 1010 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1011 outputs = reduce_per_replica(
#    1012     outputs, self.distribute_strategy, reduction='first')
#    1013 return outputs
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1312, in StrategyBase.run(***failed resolving arguments***)
#    1307 with self.scope():
#    1308   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1309   # applied when the caller is also in Eager mode.
#    1310   fn = autograph.tf_convert(
#    1311       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1312   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2888, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2886   kwargs = {}
#    2887 with self._container_strategy().scope():
# -> 2888   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3689, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3687 def _call_for_each_replica(self, fn, args, kwargs):
#    3688   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3689     return fn(*args, **kwargs)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\training.py:1000, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#     999 def run_step(data):
# -> 1000   outputs = model.train_step(data)
#    1001   # Ensure counter is updated only if `train_step` succeeds.
#    1002   with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\training.py:864, in Model.train_step(self, data)
#     862 # Run backwards pass.
#     863 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
# --> 864 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\training.py:957, in Model.compute_metrics(***failed resolving arguments***)
#     922 """Update metric states and collect all metrics to be returned.
#     923
#     924 Subclasses can optionally override this method to provide custom metric
#    (...)
#     954   `{'loss': 0.2, 'accuracy': 0.7}`.
#     955 """
#     956 del x  # The default implementation does not use `x`.
# --> 957 self.compiled_metrics.update_state(y, y_pred, sample_weight)
#     958 # Collect metrics to return
#     959 return_metrics = {}
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\compile_utils.py:459, in MetricsContainer.update_state(self, y_true, y_pred, sample_weight)
#     457   if metric_obj is None:
#     458     continue
# --> 459   metric_obj.update_state(y_t, y_p, sample_weight=mask)
#     461 for weighted_metric_obj in weighted_metric_objs:
#     462   if weighted_metric_obj is None:
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\utils\metrics_utils.py:70, in update_state_wrapper.<locals>.decorated(metric_obj, *args, **kwargs)
#      64     raise ValueError(
#      65         'Trying to run metric.update_state in replica context when '
#      66         'the metric was not created in TPUStrategy scope. '
#      67         'Make sure the keras Metric is created in TPUstrategy scope. ')
#      69 with tf_utils.graph_context_for_symbolic_tensors(*args, **kwargs):
# ---> 70   update_op = update_state_fn(*args, **kwargs)
#      71 if update_op is not None:  # update_op will be None in eager execution.
#      72   metric_obj.add_update(update_op)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\metrics.py:178, in Metric.__new__.<locals>.update_state_fn(*args, **kwargs)
#     176 control_status = tf.__internal__.autograph.control_status_ctx()
#     177 ag_update_state = tf.__internal__.autograph.tf_convert(obj_update_state, control_status)
# --> 178 return ag_update_state(*args, **kwargs)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\metrics.py:1628, in SensitivitySpecificityBase.update_state(self, y_true, y_pred, sample_weight)
#    1615 def update_state(self, y_true, y_pred, sample_weight=None):
#    1616   """Accumulates confusion matrix statistics.
#    1617
#    1618   Args:
#    (...)
#    1626     Update op.
#    1627   """
# -> 1628   return metrics_utils.update_confusion_matrix_variables(
#    1629       {
#    1630           metrics_utils.ConfusionMatrix.TRUE_POSITIVES: self.true_positives,
#    1631           metrics_utils.ConfusionMatrix.TRUE_NEGATIVES: self.true_negatives,
#    1632           metrics_utils.ConfusionMatrix.FALSE_POSITIVES: self.false_positives,
#    1633           metrics_utils.ConfusionMatrix.FALSE_NEGATIVES: self.false_negatives,
#    1634       },
#    1635       y_true,
#    1636       y_pred,
#    1637       thresholds=self.thresholds,
#    1638       thresholds_distributed_evenly=self._thresholds_distributed_evenly,
#    1639       class_id=self.class_id,
#    1640       sample_weight=sample_weight)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\utils\metrics_utils.py:628, in update_confusion_matrix_variables(variables_to_update, y_true, y_pred, thresholds, top_k, class_id, sample_weight, multi_label, label_weights, thresholds_distributed_evenly)
#     625   y_pred = y_pred[..., class_id]
#     627 if thresholds_distributed_evenly:
# --> 628   return _update_confusion_matrix_variables_optimized(
#     629       variables_to_update, y_true, y_pred, thresholds,
#     630       multi_label=multi_label, sample_weights=sample_weight,
#     631       label_weights=label_weights,
#     632       thresholds_with_epsilon=thresholds_with_epsilon)
#     634 pred_shape = tf.shape(y_pred)
#     635 num_predictions = pred_shape[0]
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\utils\metrics_utils.py:389, in _update_confusion_matrix_variables_optimized(variables_to_update, y_true, y_pred, thresholds, multi_label, sample_weights, label_weights, thresholds_with_epsilon)
#     386   y_pred = tf.reshape(y_pred, [-1])
#     388 true_labels = tf.multiply(y_true, weights)
# --> 389 false_labels = tf.multiply((1.0 - y_true), weights)
#     391 # Compute the bucket indices for each prediction value.
#     392 # Since the predict value has to be strictly greater than the thresholds,
#     393 # eg, buckets like [0, 0.5], (0.5, 1], and 0.5 belongs to first bucket.
#     394 # We have to use math.ceil(val) - 1 for the bucket.
#     395 bucket_indices = tf.math.ceil(y_pred * (num_thresholds - 1)) - 1
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\ops\math_ops.py:1441, in _OverrideBinaryOperatorHelper.<locals>.r_binary_op_wrapper(y, x)
#    1437 with ops.name_scope(None, op_name, [x, y]) as name:
#    1438   # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1439   #   r_binary_op_wrapper use different force_same_dtype values.
#    1440   y, x = maybe_promote_tensors(y, x, force_same_dtype=True)
# -> 1441   return func(x, y, name=name)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\ops\math_ops.py:548, in subtract(x, y, name)
#     544 @tf_export("math.subtract", "subtract")
#     545 @dispatch.register_binary_elementwise_api
#     546 @dispatch.add_dispatch_support
#     547 def subtract(x, y, name=None):
# --> 548   return gen_math_ops.sub(x, y, name)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:11138, in sub(x, y, name)
#   11136     pass  # Add nodes to the TensorFlow graph.
#   11137 # Add nodes to the TensorFlow graph.
# > 11138 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   11139       "Sub", x=x, y=y, name=name)
#   11140 _result = _outputs[:]
#   11141 if _execute.must_record_gradient():
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\op_def_library.py:740, in _apply_op_helper(op_type_name, name, **keywords)
#     735 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     736                         if arg.is_ref]
#     737 with _MaybeColocateWith(must_colocate_inputs):
#     738   # Add Op to graph
#     739   # pylint: disable=protected-access
# --> 740   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     741                              name=scope, input_types=input_types,
#     742                              attrs=attr_protos, op_def=op_def)
#     744 # `outputs` is returned as a separate return value so that the output
#     745 # tensors can the `op` per se can be decoupled so that the
#     746 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     747 # for more details.
#     748 outputs = op.outputs
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\func_graph.py:693, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     691   inp = self.capture(inp)
#     692   captured_inputs.append(inp)
# --> 693 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     694     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     695     compute_device)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\ops.py:3776, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3773 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3774 # Session.run call cannot occur between creating and mutating the op.
#    3775 with self._mutation_lock():
# -> 3776   ret = Operation(
#    3777       node_def,
#    3778       self,
#    3779       inputs=inputs,
#    3780       output_types=dtypes,
#    3781       control_inputs=control_inputs,
#    3782       input_types=input_types,
#    3783       original_op=self._default_original_op,
#    3784       op_def=op_def)
#    3785   self._create_op_helper(ret, compute_device=compute_device)
#    3786 return ret
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\ops.py:2171, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2169   if op_def is None:
#    2170     op_def = self._graph._get_op_def(node_def.op)
# -> 2171   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2172                             control_input_ops, op_def)
#    2173   name = compat.as_str(node_def.name)
#    2175 self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\ops.py:2010, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    2006   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    2007                                          serialized)
#    2009 try:
# -> 2010   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    2011 except errors.InvalidArgumentError as e:
#    2012   # Convert to ValueError for backwards compatibility.
#    2013   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
df_result = pd.DataFrame(results.history)
df_result.sort_values('val_loss', ascending=True, inplace = True)
df_result
# Out:
#         loss  accuracy       auc  sensitivity_at_specificity  \
# 27  0.003242  0.998628  0.999110                    0.998696
# 26  0.003363  0.998587  0.998964                    0.998439
# 28  0.003204  0.998648  0.999133                    0.998731
# 31  0.003115  0.998680  0.999159                    0.998757
# 29  0.003175  0.998653  0.999123                    0.998702
# 32  0.003059  0.998703  0.999261                    0.998947
# 33  0.003051  0.998705  0.999208                    0.998837
# 34  0.003042  0.998705  0.999218                    0.998855
# 37  0.003038  0.998715  0.999230                    0.998878
# 36  0.003042  0.998707  0.999222                    0.998863
# 35  0.003034  0.998715  0.999202                    0.998820
# 30  0.003142  0.998669  0.999139                    0.998725
# 22  0.003876  0.998371  0.998553                    0.997784
# 24  0.003876  0.998368  0.998510                    0.997698
# 20  0.004108  0.998290  0.998310                    0.997380
# 19  0.004452  0.998168  0.997825                    0.996541
# 25  0.003753  0.998419  0.998677                    0.997992
# 21  0.003940  0.998354  0.998403                    0.997504
# 17  0.004271  0.998227  0.998154                    0.997127
# 16  0.004361  0.998187  0.997965                    0.996783
# 18  0.005273  0.997904  0.995883                    0.993007
# 12  0.004900  0.998016  0.997193                    0.995453
# 23  0.003902  0.998363  0.998581                    0.997851
# 13  0.004649  0.998094  0.997534                    0.996033
# 10  0.004999  0.997967  0.997213                    0.995528
# 7   0.005649  0.997769  0.996019                    0.993419
# 14  0.004580  0.998123  0.997617                    0.996172
# 9   0.005119  0.997942  0.996715                    0.994576
# 8   0.005446  0.997835  0.996242                    0.993774
# 5   0.006382  0.997563  0.995184                    0.992101
# 15  0.004431  0.998170  0.997835                    0.996549
# 11  0.004979  0.997982  0.997142                    0.995387
# 3   0.007828  0.997219  0.993939                    0.990410
# 4   0.006754  0.997476  0.995007                    0.991899
# 2   0.009045  0.997015  0.993396                    0.989974
# 1   0.013263  0.996347  0.991212                    0.992860
# 6   0.005930  0.997680  0.995905                    0.993327
# 0   0.059626  0.992587  0.924581                    0.956840
#
#     specificity_at_sensitivity  mean_io_u  val_loss  val_accuracy   val_auc  \
# 27                    0.999991   0.496661  0.003925      0.998413  0.997247
# 26                    0.999987   0.496661  0.003929      0.998416  0.997052
# 28                    0.999990   0.496661  0.003931      0.998426  0.997014
# 31                    0.999990   0.496661  0.003938      0.998427  0.996398
# 29                    0.999991   0.496661  0.003943      0.998424  0.996571
# 32                    0.999992   0.496661  0.003949      0.998428  0.996382
# 33                    0.999990   0.496661  0.003970      0.998430  0.995939
# 34                    0.999994   0.496661  0.003976      0.998431  0.995909
# 37                    0.999990   0.496661  0.003982      0.998429  0.995984
# 36                    0.999994   0.496661  0.003987      0.998426  0.996027
# 35                    0.999991   0.496661  0.003988      0.998427  0.995864
# 30                    0.999990   0.496661  0.004020      0.998420  0.995931
# 22                    0.999975   0.496661  0.004166      0.998301  0.997111
# 24                    0.999978   0.496661  0.004197      0.998295  0.996521
# 20                    0.999969   0.496661  0.004215      0.998276  0.998528
# 19                    0.999957   0.496661  0.004321      0.998239  0.997356
# 25                    0.999977   0.496661  0.004375      0.998311  0.992653
# 21                    0.999973   0.496661  0.004388      0.998253  0.996528
# 17                    0.999960   0.496661  0.004467      0.998125  0.998198
# 16                    0.999965   0.496661  0.004564      0.998168  0.996326
# 18                    0.999934   0.496661  0.004638      0.998104  0.998267
# 12                    0.999941   0.496661  0.004642      0.998124  0.997749
# 23                    0.999972   0.496661  0.004661      0.998129  0.996689
# 13                    0.999953   0.496661  0.004747      0.998071  0.995771
# 10                    0.999940   0.496661  0.004778      0.998090  0.997647
# 7                     0.999913   0.496661  0.004891      0.998029  0.997510
# 14                    0.999951   0.496661  0.004901      0.998044  0.997794
# 9                     0.999937   0.496661  0.004988      0.998110  0.997476
# 8                     0.999926   0.496661  0.005260      0.997890  0.997514
# 5                     0.999877   0.496661  0.005934      0.997690  0.997120
# 15                    0.999960   0.496661  0.006066      0.997509  0.997979
# 11                    0.999939   0.496661  0.006287      0.997507  0.998696
# 3                     0.999798   0.496661  0.006989      0.997402  0.996194
# 4                     0.999852   0.496661  0.008111      0.996799  0.997687
# 2                     0.999734   0.496661  0.009137      0.996795  0.992456
# 1                     0.999441   0.496661  0.010658      0.996393  0.996002
# 6                     0.999903   0.496661  0.012625      0.995441  0.998131
# 0                     0.986104   0.496661  0.030904      0.994390  0.739113
#
#     val_sensitivity_at_specificity  val_specificity_at_sensitivity  \
# 27                        0.995226                        0.999938
# 26                        0.994841                        0.999944
# 28                        0.994752                        0.999943
# 31                        0.993507                        0.999939
# 29                        0.993863                        0.999945
# 32                        0.993477                        0.999942
# 33                        0.992588                        0.999942
# 34                        0.992528                        0.999941
# 37                        0.992676                        0.999939
# 36                        0.992765                        0.999937
# 35                        0.992439                        0.999938
# 30                        0.992588                        0.999940
# 22                        0.995078                        0.999935
# 24                        0.993892                        0.999929
# 20                        0.997954                        0.999919
# 19                        0.995641                        0.999923
# 25                        0.986094                        0.999944
# 21                        0.993951                        0.999926
# 17                        0.997361                        0.999932
# 16                        0.993655                        0.999909
# 18                        0.997598                        0.999908
# 12                        0.996561                        0.999909
# 23                        0.994396                        0.999903
# 13                        0.992558                        0.999926
# 10                        0.996442                        0.999911
# 7                         0.996205                        0.999892
# 14                        0.996679                        0.999887
# 9                         0.996205                        0.999904
# 8                         0.996323                        0.999860
# 5                         0.995908                        0.999859
# 15                        0.997509                        0.999793
# 11                        0.998814                        0.999802
# 3                         0.994574                        0.999740
# 4                         0.997984                        0.999618
# 2                         0.989000                        0.999686
# 1                         0.995968                        0.999401
# 6                         0.998873                        0.999544
# 0                         0.724375                        0.584038
#
#     val_mean_io_u       lr
# 27       0.497076  0.00010
# 26       0.497076  0.00010
# 28       0.497076  0.00010
# 31       0.497076  0.00010
# 29       0.497076  0.00010
# 32       0.497076  0.00001
# 33       0.497076  0.00001
# 34       0.497076  0.00001
# 37       0.497076  0.00001
# 36       0.497076  0.00001
# 35       0.497076  0.00001
# 30       0.497076  0.00010
# 22       0.497076  0.00100
# 24       0.497076  0.00100
# 20       0.497076  0.00100
# 19       0.497076  0.00100
# 25       0.497076  0.00100
# 21       0.497076  0.00100
# 17       0.497076  0.00100
# 16       0.497076  0.00100
# 18       0.497076  0.00100
# 12       0.497076  0.00100
# 23       0.497076  0.00100
# 13       0.497076  0.00100
# 10       0.497076  0.00100
# 7        0.497076  0.00100
# 14       0.497076  0.00100
# 9        0.497076  0.00100
# 8        0.497076  0.00100
# 5        0.497076  0.00100
# 15       0.497076  0.00100
# 11       0.497076  0.00100
# 3        0.497076  0.00100
# 4        0.497076  0.00100
# 2        0.497076  0.00100
# 1        0.497076  0.00100
# 6        0.497076  0.00100
# 0        0.497076  0.00100

# %%
plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["accuracy"], label="Accuracy")
plt.plot(results.history["val_accuracy"], label="val_Accuracy")
plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %%
model.save("ResUNet.h5")

# %%
# Calculate metrics
predicted = model.predict(lung_test)

# Flatten the predicted and true masks
predicted_flat = np.round(predicted.flatten())
infect_test_flat = infect_test.flatten()

# %%
# Calculate metrics for training data
train_predicted = model.predict(lung_train)

# Flatten the predicted and true masks
train_predicted_flat = np.round(train_predicted.flatten())
infect_train_flat = infect_train.flatten()

# Calculate precision and recall for training data
train_precision = Precision()
train_recall = Recall()
train_precision.update_state(infect_train_flat, train_predicted_flat)
train_recall.update_state(infect_train_flat, train_predicted_flat)

# Calculate F1 score for training data
train_f1_score = 2 * (train_precision.result() * train_recall.result()) / (train_precision.result() + train_recall.result())

# Calculate accuracy for training data
train_accuracy = np.mean(train_predicted_flat == infect_train_flat)

# Calculate metrics for testing data
test_predicted = model.predict(lung_test)

# Flatten the predicted and true masks for testing data
test_predicted_flat = np.round(test_predicted.flatten())
infect_test_flat = infect_test.flatten()

# Calculate precision and recall for testing data
test_precision = Precision()
test_recall = Recall()
test_precision.update_state(infect_test_flat, test_predicted_flat)
test_recall.update_state(infect_test_flat, test_predicted_flat)

# Calculate F1 score for testing data
test_f1_score = 2 * (test_precision.result() * test_recall.result()) / (test_precision.result() + test_recall.result())

# Calculate accuracy for testing data
test_accuracy = np.mean(test_predicted_flat == infect_test_flat)

# Calculate parameters
total_parameters = np.sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])

# Calculate FLOPs
flops = get_flops(model, batch_size=1)  # Assuming batch_size = 1

# Print the metrics for training data
print("Training Metrics:")
print("Precision: ", train_precision.result().numpy())
print("Recall: ", train_recall.result().numpy())
print("F1 Score: ", train_f1_score.numpy())
print("Accuracy: ", train_accuracy)

# Print the metrics for testing data
print("\nTesting Metrics:")
print("Precision: ", test_precision.result().numpy())
print("Recall: ", test_recall.result().numpy())
print("F1 Score: ", test_f1_score.numpy())
print("Accuracy: ", test_accuracy)

# Print the other metrics
print("\nTotal Parameters: ", total_parameters)
print("FLOPs: ", flops)
# Out:
# WARNING:tensorflow:From c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\ops\nn_ops.py:5214: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# Training Metrics:
# Precision:  0.90867245
# Recall:  0.90782046
# F1 Score:  0.9082463
# Accuracy:  0.9987751161209261
#
# Testing Metrics:
# Precision:  0.8692112
# Recall:  0.8609126
# F1 Score:  0.8650421
# Accuracy:  0.9984290383078835
#
# Total Parameters:  3145073
# FLOPs:  2281173952

# %%
device = "CPU:0"

# %%
with tf.device(device):
    # Calculate Jaccard Index (MeanIoU) for training data
    train_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    train_iou.update_state(infect_train_flat, train_predicted_flat)
    train_mean_iou = train_iou.result().numpy()

    # Calculate Jaccard Index (MeanIoU) for testing data
    test_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    test_iou.update_state(infect_test_flat, test_predicted_flat)
    test_mean_iou = test_iou.result().numpy()

    # Print the Jaccard Index (MeanIoU) for training and testing data
    print("Training Jaccard Index (MeanIoU): ", train_mean_iou)
    print("Testing Jaccard Index (MeanIoU): ", test_mean_iou)
# Out:
# Training Jaccard Index (MeanIoU):  0.9140699
# Testing Jaccard Index (MeanIoU):  0.8803004

# %%
# Plot accuracy
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
with tf.device(device):
    # Make predictions
    predicted = model.predict(lung_test)

# %%
# Make predictions and visualize
img_num = 0
predicted = model.predict(lung_test)

# Visualize results
fig = plt.figure(figsize=(18, 15))
plt.subplot(1, 3, 1)
plt.imshow(lung_test[img_num], cmap='bone')
plt.title('Original lung')

plt.subplot(1, 3, 2)
plt.imshow(lung_test[img_num], cmap='bone')
plt.imshow(infect_test[img_num][..., 0], alpha=0.5, cmap="nipy_spectral")
plt.title('Original infection mask')

plt.subplot(1, 3, 3)
plt.imshow(lung_test[img_num], cmap='bone')
plt.imshow(predicted[img_num], alpha=0.5, cmap="nipy_spectral")
plt.title('Predicted infection mask')
# Out:
# Text(0.5, 1.0, 'Predicted infection mask')

# %%
# Plot Jaccard Index (MeanIoU)
plt.plot(results.history['mean_io_u'])
plt.plot(results.history['val_mean_io_u'])
plt.title('MeanIoU (Jaccard Index) vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('MeanIoU (Jaccard Index)')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
