# %%
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras.metrics import Precision, Recall
from keras_flops import get_flops

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import LSTM, Reshape, ConvLSTM2D, Conv2D, Input, MaxPooling2D, Dropout, add, concatenate, UpSampling2D, BatchNormalization, Activation, Conv2DTranspose
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import gc

# %%
# Read and examine metadata
raw_data = pd.read_csv(r'../COVID-19 Lung CT Scan Segmentation/COVID-19 Lung CT Scan Segmentation/metadata_temp.csv')
raw_data.sample(5)
# Out:
#                                               ct_scan  \
# 7   C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 12  C:\Application\Programming\Research\Lung_Segme...
#
#                                             lung_mask  \
# 7   C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 12  C:\Application\Programming\Research\Lung_Segme...
#
#                                        infection_mask  \
# 7   C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 12  C:\Application\Programming\Research\Lung_Segme...
#
#                               lung_and_infection_mask
# 7   C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 12  C:\Application\Programming\Research\Lung_Segme...

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
# Read sample
sample_ct   = read_nii(raw_data.loc[1,'ct_scan'])
sample_lung = read_nii(raw_data.loc[1,'lung_mask'])
sample_infe = read_nii(raw_data.loc[1,'infection_mask'])
sample_all  = read_nii(raw_data.loc[1,'lung_and_infection_mask'])

# Examine Shape
sample_ct.shape
# Out:
# (512, 512, 200)

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %%
IMG_SIZE = 128
IMG_HEIGHT = IMG_SIZE
IMG_WIDTH = IMG_SIZE
IMG_CHANNELS = 1

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

def get_data():
    lungs_data = []
    infections_data  = []

    for row in range(len(raw_data)):
        lungs_image = read_nii(raw_data['ct_scan'][row])
        infection_image = read_nii(raw_data['infection_mask'][row])

        for slice_no in range(lungs_image.shape[2]):
            lung_slice = cv2.resize(lungs_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA)
            infection_slice = cv2.resize(infection_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')

            lung_slice_temp = lung_slice.reshape(-1, 2)
            lung_slice_temp = scaler.fit_transform(lung_slice_temp)
            lung_slice = lung_slice_temp.reshape(lung_slice.shape)
            lungs_data.append(lung_slice[..., np.newaxis])

            infections_data.append(infection_slice[..., np.newaxis])
    return lungs_data, infections_data

# %%
data = get_data()
lungs = np.array(data[0])
infections = np.array(data[1])

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,2,1)
plt.imshow(lungs[451], cmap = 'bone')
plt.title('Transformed Image')

plt.subplot(1,2,2)
plt.imshow(lungs[451], cmap = 'bone')
plt.imshow(infections[451],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Transformed Infection Mask')
# Out:
# Text(0.5, 1.0, 'Transformed Infection Mask')

# %%
# Split the data into train and test sets
lung_train, lung_test, infect_train, infect_test = train_test_split(lungs, infections, test_size=0.1, shuffle=True)

# %%
from tensorflow.keras.layers import Add

# %%
def recc_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True, conv_num=2, rec_num=2):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    skip_layer = Conv2D(filters = 1, kernel_size = (kernel_size, kernel_size),\
                kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    temp = skip_layer
    for _ in range(conv_num):
        x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
                kernel_initializer = 'he_normal', padding = 'same')(temp)
        if batchnorm:
            x = BatchNormalization()(x)
        x = Activation('relu')(x)

        for _ in range(rec_num):
            x = add([temp, x])
            x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
                    kernel_initializer = 'he_normal', padding = 'same')(x)
            if batchnorm:
                x = BatchNormalization()(x)
            x = Activation("relu")(x)    
        temp = x
        
    x = add([skip_layer, temp])
    return x

# %%
def RecurrentUnet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = recc_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = recc_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = recc_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = recc_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = recc_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = recc_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = recc_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = recc_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = recc_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
import tensorflow.keras.backend as K

def jaccard_loss(y_true, y_pred, smooth=1e-7):
    y_true = K.cast(y_true, dtype='float32')  # Cast y_true to float32
    intersection = K.sum(y_true * y_pred, axis=(1, 2, 3))
    union = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3)) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    return 1 - jaccard

# %%
from keras import backend as K
K.clear_session()

# Define the UNET model with TensorFlow's MeanIoU metric
input_img = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), name='img')
model = RecurrentUnet(input_img, n_filters=16, dropout=0.05)
metrics = ["accuracy", 
           tf.keras.metrics.AUC(), 
           tf.keras.metrics.SensitivityAtSpecificity(0.5), 
           tf.keras.metrics.SpecificityAtSensitivity(0.5),
           tf.keras.metrics.MeanIoU(num_classes=2)]  # Use MeanIoU as the Jaccard Index metric
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=metrics)  # Use custom Jaccard loss

gc.collect()
# Out:
# 479

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 1)  10          ['img[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  160         ['conv2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 16  64         ['conv2d_1[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  add (Add)                      (None, 128, 128, 16  0           ['conv2d[0][0]',
#                                 )                                 'activation[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 16  2320        ['add[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 128, 128, 16  0           ['conv2d[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 16  2320        ['add_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 16  64         ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 16  2320        ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 16  64         ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 128, 128, 16  0           ['activation_2[0][0]',
#                                 )                                 'activation_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 16  2320        ['add_2[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 16  64         ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 128, 128, 16  0           ['activation_2[0][0]',
#                                 )                                 'activation_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 16  2320        ['add_3[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 16  64         ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_5 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 128, 128, 16  0           ['conv2d[0][0]',
#                                 )                                 'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['add_4[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 16)   0           ['max_pooling2d[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 1)    145         ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 32)   320         ['conv2d_7[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_6[0][0]']
#
#  add_5 (Add)                    (None, 64, 64, 32)   0           ['conv2d_7[0][0]',
#                                                                   'activation_6[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 32)   9248        ['add_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_7[0][0]']
#
#  add_6 (Add)                    (None, 64, 64, 32)   0           ['conv2d_7[0][0]',
#                                                                   'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 32)   9248        ['add_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_9[0][0]']
#
#  add_7 (Add)                    (None, 64, 64, 32)   0           ['activation_8[0][0]',
#                                                                   'activation_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 32)   9248        ['add_7[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 32)  128         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_10[0][0]']
#
#  add_8 (Add)                    (None, 64, 64, 32)   0           ['activation_8[0][0]',
#                                                                   'activation_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 32)   9248        ['add_8[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 32)  128         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_11[0][0]']
#
#  add_9 (Add)                    (None, 64, 64, 32)   0           ['conv2d_7[0][0]',
#                                                                   'activation_11[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['add_9[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 32)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 1)    289         ['dropout_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   640         ['conv2d_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_12[0][0]']
#
#  add_10 (Add)                   (None, 32, 32, 64)   0           ['conv2d_14[0][0]',
#                                                                   'activation_12[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 64)   36928       ['add_10[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_13[0][0]']
#
#  add_11 (Add)                   (None, 32, 32, 64)   0           ['conv2d_14[0][0]',
#                                                                   'activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 64)   36928       ['add_11[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_15[0][0]']
#
#  add_12 (Add)                   (None, 32, 32, 64)   0           ['activation_14[0][0]',
#                                                                   'activation_15[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   36928       ['add_12[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_16[0][0]']
#
#  add_13 (Add)                   (None, 32, 32, 64)   0           ['activation_14[0][0]',
#                                                                   'activation_16[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 64)   36928       ['add_13[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_17[0][0]']
#
#  add_14 (Add)                   (None, 32, 32, 64)   0           ['conv2d_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['add_14[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 64)   0           ['max_pooling2d_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 1)    577         ['dropout_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 128)  1280        ['conv2d_21[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_18[0][0]']
#
#  add_15 (Add)                   (None, 16, 16, 128)  0           ['conv2d_21[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 128)  147584      ['add_15[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 128)  512        ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_19[0][0]']
#
#  add_16 (Add)                   (None, 16, 16, 128)  0           ['conv2d_21[0][0]',
#                                                                   'activation_19[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 128)  147584      ['add_16[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 128)  512        ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_21[0][0]']
#
#  add_17 (Add)                   (None, 16, 16, 128)  0           ['activation_20[0][0]',
#                                                                   'activation_21[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 128)  147584      ['add_17[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_22[0][0]']
#
#  add_18 (Add)                   (None, 16, 16, 128)  0           ['activation_20[0][0]',
#                                                                   'activation_22[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 128)  147584      ['add_18[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 128)  512        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_23[0][0]']
#
#  add_19 (Add)                   (None, 16, 16, 128)  0           ['conv2d_21[0][0]',
#                                                                   'activation_23[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['add_19[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 128)    0           ['max_pooling2d_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 1)      1153        ['dropout_3[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 256)    2560        ['conv2d_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_24[0][0]']
#
#  add_20 (Add)                   (None, 8, 8, 256)    0           ['conv2d_28[0][0]',
#                                                                   'activation_24[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 256)    590080      ['add_20[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_25[0][0]']
#
#  add_21 (Add)                   (None, 8, 8, 256)    0           ['conv2d_28[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 256)    590080      ['add_21[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_26[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 256)    590080      ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_27[0][0]']
#
#  add_22 (Add)                   (None, 8, 8, 256)    0           ['activation_26[0][0]',
#                                                                   'activation_27[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 256)    590080      ['add_22[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_28[0][0]']
#
#  add_23 (Add)                   (None, 8, 8, 256)    0           ['activation_26[0][0]',
#                                                                   'activation_28[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 256)    590080      ['add_23[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_29[0][0]']
#
#  add_24 (Add)                   (None, 8, 8, 256)    0           ['conv2d_28[0][0]',
#                                                                   'activation_29[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  295040     ['add_24[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'add_19[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 256)  0           ['concatenate[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 1)    2305        ['dropout_4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 128)  1280        ['conv2d_35[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 128)  512        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_30[0][0]']
#
#  add_25 (Add)                   (None, 16, 16, 128)  0           ['conv2d_35[0][0]',
#                                                                   'activation_30[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 128)  147584      ['add_25[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 128)  512        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_31[0][0]']
#
#  add_26 (Add)                   (None, 16, 16, 128)  0           ['conv2d_35[0][0]',
#                                                                   'activation_31[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 128)  147584      ['add_26[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 128)  512        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 128)  512        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_33[0][0]']
#
#  add_27 (Add)                   (None, 16, 16, 128)  0           ['activation_32[0][0]',
#                                                                   'activation_33[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 128)  147584      ['add_27[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 128)  512        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_34[0][0]']
#
#  add_28 (Add)                   (None, 16, 16, 128)  0           ['activation_32[0][0]',
#                                                                   'activation_34[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 128)  147584      ['add_28[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 128)  512        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_35[0][0]']
#
#  add_29 (Add)                   (None, 16, 16, 128)  0           ['conv2d_35[0][0]',
#                                                                   'activation_35[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  73792       ['add_29[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'add_14[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['concatenate_1[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 1)    1153        ['dropout_5[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 64)   640         ['conv2d_42[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_36[0][0]']
#
#  add_30 (Add)                   (None, 32, 32, 64)   0           ['conv2d_42[0][0]',
#                                                                   'activation_36[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 32, 32, 64)   36928       ['add_30[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 32, 32, 64)  256         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_37[0][0]']
#
#  add_31 (Add)                   (None, 32, 32, 64)   0           ['conv2d_42[0][0]',
#                                                                   'activation_37[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 64)   36928       ['add_31[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 32, 32, 64)  256         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 32, 32, 64)  256         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_39[0][0]']
#
#  add_32 (Add)                   (None, 32, 32, 64)   0           ['activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 64)   36928       ['add_32[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 64)  256         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_40[0][0]']
#
#  add_33 (Add)                   (None, 32, 32, 64)   0           ['activation_38[0][0]',
#                                                                   'activation_40[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 64)   36928       ['add_33[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 64)  256         ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_41[0][0]']
#
#  add_34 (Add)                   (None, 32, 32, 64)   0           ['conv2d_42[0][0]',
#                                                                   'activation_41[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  18464       ['add_34[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'add_9[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 64)   0           ['concatenate_2[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 64, 64, 1)    577         ['dropout_6[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 64, 64, 32)   320         ['conv2d_49[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 64, 64, 32)  128         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_42[0][0]']
#
#  add_35 (Add)                   (None, 64, 64, 32)   0           ['conv2d_49[0][0]',
#                                                                   'activation_42[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 64, 64, 32)   9248        ['add_35[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 64, 64, 32)  128         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_43[0][0]']
#
#  add_36 (Add)                   (None, 64, 64, 32)   0           ['conv2d_49[0][0]',
#                                                                   'activation_43[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 32)   9248        ['add_36[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 64, 64, 32)  128         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 64, 64, 32)  128         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_45[0][0]']
#
#  add_37 (Add)                   (None, 64, 64, 32)   0           ['activation_44[0][0]',
#                                                                   'activation_45[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 64, 64, 32)   9248        ['add_37[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 64, 64, 32)  128         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_46[0][0]']
#
#  add_38 (Add)                   (None, 64, 64, 32)   0           ['activation_44[0][0]',
#                                                                   'activation_46[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 32)   9248        ['add_38[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 64, 64, 32)  128         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_47[0][0]']
#
#  add_39 (Add)                   (None, 64, 64, 32)   0           ['conv2d_49[0][0]',
#                                                                   'activation_47[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  4624       ['add_39[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'add_4[0][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 1)  289         ['dropout_7[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 16  160         ['conv2d_56[0][0]']
#                                 )
#
#  batch_normalization_48 (BatchN  (None, 128, 128, 16  64         ['conv2d_57[0][0]']
#  ormalization)                  )
#
#  activation_48 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_48[0][0]']
#                                 )
#
#  add_40 (Add)                   (None, 128, 128, 16  0           ['conv2d_56[0][0]',
#                                 )                                 'activation_48[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 16  2320        ['add_40[0][0]']
#                                 )
#
#  batch_normalization_49 (BatchN  (None, 128, 128, 16  64         ['conv2d_58[0][0]']
#  ormalization)                  )
#
#  activation_49 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_49[0][0]']
#                                 )
#
#  add_41 (Add)                   (None, 128, 128, 16  0           ['conv2d_56[0][0]',
#                                 )                                 'activation_49[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 128, 128, 16  2320        ['add_41[0][0]']
#                                 )
#
#  batch_normalization_50 (BatchN  (None, 128, 128, 16  64         ['conv2d_59[0][0]']
#  ormalization)                  )
#
#  activation_50 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_50[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 16  2320        ['activation_50[0][0]']
#                                 )
#
#  batch_normalization_51 (BatchN  (None, 128, 128, 16  64         ['conv2d_60[0][0]']
#  ormalization)                  )
#
#  activation_51 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_51[0][0]']
#                                 )
#
#  add_42 (Add)                   (None, 128, 128, 16  0           ['activation_50[0][0]',
#                                 )                                 'activation_51[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 128, 128, 16  2320        ['add_42[0][0]']
#                                 )
#
#  batch_normalization_52 (BatchN  (None, 128, 128, 16  64         ['conv2d_61[0][0]']
#  ormalization)                  )
#
#  activation_52 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_52[0][0]']
#                                 )
#
#  add_43 (Add)                   (None, 128, 128, 16  0           ['activation_50[0][0]',
#                                 )                                 'activation_52[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 128, 128, 16  2320        ['add_43[0][0]']
#                                 )
#
#  batch_normalization_53 (BatchN  (None, 128, 128, 16  64         ['conv2d_62[0][0]']
#  ormalization)                  )
#
#  activation_53 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_53[0][0]']
#                                 )
#
#  add_44 (Add)                   (None, 128, 128, 16  0           ['conv2d_56[0][0]',
#                                 )                                 'activation_53[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 128, 128, 1)  17          ['add_44[0][0]']
#
# ==================================================================================================
# Total params: 5,334,659
# Trainable params: 5,325,827
# Non-trainable params: 8,832
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_dtype=True)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.975208 to fit
#
# (process:21128): GLib-GIO-WARNING **: 22:34:14.111: Unexpectedly, UWP app `18184wherewhere.AndroidAppInstaller_0.1.25.0_x64__4v4sx105x6y4r' (AUMId `18184wherewhere.AndroidAppInstaller_4v4sx105x6y4r!App') supports 4 extensions but has no verbs
#
# (process:21128): GLib-GIO-WARNING **: 22:34:14.724: Unexpectedly, UWP app `Microsoft.ScreenSketch_11.2310.54.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.ScreenSketch_8wekyb3d8bbwe!App') supports 29 extensions but has no verbs
#
# (process:21128): GLib-GIO-WARNING **: 22:34:14.758: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs
#
# (process:21128): GLib-GIO-WARNING **: 22:34:14.932: Unexpectedly, UWP app `Microsoft.OutlookForWindows_1.2023.1214.201_x64__8wekyb3d8bbwe' (AUMId `Microsoft.OutlookForWindows_8wekyb3d8bbwe!Microsoft.OutlookforWindows') supports 1 extensions but has no verbs

# %%
# Define callbacks
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-Unet.h5', verbose=1, save_best_only=True, save_weights_only=True),
]

# %%
results = model.fit(lung_train, infect_train, batch_size=8, epochs=50, callbacks=callbacks, validation_data=(lung_test, infect_test), use_multiprocessing=True)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 results = model.fit(lung_train, infect_train, batch_size=8, epochs=50, callbacks=callbacks, validation_data=(lung_test, infect_test), use_multiprocessing=True)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\training.py:1384, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1377 with tf.profiler.experimental.Trace(
#    1378     'train',
#    1379     epoch_num=epoch,
#    1380     step_num=step,
#    1381     batch_size=batch_size,
#    1382     _r=1):
#    1383   callbacks.on_train_batch_begin(step)
# -> 1384   tmp_logs = self.train_function(iterator)
#    1385   if data_handler.should_sync:
#    1386     context.async_wait()
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\def_function.py:980, in Function._call(self, *args, **kwds)
#     976     pass  # Fall through to cond-based initialization.
#     977   else:
#     978     # Lifting succeeded, so variables are initialized and we can run the
#     979     # stateless function.
# --> 980     return self._stateless_fn(*args, **kwds)
#     981 else:
#     982   _, _, _, filtered_flat_args = \
#     983       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     984           *args, **kwds)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\function.py:2955, in Function.__call__(self, *args, **kwargs)
#    2952 """Calls a graph function specialized to the inputs."""
#    2953 with self._lock:
#    2954   (graph_function,
# -> 2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\function.py:3292, in Function._maybe_define_function(self, args, kwargs)
#    3288   return self._define_function_with_shape_relaxation(
#    3289       args, kwargs, flat_args, filtered_flat_args)
#    3291 self._function_cache.add_call_context(cache_key.call_context)
# -> 3292 graph_function = self._create_graph_function(args, kwargs)
#    3293 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                          graph_function)
#    3296 return graph_function, filtered_flat_args
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\function.py:3130, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3125 missing_arg_names = [
#    3126     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3127 ]
#    3128 arg_names = base_arg_names + missing_arg_names
#    3129 graph_function = ConcreteFunction(
# -> 3130     func_graph_module.func_graph_from_py_func(
#    3131         self._name,
#    3132         self._python_function,
#    3133         args,
#    3134         kwargs,
#    3135         self.input_signature,
#    3136         autograph=self._autograph,
#    3137         autograph_options=self._autograph_options,
#    3138         arg_names=arg_names,
#    3139         override_flat_arg_shapes=override_flat_arg_shapes,
#    3140         capture_by_value=self._capture_by_value),
#    3141     self._function_attributes,
#    3142     function_spec=self.function_spec,
#    3143     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3144     # scope. This is not the default behavior since it gets used in some
#    3145     # places (like Keras) where the FuncGraph lives longer than the
#    3146     # ConcreteFunction.
#    3147     shared_func_graph=False)
#    3148 return graph_function
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\func_graph.py:1161, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1158 else:
#    1159   _, original_func = tf_decorator.unwrap(python_func)
# -> 1161 func_outputs = python_func(*func_args, **func_kwargs)
#    1163 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1164 # TensorArrays and `None`s.
#    1165 func_outputs = nest.map_structure(convert, func_outputs,
#    1166                                   expand_composites=True)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\eager\def_function.py:677, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     673 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     674   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     675   # the function a weak reference to itself to avoid a reference cycle.
#     676   with OptionalXlaContext(compile_with_xla):
# --> 677     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678   return out
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\func_graph.py:1136, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1134 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1135 try:
# -> 1136   return autograph.converted_call(
#    1137       original_func,
#    1138       args,
#    1139       kwargs,
#    1140       options=autograph.ConversionOptions(
#    1141           recursive=True,
#    1142           optional_features=autograph_options,
#    1143           user_requested=True,
#    1144       ))
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filemxzdwcn3.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\training.py:1010, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1007   run_step = tf.function(
#    1008       run_step, jit_compile=True, experimental_relax_shapes=True)
#    1009 data = next(iterator)
# -> 1010 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1011 outputs = reduce_per_replica(
#    1012     outputs, self.distribute_strategy, reduction='first')
#    1013 return outputs
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1312, in StrategyBase.run(***failed resolving arguments***)
#    1307 with self.scope():
#    1308   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1309   # applied when the caller is also in Eager mode.
#    1310   fn = autograph.tf_convert(
#    1311       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1312   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2888, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2886   kwargs = {}
#    2887 with self._container_strategy().scope():
# -> 2888   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3689, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3687 def _call_for_each_replica(self, fn, args, kwargs):
#    3688   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3689     return fn(*args, **kwargs)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\training.py:1000, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#     999 def run_step(data):
# -> 1000   outputs = model.train_step(data)
#    1001   # Ensure counter is updated only if `train_step` succeeds.
#    1002   with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\training.py:860, in Model.train_step(self, data)
#     858 with tf.GradientTape() as tape:
#     859   y_pred = self(x, training=True)
# --> 860   loss = self.compute_loss(x, y, y_pred, sample_weight)
#     861 self._validate_target_and_loss(y, loss)
#     862 # Run backwards pass.
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\training.py:918, in Model.compute_loss(***failed resolving arguments***)
#     867 """Compute the total loss, validate it, and return it.
#     868
#     869 Subclasses can optionally override this method to provide custom loss
#    (...)
#     915   the case when called by `Model.test_step`).
#     916 """
#     917 del x  # The default implementation does not use `x`.
# --> 918 return self.compiled_loss(
#     919     y, y_pred, sample_weight, regularization_losses=self.losses)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\engine\compile_utils.py:201, in LossesContainer.__call__(self, y_true, y_pred, sample_weight, regularization_losses)
#     199 y_t, y_p, sw = match_dtype_and_rank(y_t, y_p, sw)
#     200 sw = apply_mask(y_p, sw, get_mask(y_p))
# --> 201 loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     203 loss_metric_value = loss_value
#     204 # Correct for the `Mean` loss metrics counting each replica as a batch.
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\losses.py:142, in Loss.__call__(self, y_true, y_pred, sample_weight)
#     140   call_fn = tf.__internal__.autograph.tf_convert(self.call, tf.__internal__.autograph.control_status_ctx())
#     141 losses = call_fn(y_true, y_pred)
# --> 142 return losses_utils.compute_weighted_loss(
#     143     losses, sample_weight, reduction=self._get_reduction())
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\keras\utils\losses_utils.py:314, in compute_weighted_loss(losses, sample_weight, reduction, name)
#     310 input_dtype = losses.dtype
#     312 if not isinstance(sample_weight,
#     313                   (keras_tensor.KerasTensor, tf.RaggedTensor)):
# --> 314   sample_weight = tf.convert_to_tensor(sample_weight)
#     316 # TODO(psv): Handle casting here in a better way, eg. if losses is float64
#     317 # we do not want to lose precision.
#     318 losses = tf.cast(losses, 'float32')
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\ops.py:1559, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1495 @tf_export("convert_to_tensor", v1=[])
#    1496 @dispatch.add_dispatch_support
#    1497 def convert_to_tensor_v2_with_dispatch(
#    1498     value, dtype=None, dtype_hint=None, name=None):
#    1499   """Converts the given `value` to a `Tensor`.
#    1500
#    1501   This function converts Python objects of various types to `Tensor`
#    (...)
#    1557     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#    1558   """
# -> 1559   return convert_to_tensor_v2(
#    1560       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\ops.py:1565, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1563 def convert_to_tensor_v2(value, dtype=None, dtype_hint=None, name=None):
#    1564   """Converts the given `value` to a `Tensor`."""
# -> 1565   return convert_to_tensor(
#    1566       value=value,
#    1567       dtype=dtype,
#    1568       name=name,
#    1569       preferred_dtype=dtype_hint,
#    1570       as_ref=False)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\ops.py:1695, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1690       raise TypeError("convert_to_tensor did not convert to "
#    1691                       "the preferred dtype: %s vs %s " %
#    1692                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1694 if ret is None:
# -> 1695   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1697 if ret is NotImplemented:
#    1698   continue
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:48, in _default_conversion_function(***failed resolving arguments***)
#      46 def _default_conversion_function(value, dtype, name, as_ref):
#      47   del as_ref  # Unused.
# ---> 48   return constant_op.constant(value, dtype, name=name)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\constant_op.py:267, in constant(value, dtype, shape, name)
#     170 @tf_export("constant", v1=[])
#     171 def constant(value, dtype=None, shape=None, name="Const"):
#     172   """Creates a constant tensor from a tensor-like object.
#     173
#     174   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\constant_op.py:289, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     288 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 289 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     290     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     292 if op_callbacks.should_invoke_op_callbacks():
#     293   # TODO(b/147670703): Once the special-op creation code paths
#     294   # are unified. Remove this `if` block.
#     295   callback_outputs = op_callbacks.invoke_op_callbacks(
#     296       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\func_graph.py:693, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     691   inp = self.capture(inp)
#     692   captured_inputs.append(inp)
# --> 693 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     694     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     695     compute_device)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\ops.py:3776, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3773 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3774 # Session.run call cannot occur between creating and mutating the op.
#    3775 with self._mutation_lock():
# -> 3776   ret = Operation(
#    3777       node_def,
#    3778       self,
#    3779       inputs=inputs,
#    3780       output_types=dtypes,
#    3781       control_inputs=control_inputs,
#    3782       input_types=input_types,
#    3783       original_op=self._default_original_op,
#    3784       op_def=op_def)
#    3785   self._create_op_helper(ret, compute_device=compute_device)
#    3786 return ret
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\ops.py:2171, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2169   if op_def is None:
#    2170     op_def = self._graph._get_op_def(node_def.op)
# -> 2171   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2172                             control_input_ops, op_def)
#    2173   name = compat.as_str(node_def.name)
#    2175 self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\framework\ops.py:2010, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    2006   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    2007                                          serialized)
#    2009 try:
# -> 2010   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    2011 except errors.InvalidArgumentError as e:
#    2012   # Convert to ValueError for backwards compatibility.
#    2013   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
df_result = pd.DataFrame(results.history)
df_result.sort_values('val_loss', ascending=True, inplace = True)
df_result
# Out:
#         loss  accuracy       auc  sensitivity_at_specificity  \
# 41  0.004341  0.998200  0.998212                    0.997285
# 49  0.004275  0.998231  0.998195                    0.997222
# 44  0.004320  0.998210  0.998230                    0.997311
# 46  0.004284  0.998224  0.998147                    0.997127
# 38  0.004364  0.998193  0.998175                    0.997219
# 48  0.004293  0.998222  0.998191                    0.997222
# 42  0.004333  0.998214  0.998167                    0.997190
# 32  0.004402  0.998180  0.998117                    0.997118
# 45  0.004306  0.998215  0.998262                    0.997369
# 43  0.004323  0.998211  0.998236                    0.997325
# 40  0.004328  0.998217  0.998099                    0.997049
# 33  0.004385  0.998188  0.998205                    0.997288
# 47  0.004305  0.998221  0.998175                    0.997193
# 34  0.004387  0.998191  0.998183                    0.997245
# 37  0.004360  0.998199  0.998214                    0.997297
# 39  0.004343  0.998197  0.998201                    0.997262
# 31  0.004442  0.998160  0.998123                    0.997147
# 35  0.004382  0.998193  0.998132                    0.997138
# 36  0.004357  0.998201  0.998131                    0.997127
# 28  0.004650  0.998083  0.997822                    0.996628
# 30  0.004592  0.998101  0.997952                    0.996867
# 25  0.004798  0.998019  0.997752                    0.996556
# 26  0.004765  0.998037  0.997779                    0.996593
# 27  0.004714  0.998053  0.997839                    0.996691
# 29  0.004591  0.998101  0.997982                    0.996925
# 24  0.004874  0.998002  0.997616                    0.996317
# 22  0.005060  0.997931  0.997426                    0.996023
# 23  0.004948  0.997969  0.997541                    0.996199
# 21  0.005370  0.997813  0.997128                    0.995576
# 20  0.006537  0.997402  0.995410                    0.992789
# 15  0.007061  0.997207  0.994857                    0.992040
# 18  0.006469  0.997402  0.995711                    0.993351
# 16  0.006855  0.997297  0.995049                    0.992291
# 13  0.007805  0.996954  0.993671                    0.990221
# 14  0.007415  0.997067  0.994299                    0.991164
# 11  0.007933  0.996877  0.994114                    0.991239
# 9   0.008507  0.996673  0.993186                    0.989898
# 17  0.007106  0.997188  0.994772                    0.991919
# 12  0.007772  0.996943  0.993739                    0.990357
# 8   0.009044  0.996495  0.992329                    0.988720
# 19  0.006391  0.997450  0.995765                    0.993415
# 10  0.008166  0.996826  0.993353                    0.989939
# 6   0.009531  0.996315  0.991330                    0.987282
# 5   0.010413  0.996021  0.990351                    0.986328
# 4   0.011662  0.995630  0.986769                    0.980811
# 3   0.012212  0.995423  0.986726                    0.981702
# 7   0.009343  0.996378  0.991900                    0.988161
# 2   0.013456  0.995018  0.984117                    0.978742
# 1   0.015942  0.994342  0.978244                    0.972549
# 0   0.036863  0.990252  0.904995                    0.895200
#
#     specificity_at_sensitivity  mean_io_u  val_loss  val_accuracy   val_auc  \
# 41                    0.999962   0.496658  0.004734      0.998071  0.996210
# 49                    0.999963   0.496658  0.004735      0.998071  0.996142
# 44                    0.999961   0.496658  0.004740      0.998059  0.996094
# 46                    0.999960   0.496658  0.004744      0.998069  0.995812
# 38                    0.999956   0.496658  0.004748      0.998068  0.996091
# 48                    0.999962   0.496658  0.004748      0.998057  0.996288
# 42                    0.999962   0.496658  0.004752      0.998055  0.996446
# 32                    0.999957   0.496658  0.004753      0.998045  0.996322
# 45                    0.999962   0.496658  0.004754      0.998062  0.996151
# 43                    0.999962   0.496658  0.004759      0.998049  0.996255
# 40                    0.999960   0.496658  0.004761      0.998057  0.996179
# 33                    0.999957   0.496658  0.004764      0.998044  0.996338
# 47                    0.999961   0.496658  0.004770      0.998051  0.996343
# 34                    0.999957   0.496658  0.004770      0.998048  0.996352
# 37                    0.999956   0.496658  0.004775      0.998048  0.996235
# 39                    0.999958   0.496658  0.004782      0.998052  0.996179
# 31                    0.999959   0.496658  0.004797      0.998038  0.996272
# 35                    0.999955   0.496658  0.004797      0.998030  0.996394
# 36                    0.999958   0.496658  0.004809      0.998035  0.996232
# 28                    0.999942   0.496658  0.004879      0.997992  0.997049
# 30                    0.999950   0.496658  0.004905      0.997984  0.996217
# 25                    0.999936   0.496658  0.004931      0.997973  0.996153
# 26                    0.999936   0.496658  0.004934      0.997984  0.995521
# 27                    0.999938   0.496658  0.004951      0.997960  0.996339
# 29                    0.999949   0.496658  0.005003      0.997937  0.996430
# 24                    0.999930   0.496658  0.005013      0.997927  0.996726
# 22                    0.999922   0.496658  0.005038      0.997900  0.996222
# 23                    0.999929   0.496658  0.005059      0.997931  0.995162
# 21                    0.999896   0.496658  0.005249      0.997790  0.996457
# 20                    0.999809   0.496658  0.006082      0.997529  0.996021
# 15                    0.999741   0.496658  0.006173      0.997422  0.995760
# 18                    0.999798   0.496658  0.006267      0.997495  0.992054
# 16                    0.999774   0.496658  0.006551      0.997394  0.992638
# 13                    0.999667   0.496658  0.006775      0.997257  0.992630
# 14                    0.999690   0.496658  0.007036      0.997063  0.996477
# 11                    0.999632   0.496658  0.007128      0.997176  0.994284
# 9                     0.999559   0.496658  0.007241      0.997065  0.993497
# 17                    0.999748   0.496658  0.007576      0.997036  0.996321
# 12                    0.999664   0.496658  0.007578      0.996909  0.994601
# 8                     0.999457   0.496658  0.007906      0.996897  0.988868
# 19                    0.999809   0.496658  0.008179      0.996714  0.990839
# 10                    0.999608   0.496658  0.008189      0.996735  0.988958
# 6                     0.999376   0.496658  0.008424      0.996616  0.993141
# 5                     0.999182   0.496658  0.008881      0.996580  0.992277
# 4                     0.998923   0.496658  0.009400      0.996361  0.989738
# 3                     0.998742   0.496658  0.010043      0.996217  0.990561
# 7                     0.999397   0.496658  0.011382      0.995779  0.993818
# 2                     0.998315   0.496658  0.013745      0.995069  0.975622
# 1                     0.997161   0.496658  0.014853      0.994396  0.989319
# 0                     0.974338   0.496654  0.016591      0.994461  0.983251
#
#     val_sensitivity_at_specificity  val_specificity_at_sensitivity  \
# 41                        0.993557                        0.999916
# 49                        0.993407                        0.999916
# 44                        0.993317                        0.999919
# 46                        0.992748                        0.999914
# 38                        0.993317                        0.999914
# 48                        0.993707                        0.999918
# 42                        0.994036                        0.999918
# 32                        0.993796                        0.999911
# 45                        0.993437                        0.999915
# 43                        0.993647                        0.999919
# 40                        0.993497                        0.999914
# 33                        0.993826                        0.999917
# 47                        0.993826                        0.999917
# 34                        0.993856                        0.999911
# 37                        0.993617                        0.999915
# 39                        0.993497                        0.999915
# 31                        0.993707                        0.999911
# 35                        0.993946                        0.999918
# 36                        0.993617                        0.999912
# 28                        0.995355                        0.999905
# 30                        0.993647                        0.999912
# 25                        0.993557                        0.999899
# 26                        0.992268                        0.999907
# 27                        0.993916                        0.999914
# 29                        0.994126                        0.999899
# 24                        0.994755                        0.999890
# 22                        0.993766                        0.999889
# 23                        0.991609                        0.999892
# 21                        0.994336                        0.999881
# 20                        0.994066                        0.999793
# 15                        0.993497                        0.999778
# 18                        0.985855                        0.999775
# 16                        0.987443                        0.999725
# 13                        0.987413                        0.999697
# 14                        0.995445                        0.999727
# 11                        0.991339                        0.999689
# 9                         0.989781                        0.999608
# 17                        0.994845                        0.999710
# 12                        0.991998                        0.999659
# 8                         0.980640                        0.999516
# 19                        0.983877                        0.999669
# 10                        0.981030                        0.999420
# 6                         0.990230                        0.999444
# 5                         0.989391                        0.999349
# 4                         0.984476                        0.999266
# 3                         0.987863                        0.999068
# 7                         0.992178                        0.999282
# 2                         0.958493                        0.998501
# 1                         0.989451                        0.998254
# 0                         0.986035                        0.997099
#
#     val_mean_io_u       lr
# 41       0.497107  0.00001
# 49       0.497107  0.00001
# 44       0.497107  0.00001
# 46       0.497107  0.00001
# 38       0.497107  0.00001
# 48       0.497107  0.00001
# 42       0.497107  0.00001
# 32       0.497107  0.00001
# 45       0.497107  0.00001
# 43       0.497107  0.00001
# 40       0.497107  0.00001
# 33       0.497107  0.00001
# 47       0.497107  0.00001
# 34       0.497107  0.00001
# 37       0.497107  0.00001
# 39       0.497107  0.00001
# 31       0.497107  0.00001
# 35       0.497107  0.00001
# 36       0.497107  0.00001
# 28       0.497107  0.00010
# 30       0.497107  0.00010
# 25       0.497107  0.00010
# 26       0.497107  0.00010
# 27       0.497107  0.00010
# 29       0.497107  0.00010
# 24       0.497107  0.00010
# 22       0.497107  0.00010
# 23       0.497107  0.00010
# 21       0.497107  0.00010
# 20       0.497107  0.00100
# 15       0.497107  0.00100
# 18       0.497107  0.00100
# 16       0.497107  0.00100
# 13       0.497107  0.00100
# 14       0.497107  0.00100
# 11       0.497107  0.00100
# 9        0.497107  0.00100
# 17       0.497107  0.00100
# 12       0.497107  0.00100
# 8        0.497107  0.00100
# 19       0.497107  0.00100
# 10       0.497107  0.00100
# 6        0.497107  0.00100
# 5        0.497107  0.00100
# 4        0.497107  0.00100
# 3        0.497107  0.00100
# 7        0.497107  0.00100
# 2        0.497107  0.00100
# 1        0.497107  0.00100
# 0        0.497107  0.00100

# %%
model.save("Recurrent_UNet.h5")

# %%
plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["accuracy"], label="Accuracy")
plt.plot(results.history["val_accuracy"], label="val_Accuracy")
plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %%
# Calculate metrics
predicted = model.predict(lung_test)

# Flatten the predicted and true masks
predicted_flat = np.round(predicted.flatten())
infect_test_flat = infect_test.flatten()

# %%
device = "CPU:0"

# %%
with tf.device(device):
    # Calculate metrics for training data
    train_predicted = model.predict(lung_train)

    # Flatten the predicted and true masks
    train_predicted_flat = np.round(train_predicted.flatten())
    infect_train_flat = infect_train.flatten()

    # Calculate precision and recall for training data
    train_precision = Precision()
    train_recall = Recall()
    train_precision.update_state(infect_train_flat, train_predicted_flat)
    train_recall.update_state(infect_train_flat, train_predicted_flat)

    # Calculate F1 score for training data
    train_f1_score = 2 * (train_precision.result() * train_recall.result()) / (train_precision.result() + train_recall.result())

    # Calculate accuracy for training data
    train_accuracy = np.mean(train_predicted_flat == infect_train_flat)

    # Calculate metrics for testing data
    test_predicted = model.predict(lung_test)

    # Flatten the predicted and true masks for testing data
    test_predicted_flat = np.round(test_predicted.flatten())
    infect_test_flat = infect_test.flatten()

    # Calculate precision and recall for testing data
    test_precision = Precision()
    test_recall = Recall()
    test_precision.update_state(infect_test_flat, test_predicted_flat)
    test_recall.update_state(infect_test_flat, test_predicted_flat)

    # Calculate F1 score for testing data
    test_f1_score = 2 * (test_precision.result() * test_recall.result()) / (test_precision.result() + test_recall.result())

    # Calculate accuracy for testing data
    test_accuracy = np.mean(test_predicted_flat == infect_test_flat)

    # Calculate parameters
    total_parameters = np.sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])

    # Calculate FLOPs
    flops = get_flops(model, batch_size=1)  # Assuming batch_size = 1

    # Print the metrics for training data
    print("Training Metrics:")
    print("Precision: ", train_precision.result().numpy())
    print("Recall: ", train_recall.result().numpy())
    print("F1 Score: ", train_f1_score.numpy())
    print("Accuracy: ", train_accuracy)

    # Print the metrics for testing data
    print("\nTesting Metrics:")
    print("Precision: ", test_precision.result().numpy())
    print("Recall: ", test_recall.result().numpy())
    print("F1 Score: ", test_f1_score.numpy())
    print("Accuracy: ", test_accuracy)

    # Print the other metrics
    print("\nTotal Parameters: ", total_parameters)
    print("FLOPs: ", flops)
# Out:
# WARNING:tensorflow:From c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\ops\nn_ops.py:5214: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# Training Metrics:
# Precision:  0.87314
# Recall:  0.87634593
# F1 Score:  0.87474
# Accuracy:  0.998322226784446
#
# Testing Metrics:
# Precision:  0.8376491
# Recall:  0.82693
# F1 Score:  0.83225495
# Accuracy:  0.998071323741566
#
# Total Parameters:  5325827
# FLOPs:  3611152832

# %%
with tf.device("CPU"):
    # Calculate Jaccard Index (MeanIoU) for training data
    train_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    train_iou.update_state(infect_train_flat, train_predicted_flat)
    train_mean_iou = train_iou.result().numpy()

    # Calculate Jaccard Index (MeanIoU) for testing data
    test_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    test_iou.update_state(infect_test_flat, test_predicted_flat)
    test_mean_iou = test_iou.result().numpy()

    # Print the Jaccard Index (MeanIoU) for training and testing data
    print("Training Jaccard Index (MeanIoU): ", train_mean_iou)
    print("Testing Jaccard Index (MeanIoU): ", test_mean_iou)
# Out:
# Training Jaccard Index (MeanIoU):  0.9020136
# Testing Jaccard Index (MeanIoU):  0.89031833

# %%
# Plot accuracy
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
# Make predictions
predicted = model.predict(lung_test)
# Out:
# 11/11 [==============================] - 2s 220ms/step

# %%
with tf.device(device):
    # Make predictions and visualize
    img_num = 8
    predicted = model.predict(lung_test)

    # Visualize results
    fig = plt.figure(figsize=(18, 15))
    plt.subplot(1, 3, 1)
    plt.imshow(lung_test[img_num], cmap='bone')
    plt.title('Original lung')

    plt.subplot(1, 3, 2)
    plt.imshow(lung_test[img_num], cmap='bone')
    plt.imshow(infect_test[img_num][..., 0], alpha=0.5, cmap="nipy_spectral")
    plt.title('Original infection mask')

    plt.subplot(1, 3, 3)
    plt.imshow(lung_test[img_num], cmap='bone')
    plt.imshow(predicted[img_num], alpha=0.5, cmap="nipy_spectral")
    plt.title('Predicted infection mask')
# Out:
# 11/11 [==============================] - 3s 240ms/step
# Text(0.5, 1.0, 'Predicted infection mask')

# %%
# Plot Jaccard Index (MeanIoU)
plt.plot(results.history['mean_io_u'])
plt.plot(results.history['val_mean_io_u'])
plt.title('MeanIoU (Jaccard Index) vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('MeanIoU (Jaccard Index)')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
