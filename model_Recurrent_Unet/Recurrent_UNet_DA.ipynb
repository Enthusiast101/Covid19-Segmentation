# %%
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras.metrics import Precision, Recall
from keras_flops import get_flops

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import LSTM, Reshape, ConvLSTM2D, Conv2D, Input, MaxPooling2D, Dropout, add, concatenate, UpSampling2D, BatchNormalization, Activation, Conv2DTranspose
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import gc

# %%
# Read and examine metadata
raw_data = pd.read_csv(r'../COVID-19 Lung CT Scan Segmentation/COVID-19 Lung CT Scan Segmentation/metadata_temp.csv')
raw_data.sample(5)
# Out:
#                                               ct_scan  \
# 11  C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 14  C:\Application\Programming\Research\Lung_Segme...
# 6   C:\Application\Programming\Research\Lung_Segme...
#
#                                             lung_mask  \
# 11  C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 14  C:\Application\Programming\Research\Lung_Segme...
# 6   C:\Application\Programming\Research\Lung_Segme...
#
#                                        infection_mask  \
# 11  C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 14  C:\Application\Programming\Research\Lung_Segme...
# 6   C:\Application\Programming\Research\Lung_Segme...
#
#                               lung_and_infection_mask
# 11  C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
# 14  C:\Application\Programming\Research\Lung_Segme...
# 6   C:\Application\Programming\Research\Lung_Segme...

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
# Read sample
sample_ct   = read_nii(raw_data.loc[1,'ct_scan'])
sample_lung = read_nii(raw_data.loc[1,'lung_mask'])
sample_infe = read_nii(raw_data.loc[1,'infection_mask'])
sample_all  = read_nii(raw_data.loc[1,'lung_and_infection_mask'])

# Examine Shape
sample_ct.shape
# Out:
# (512, 512, 200)

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %%
IMG_SIZE = 128
IMG_HEIGHT = IMG_SIZE
IMG_WIDTH = IMG_SIZE
IMG_CHANNELS = 1

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

def get_data():
    lungs_data = []
    infections_data  = []

    for row in range(len(raw_data)):
        lungs_image = read_nii(raw_data['ct_scan'][row])
        infection_image = read_nii(raw_data['infection_mask'][row])

        for slice_no in range(lungs_image.shape[2]):
            lung_slice = cv2.resize(lungs_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA)
            infection_slice = cv2.resize(infection_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')

            lung_slice_temp = lung_slice.reshape(-1, 2)
            lung_slice_temp = scaler.fit_transform(lung_slice_temp)
            lung_slice = lung_slice_temp.reshape(lung_slice.shape)
            lungs_data.append(lung_slice[..., np.newaxis])

            infections_data.append(infection_slice[..., np.newaxis])
    return lungs_data, infections_data

# %%
data = get_data()
lungs = np.array(data[0])
infections = np.array(data[1])

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,2,1)
plt.imshow(lungs[451], cmap = 'bone')
plt.title('Transformed Image')

plt.subplot(1,2,2)
plt.imshow(lungs[451], cmap = 'bone')
plt.imshow(infections[451],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Transformed Infection Mask')
# Out:
# Text(0.5, 1.0, 'Transformed Infection Mask')

# %%
# Split the data into train and test sets
lung_train, lung_test, infect_train, infect_test = train_test_split(lungs, infections, test_size=0.1, shuffle=True)

# %%
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, RandomContrast, RandomCrop, GaussianNoise

# %%
def recc_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True, conv_num=2, rec_num=2):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    skip_layer = Conv2D(filters = 1, kernel_size = (kernel_size, kernel_size),\
                kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    temp = skip_layer
    for _ in range(conv_num):
        x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
                kernel_initializer = 'he_normal', padding = 'same')(temp)
        if batchnorm:
            x = BatchNormalization()(x)
        x = Activation('relu')(x)

        for _ in range(rec_num):
            x = add([temp, x])
            x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
                    kernel_initializer = 'he_normal', padding = 'same')(x)
            if batchnorm:
                x = BatchNormalization()(x)
            x = Activation("relu")(x)    
        temp = x
        
    x = add([skip_layer, temp])
    return x

# %%
def RecurrentUnet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    aug = RandomRotation(10)(input_img)
    aug = RandomZoom(0.1)(aug)
    aug = RandomContrast(0.1)(aug)
    aug = GaussianNoise(10)(aug)
    input_img = aug  
    # Contracting Path
    c1 = recc_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = recc_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = recc_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = recc_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = recc_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = recc_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = recc_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = recc_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = recc_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
import tensorflow.keras.backend as K

def jaccard_loss(y_true, y_pred, smooth=1e-7):
    y_true = K.cast(y_true, dtype='float32')  # Cast y_true to float32
    intersection = K.sum(y_true * y_pred, axis=(1, 2, 3))
    union = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3)) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    return 1 - jaccard

# %%
from keras import backend as K
K.clear_session()

# Define the UNET model with TensorFlow's MeanIoU metric
input_img = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), name='img')
model = RecurrentUnet(input_img, n_filters=16, dropout=0.05)
metrics = ["accuracy", 
           tf.keras.metrics.AUC(), 
           tf.keras.metrics.SensitivityAtSpecificity(0.5), 
           tf.keras.metrics.SpecificityAtSensitivity(0.5),
           tf.keras.metrics.MeanIoU(num_classes=2)]  # Use MeanIoU as the Jaccard Index metric
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=metrics)  # Use custom Jaccard loss

gc.collect()
# Out:
# 1899

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 1)  10          ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  160         ['conv2d[1][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 16  64         ['conv2d_1[1][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 16  0           ['batch_normalization[1][0]']
#                                 )
#
#  add (Add)                      (None, 128, 128, 16  0           ['conv2d[1][0]',
#                                 )                                 'activation[1][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 16  2320        ['add[1][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 16  64         ['conv2d_2[1][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_1[1][0]']
#                                 )
#
#  add_1 (Add)                    (None, 128, 128, 16  0           ['conv2d[1][0]',
#                                 )                                 'activation_1[1][0]']
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 16  2320        ['add_1[1][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 16  64         ['conv2d_3[1][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_2[1][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 16  2320        ['activation_2[1][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 16  64         ['conv2d_4[1][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_3[1][0]']
#                                 )
#
#  add_2 (Add)                    (None, 128, 128, 16  0           ['activation_2[1][0]',
#                                 )                                 'activation_3[1][0]']
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 16  2320        ['add_2[1][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 16  64         ['conv2d_5[1][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_4[1][0]']
#                                 )
#
#  add_3 (Add)                    (None, 128, 128, 16  0           ['activation_2[1][0]',
#                                 )                                 'activation_4[1][0]']
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 16  2320        ['add_3[1][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 16  64         ['conv2d_6[1][0]']
#  rmalization)                   )
#
#  activation_5 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_5[1][0]']
#                                 )
#
#  add_4 (Add)                    (None, 128, 128, 16  0           ['conv2d[1][0]',
#                                 )                                 'activation_5[1][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['add_4[1][0]']
#
#  dropout (Dropout)              (None, 64, 64, 16)   0           ['max_pooling2d[1][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 1)    145         ['dropout[1][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 32)   320         ['conv2d_7[1][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_8[1][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_6[1][0]']
#
#  add_5 (Add)                    (None, 64, 64, 32)   0           ['conv2d_7[1][0]',
#                                                                   'activation_6[1][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 32)   9248        ['add_5[1][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_9[1][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_7[1][0]']
#
#  add_6 (Add)                    (None, 64, 64, 32)   0           ['conv2d_7[1][0]',
#                                                                   'activation_7[1][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 32)   9248        ['add_6[1][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_10[1][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_8[1][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_8[1][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_11[1][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_9[1][0]']
#
#  add_7 (Add)                    (None, 64, 64, 32)   0           ['activation_8[1][0]',
#                                                                   'activation_9[1][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 32)   9248        ['add_7[1][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 32)  128         ['conv2d_12[1][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_10[1][0]']
#
#  add_8 (Add)                    (None, 64, 64, 32)   0           ['activation_8[1][0]',
#                                                                   'activation_10[1][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 32)   9248        ['add_8[1][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 32)  128         ['conv2d_13[1][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_11[1][0]']
#
#  add_9 (Add)                    (None, 64, 64, 32)   0           ['conv2d_7[1][0]',
#                                                                   'activation_11[1][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['add_9[1][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 32)   0           ['max_pooling2d_1[1][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 1)    289         ['dropout_1[1][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   640         ['conv2d_14[1][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['conv2d_15[1][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_12[1][0]']
#
#  add_10 (Add)                   (None, 32, 32, 64)   0           ['conv2d_14[1][0]',
#                                                                   'activation_12[1][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 64)   36928       ['add_10[1][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 64)  256         ['conv2d_16[1][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_13[1][0]']
#
#  add_11 (Add)                   (None, 32, 32, 64)   0           ['conv2d_14[1][0]',
#                                                                   'activation_13[1][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 64)   36928       ['add_11[1][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 64)  256         ['conv2d_17[1][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_14[1][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_14[1][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 64)  256         ['conv2d_18[1][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_15[1][0]']
#
#  add_12 (Add)                   (None, 32, 32, 64)   0           ['activation_14[1][0]',
#                                                                   'activation_15[1][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   36928       ['add_12[1][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 64)  256         ['conv2d_19[1][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_16[1][0]']
#
#  add_13 (Add)                   (None, 32, 32, 64)   0           ['activation_14[1][0]',
#                                                                   'activation_16[1][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 64)   36928       ['add_13[1][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 64)  256         ['conv2d_20[1][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_17[1][0]']
#
#  add_14 (Add)                   (None, 32, 32, 64)   0           ['conv2d_14[1][0]',
#                                                                   'activation_17[1][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['add_14[1][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 64)   0           ['max_pooling2d_2[1][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 1)    577         ['dropout_2[1][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 128)  1280        ['conv2d_21[1][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 128)  512        ['conv2d_22[1][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_18[1][0]']
#
#  add_15 (Add)                   (None, 16, 16, 128)  0           ['conv2d_21[1][0]',
#                                                                   'activation_18[1][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 128)  147584      ['add_15[1][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 128)  512        ['conv2d_23[1][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_19[1][0]']
#
#  add_16 (Add)                   (None, 16, 16, 128)  0           ['conv2d_21[1][0]',
#                                                                   'activation_19[1][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 128)  147584      ['add_16[1][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 128)  512        ['conv2d_24[1][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_20[1][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_20[1][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 128)  512        ['conv2d_25[1][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_21[1][0]']
#
#  add_17 (Add)                   (None, 16, 16, 128)  0           ['activation_20[1][0]',
#                                                                   'activation_21[1][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 128)  147584      ['add_17[1][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 128)  512        ['conv2d_26[1][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_22[1][0]']
#
#  add_18 (Add)                   (None, 16, 16, 128)  0           ['activation_20[1][0]',
#                                                                   'activation_22[1][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 128)  147584      ['add_18[1][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 128)  512        ['conv2d_27[1][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_23[1][0]']
#
#  add_19 (Add)                   (None, 16, 16, 128)  0           ['conv2d_21[1][0]',
#                                                                   'activation_23[1][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['add_19[1][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 128)    0           ['max_pooling2d_3[1][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 1)      1153        ['dropout_3[1][0]']
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 256)    2560        ['conv2d_28[1][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_29[1][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_24[1][0]']
#
#  add_20 (Add)                   (None, 8, 8, 256)    0           ['conv2d_28[1][0]',
#                                                                   'activation_24[1][0]']
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 256)    590080      ['add_20[1][0]']
#
#  batch_normalization_25 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_30[1][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_25[1][0]']
#
#  add_21 (Add)                   (None, 8, 8, 256)    0           ['conv2d_28[1][0]',
#                                                                   'activation_25[1][0]']
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 256)    590080      ['add_21[1][0]']
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_31[1][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_26[1][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 256)    590080      ['activation_26[1][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_32[1][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_27[1][0]']
#
#  add_22 (Add)                   (None, 8, 8, 256)    0           ['activation_26[1][0]',
#                                                                   'activation_27[1][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 256)    590080      ['add_22[1][0]']
#
#  batch_normalization_28 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_33[1][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_28[1][0]']
#
#  add_23 (Add)                   (None, 8, 8, 256)    0           ['activation_26[1][0]',
#                                                                   'activation_28[1][0]']
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 256)    590080      ['add_23[1][0]']
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_34[1][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_29[1][0]']
#
#  add_24 (Add)                   (None, 8, 8, 256)    0           ['conv2d_28[1][0]',
#                                                                   'activation_29[1][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  295040     ['add_24[1][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[1][0]',
#                                                                   'add_19[1][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 256)  0           ['concatenate[1][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 1)    2305        ['dropout_4[1][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 128)  1280        ['conv2d_35[1][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 128)  512        ['conv2d_36[1][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_30[1][0]']
#
#  add_25 (Add)                   (None, 16, 16, 128)  0           ['conv2d_35[1][0]',
#                                                                   'activation_30[1][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 128)  147584      ['add_25[1][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 128)  512        ['conv2d_37[1][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_31[1][0]']
#
#  add_26 (Add)                   (None, 16, 16, 128)  0           ['conv2d_35[1][0]',
#                                                                   'activation_31[1][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 128)  147584      ['add_26[1][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 128)  512        ['conv2d_38[1][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_32[1][0]']
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_32[1][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 128)  512        ['conv2d_39[1][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_33[1][0]']
#
#  add_27 (Add)                   (None, 16, 16, 128)  0           ['activation_32[1][0]',
#                                                                   'activation_33[1][0]']
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 128)  147584      ['add_27[1][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 128)  512        ['conv2d_40[1][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_34[1][0]']
#
#  add_28 (Add)                   (None, 16, 16, 128)  0           ['activation_32[1][0]',
#                                                                   'activation_34[1][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 128)  147584      ['add_28[1][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 128)  512        ['conv2d_41[1][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_35[1][0]']
#
#  add_29 (Add)                   (None, 16, 16, 128)  0           ['conv2d_35[1][0]',
#                                                                   'activation_35[1][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  73792       ['add_29[1][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[1][0]',
#                                                                   'add_14[1][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['concatenate_1[1][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 1)    1153        ['dropout_5[1][0]']
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 64)   640         ['conv2d_42[1][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 64)  256         ['conv2d_43[1][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_36[1][0]']
#
#  add_30 (Add)                   (None, 32, 32, 64)   0           ['conv2d_42[1][0]',
#                                                                   'activation_36[1][0]']
#
#  conv2d_44 (Conv2D)             (None, 32, 32, 64)   36928       ['add_30[1][0]']
#
#  batch_normalization_37 (BatchN  (None, 32, 32, 64)  256         ['conv2d_44[1][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_37[1][0]']
#
#  add_31 (Add)                   (None, 32, 32, 64)   0           ['conv2d_42[1][0]',
#                                                                   'activation_37[1][0]']
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 64)   36928       ['add_31[1][0]']
#
#  batch_normalization_38 (BatchN  (None, 32, 32, 64)  256         ['conv2d_45[1][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_38[1][0]']
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_38[1][0]']
#
#  batch_normalization_39 (BatchN  (None, 32, 32, 64)  256         ['conv2d_46[1][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_39[1][0]']
#
#  add_32 (Add)                   (None, 32, 32, 64)   0           ['activation_38[1][0]',
#                                                                   'activation_39[1][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 64)   36928       ['add_32[1][0]']
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 64)  256         ['conv2d_47[1][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_40[1][0]']
#
#  add_33 (Add)                   (None, 32, 32, 64)   0           ['activation_38[1][0]',
#                                                                   'activation_40[1][0]']
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 64)   36928       ['add_33[1][0]']
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 64)  256         ['conv2d_48[1][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_41[1][0]']
#
#  add_34 (Add)                   (None, 32, 32, 64)   0           ['conv2d_42[1][0]',
#                                                                   'activation_41[1][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  18464       ['add_34[1][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[1][0]',
#                                                                   'add_9[1][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 64)   0           ['concatenate_2[1][0]']
#
#  conv2d_49 (Conv2D)             (None, 64, 64, 1)    577         ['dropout_6[1][0]']
#
#  conv2d_50 (Conv2D)             (None, 64, 64, 32)   320         ['conv2d_49[1][0]']
#
#  batch_normalization_42 (BatchN  (None, 64, 64, 32)  128         ['conv2d_50[1][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_42[1][0]']
#
#  add_35 (Add)                   (None, 64, 64, 32)   0           ['conv2d_49[1][0]',
#                                                                   'activation_42[1][0]']
#
#  conv2d_51 (Conv2D)             (None, 64, 64, 32)   9248        ['add_35[1][0]']
#
#  batch_normalization_43 (BatchN  (None, 64, 64, 32)  128         ['conv2d_51[1][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_43[1][0]']
#
#  add_36 (Add)                   (None, 64, 64, 32)   0           ['conv2d_49[1][0]',
#                                                                   'activation_43[1][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 32)   9248        ['add_36[1][0]']
#
#  batch_normalization_44 (BatchN  (None, 64, 64, 32)  128         ['conv2d_52[1][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_44[1][0]']
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_44[1][0]']
#
#  batch_normalization_45 (BatchN  (None, 64, 64, 32)  128         ['conv2d_53[1][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_45[1][0]']
#
#  add_37 (Add)                   (None, 64, 64, 32)   0           ['activation_44[1][0]',
#                                                                   'activation_45[1][0]']
#
#  conv2d_54 (Conv2D)             (None, 64, 64, 32)   9248        ['add_37[1][0]']
#
#  batch_normalization_46 (BatchN  (None, 64, 64, 32)  128         ['conv2d_54[1][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_46[1][0]']
#
#  add_38 (Add)                   (None, 64, 64, 32)   0           ['activation_44[1][0]',
#                                                                   'activation_46[1][0]']
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 32)   9248        ['add_38[1][0]']
#
#  batch_normalization_47 (BatchN  (None, 64, 64, 32)  128         ['conv2d_55[1][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_47[1][0]']
#
#  add_39 (Add)                   (None, 64, 64, 32)   0           ['conv2d_49[1][0]',
#                                                                   'activation_47[1][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  4624       ['add_39[1][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[1][0]',
#                                 )                                 'add_4[1][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['concatenate_3[1][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 1)  289         ['dropout_7[1][0]']
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 16  160         ['conv2d_56[1][0]']
#                                 )
#
#  batch_normalization_48 (BatchN  (None, 128, 128, 16  64         ['conv2d_57[1][0]']
#  ormalization)                  )
#
#  activation_48 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_48[1][0]']
#                                 )
#
#  add_40 (Add)                   (None, 128, 128, 16  0           ['conv2d_56[1][0]',
#                                 )                                 'activation_48[1][0]']
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 16  2320        ['add_40[1][0]']
#                                 )
#
#  batch_normalization_49 (BatchN  (None, 128, 128, 16  64         ['conv2d_58[1][0]']
#  ormalization)                  )
#
#  activation_49 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_49[1][0]']
#                                 )
#
#  add_41 (Add)                   (None, 128, 128, 16  0           ['conv2d_56[1][0]',
#                                 )                                 'activation_49[1][0]']
#
#  conv2d_59 (Conv2D)             (None, 128, 128, 16  2320        ['add_41[1][0]']
#                                 )
#
#  batch_normalization_50 (BatchN  (None, 128, 128, 16  64         ['conv2d_59[1][0]']
#  ormalization)                  )
#
#  activation_50 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_50[1][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 16  2320        ['activation_50[1][0]']
#                                 )
#
#  batch_normalization_51 (BatchN  (None, 128, 128, 16  64         ['conv2d_60[1][0]']
#  ormalization)                  )
#
#  activation_51 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_51[1][0]']
#                                 )
#
#  add_42 (Add)                   (None, 128, 128, 16  0           ['activation_50[1][0]',
#                                 )                                 'activation_51[1][0]']
#
#  conv2d_61 (Conv2D)             (None, 128, 128, 16  2320        ['add_42[1][0]']
#                                 )
#
#  batch_normalization_52 (BatchN  (None, 128, 128, 16  64         ['conv2d_61[1][0]']
#  ormalization)                  )
#
#  activation_52 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_52[1][0]']
#                                 )
#
#  add_43 (Add)                   (None, 128, 128, 16  0           ['activation_50[1][0]',
#                                 )                                 'activation_52[1][0]']
#
#  conv2d_62 (Conv2D)             (None, 128, 128, 16  2320        ['add_43[1][0]']
#                                 )
#
#  batch_normalization_53 (BatchN  (None, 128, 128, 16  64         ['conv2d_62[1][0]']
#  ormalization)                  )
#
#  activation_53 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_53[1][0]']
#                                 )
#
#  add_44 (Add)                   (None, 128, 128, 16  0           ['conv2d_56[1][0]',
#                                 )                                 'activation_53[1][0]']
#
#  conv2d_63 (Conv2D)             (None, 128, 128, 1)  17          ['add_44[1][0]']
#
# ==================================================================================================
# Total params: 5,334,659
# Trainable params: 5,325,827
# Non-trainable params: 8,832
# __________________________________________________________________________________________________

# %%
# Define callbacks
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-Unet.h5', verbose=1, save_best_only=True, save_weights_only=True),
]

# %%
results = model.fit(lung_train, infect_train, batch_size=8, epochs=50, callbacks=callbacks, validation_data=(lung_test, infect_test), use_multiprocessing=True)
# Out:
# Epoch 1/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9840 - auc: 0.8295 - sensitivity_at_specificity: 0.8623 - specificity_at_sensitivity: 0.9140 - mean_io_u: 0.4968
# Epoch 1: val_loss improved from inf to 0.02552, saving model to model-Unet.h5
# 396/396 [==============================] - 72s 146ms/step - loss: 0.0921 - accuracy: 0.9840 - auc: 0.8295 - sensitivity_at_specificity: 0.8623 - specificity_at_sensitivity: 0.9140 - mean_io_u: 0.4968 - val_loss: 0.0255 - val_accuracy: 0.9936 - val_auc: 0.9375 - val_sensitivity_at_specificity: 0.9430 - val_specificity_at_sensitivity: 0.9905 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 2/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9948 - auc: 0.9662 - sensitivity_at_specificity: 0.9520 - specificity_at_sensitivity: 0.9977 - mean_io_u: 0.4967
# Epoch 2: val_loss improved from 0.02552 to 0.01658, saving model to model-Unet.h5
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0169 - accuracy: 0.9948 - auc: 0.9662 - sensitivity_at_specificity: 0.9520 - specificity_at_sensitivity: 0.9977 - mean_io_u: 0.4967 - val_loss: 0.0166 - val_accuracy: 0.9950 - val_auc: 0.9553 - val_sensitivity_at_specificity: 0.9301 - val_specificity_at_sensitivity: 0.9971 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 3/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9956 - auc: 0.9818 - sensitivity_at_specificity: 0.9738 - specificity_at_sensitivity: 0.9989 - mean_io_u: 0.4967
# Epoch 3: val_loss improved from 0.01658 to 0.01465, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0132 - accuracy: 0.9956 - auc: 0.9818 - sensitivity_at_specificity: 0.9738 - specificity_at_sensitivity: 0.9989 - mean_io_u: 0.4967 - val_loss: 0.0146 - val_accuracy: 0.9949 - val_auc: 0.9910 - val_sensitivity_at_specificity: 0.9910 - val_specificity_at_sensitivity: 0.9989 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 4/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9960 - auc: 0.9848 - sensitivity_at_specificity: 0.9772 - specificity_at_sensitivity: 0.9992 - mean_io_u: 0.4967
# Epoch 4: val_loss did not improve from 0.01465
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0117 - accuracy: 0.9960 - auc: 0.9848 - sensitivity_at_specificity: 0.9772 - specificity_at_sensitivity: 0.9992 - mean_io_u: 0.4967 - val_loss: 0.0186 - val_accuracy: 0.9937 - val_auc: 0.9610 - val_sensitivity_at_specificity: 0.9412 - val_specificity_at_sensitivity: 0.9976 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 5/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9962 - auc: 0.9862 - sensitivity_at_specificity: 0.9786 - specificity_at_sensitivity: 0.9994 - mean_io_u: 0.4967
# Epoch 5: val_loss improved from 0.01465 to 0.00984, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 147ms/step - loss: 0.0109 - accuracy: 0.9962 - auc: 0.9862 - sensitivity_at_specificity: 0.9786 - specificity_at_sensitivity: 0.9994 - mean_io_u: 0.4967 - val_loss: 0.0098 - val_accuracy: 0.9967 - val_auc: 0.9899 - val_sensitivity_at_specificity: 0.9857 - val_specificity_at_sensitivity: 0.9995 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 6/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9966 - auc: 0.9880 - sensitivity_at_specificity: 0.9807 - specificity_at_sensitivity: 0.9995 - mean_io_u: 0.4967
# Epoch 6: val_loss did not improve from 0.00984
# 396/396 [==============================] - 59s 148ms/step - loss: 0.0097 - accuracy: 0.9966 - auc: 0.9880 - sensitivity_at_specificity: 0.9807 - specificity_at_sensitivity: 0.9995 - mean_io_u: 0.4967 - val_loss: 0.0500 - val_accuracy: 0.9817 - val_auc: 0.9911 - val_sensitivity_at_specificity: 0.9952 - val_specificity_at_sensitivity: 0.9989 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 7/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9966 - auc: 0.9897 - sensitivity_at_specificity: 0.9837 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967
# Epoch 7: val_loss improved from 0.00984 to 0.00778, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0093 - accuracy: 0.9966 - auc: 0.9897 - sensitivity_at_specificity: 0.9837 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967 - val_loss: 0.0078 - val_accuracy: 0.9972 - val_auc: 0.9893 - val_sensitivity_at_specificity: 0.9813 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 8/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9967 - auc: 0.9886 - sensitivity_at_specificity: 0.9816 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967
# Epoch 8: val_loss did not improve from 0.00778
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0094 - accuracy: 0.9967 - auc: 0.9886 - sensitivity_at_specificity: 0.9816 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967 - val_loss: 0.0080 - val_accuracy: 0.9972 - val_auc: 0.9939 - val_sensitivity_at_specificity: 0.9912 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 9/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9968 - auc: 0.9906 - sensitivity_at_specificity: 0.9850 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967
# Epoch 9: val_loss did not improve from 0.00778
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0088 - accuracy: 0.9968 - auc: 0.9906 - sensitivity_at_specificity: 0.9850 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967 - val_loss: 0.0107 - val_accuracy: 0.9962 - val_auc: 0.9885 - val_sensitivity_at_specificity: 0.9812 - val_specificity_at_sensitivity: 0.9995 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 10/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9970 - auc: 0.9924 - sensitivity_at_specificity: 0.9880 - specificity_at_sensitivity: 0.9997 - mean_io_u: 0.4967
# Epoch 10: val_loss did not improve from 0.00778
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0082 - accuracy: 0.9970 - auc: 0.9924 - sensitivity_at_specificity: 0.9880 - specificity_at_sensitivity: 0.9997 - mean_io_u: 0.4967 - val_loss: 0.0090 - val_accuracy: 0.9969 - val_auc: 0.9758 - val_sensitivity_at_specificity: 0.9540 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 11/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9969 - auc: 0.9921 - sensitivity_at_specificity: 0.9874 - specificity_at_sensitivity: 0.9997 - mean_io_u: 0.4967
# Epoch 11: val_loss improved from 0.00778 to 0.00724, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0082 - accuracy: 0.9969 - auc: 0.9921 - sensitivity_at_specificity: 0.9874 - specificity_at_sensitivity: 0.9997 - mean_io_u: 0.4967 - val_loss: 0.0072 - val_accuracy: 0.9974 - val_auc: 0.9855 - val_sensitivity_at_specificity: 0.9727 - val_specificity_at_sensitivity: 0.9998 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 12/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9972 - auc: 0.9934 - sensitivity_at_specificity: 0.9893 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 12: val_loss did not improve from 0.00724
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0075 - accuracy: 0.9972 - auc: 0.9934 - sensitivity_at_specificity: 0.9893 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0086 - val_accuracy: 0.9971 - val_auc: 0.9773 - val_sensitivity_at_specificity: 0.9574 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 13/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9971 - auc: 0.9921 - sensitivity_at_specificity: 0.9871 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 13: val_loss did not improve from 0.00724
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0078 - accuracy: 0.9971 - auc: 0.9921 - sensitivity_at_specificity: 0.9871 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0103 - val_accuracy: 0.9966 - val_auc: 0.9676 - val_sensitivity_at_specificity: 0.9384 - val_specificity_at_sensitivity: 0.9996 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 14/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9971 - auc: 0.9922 - sensitivity_at_specificity: 0.9871 - specificity_at_sensitivity: 0.9997 - mean_io_u: 0.4967
# Epoch 14: val_loss did not improve from 0.00724
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0077 - accuracy: 0.9971 - auc: 0.9922 - sensitivity_at_specificity: 0.9871 - specificity_at_sensitivity: 0.9997 - mean_io_u: 0.4967 - val_loss: 0.0144 - val_accuracy: 0.9960 - val_auc: 0.9340 - val_sensitivity_at_specificity: 0.8739 - val_specificity_at_sensitivity: 0.9991 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 15/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9971 - auc: 0.9922 - sensitivity_at_specificity: 0.9871 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 15: val_loss did not improve from 0.00724
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0076 - accuracy: 0.9971 - auc: 0.9922 - sensitivity_at_specificity: 0.9871 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0108 - val_accuracy: 0.9962 - val_auc: 0.9952 - val_sensitivity_at_specificity: 0.9948 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 16/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9971 - auc: 0.9926 - sensitivity_at_specificity: 0.9879 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 16: val_loss did not improve from 0.00724
# 396/396 [==============================] - 59s 148ms/step - loss: 0.0076 - accuracy: 0.9971 - auc: 0.9926 - sensitivity_at_specificity: 0.9879 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0074 - val_accuracy: 0.9973 - val_auc: 0.9875 - val_sensitivity_at_specificity: 0.9774 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4969 - lr: 0.0010
# Epoch 17/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9973 - auc: 0.9948 - sensitivity_at_specificity: 0.9918 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 17: val_loss improved from 0.00724 to 0.00576, saving model to model-Unet.h5
# 396/396 [==============================] - 62s 157ms/step - loss: 0.0069 - accuracy: 0.9973 - auc: 0.9948 - sensitivity_at_specificity: 0.9918 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0058 - val_accuracy: 0.9977 - val_auc: 0.9961 - val_sensitivity_at_specificity: 0.9938 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-04
# Epoch 18/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9975 - auc: 0.9958 - sensitivity_at_specificity: 0.9935 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 18: val_loss did not improve from 0.00576
# 396/396 [==============================] - 58s 147ms/step - loss: 0.0063 - accuracy: 0.9975 - auc: 0.9958 - sensitivity_at_specificity: 0.9935 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0060 - val_accuracy: 0.9977 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9947 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-04
# Epoch 19/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9976 - auc: 0.9958 - sensitivity_at_specificity: 0.9934 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 19: val_loss did not improve from 0.00576
# 396/396 [==============================] - 59s 148ms/step - loss: 0.0062 - accuracy: 0.9976 - auc: 0.9958 - sensitivity_at_specificity: 0.9934 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0058 - val_accuracy: 0.9977 - val_auc: 0.9975 - val_sensitivity_at_specificity: 0.9966 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-04
# Epoch 20/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9976 - auc: 0.9965 - sensitivity_at_specificity: 0.9946 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 20: val_loss improved from 0.00576 to 0.00543, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0060 - accuracy: 0.9976 - auc: 0.9965 - sensitivity_at_specificity: 0.9946 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0054 - val_accuracy: 0.9978 - val_auc: 0.9968 - val_sensitivity_at_specificity: 0.9950 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-04
# Epoch 21/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9976 - auc: 0.9963 - sensitivity_at_specificity: 0.9942 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 21: val_loss improved from 0.00543 to 0.00528, saving model to model-Unet.h5
# 396/396 [==============================] - 59s 149ms/step - loss: 0.0059 - accuracy: 0.9976 - auc: 0.9963 - sensitivity_at_specificity: 0.9942 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0053 - val_accuracy: 0.9979 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9945 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-04
# Epoch 22/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9976 - auc: 0.9963 - sensitivity_at_specificity: 0.9941 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 22: val_loss did not improve from 0.00528
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0059 - accuracy: 0.9976 - auc: 0.9963 - sensitivity_at_specificity: 0.9941 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0053 - val_accuracy: 0.9979 - val_auc: 0.9970 - val_sensitivity_at_specificity: 0.9954 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-04
# Epoch 23/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9977 - auc: 0.9963 - sensitivity_at_specificity: 0.9942 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 23: val_loss improved from 0.00528 to 0.00526, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0058 - accuracy: 0.9977 - auc: 0.9963 - sensitivity_at_specificity: 0.9942 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0053 - val_accuracy: 0.9979 - val_auc: 0.9974 - val_sensitivity_at_specificity: 0.9961 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-04
# Epoch 24/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9977 - auc: 0.9964 - sensitivity_at_specificity: 0.9943 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 24: val_loss did not improve from 0.00526
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0058 - accuracy: 0.9977 - auc: 0.9964 - sensitivity_at_specificity: 0.9943 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0056 - val_accuracy: 0.9978 - val_auc: 0.9978 - val_sensitivity_at_specificity: 0.9969 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-04
# Epoch 25/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9977 - auc: 0.9966 - sensitivity_at_specificity: 0.9946 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 25: val_loss improved from 0.00526 to 0.00520, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0057 - accuracy: 0.9977 - auc: 0.9966 - sensitivity_at_specificity: 0.9946 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0052 - val_accuracy: 0.9979 - val_auc: 0.9958 - val_sensitivity_at_specificity: 0.9929 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-04
# Epoch 26/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9977 - auc: 0.9965 - sensitivity_at_specificity: 0.9945 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 26: val_loss did not improve from 0.00520
# 396/396 [==============================] - 58s 145ms/step - loss: 0.0057 - accuracy: 0.9977 - auc: 0.9965 - sensitivity_at_specificity: 0.9945 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0052 - val_accuracy: 0.9979 - val_auc: 0.9977 - val_sensitivity_at_specificity: 0.9967 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-04
# Epoch 27/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9978 - auc: 0.9967 - sensitivity_at_specificity: 0.9948 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 27: val_loss improved from 0.00520 to 0.00506, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 145ms/step - loss: 0.0055 - accuracy: 0.9978 - auc: 0.9967 - sensitivity_at_specificity: 0.9948 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0051 - val_accuracy: 0.9979 - val_auc: 0.9975 - val_sensitivity_at_specificity: 0.9962 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 28/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 28: val_loss improved from 0.00506 to 0.00503, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 145ms/step - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9979 - val_auc: 0.9973 - val_sensitivity_at_specificity: 0.9958 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 29/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9954 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 29: val_loss did not improve from 0.00503
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9954 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0051 - val_accuracy: 0.9979 - val_auc: 0.9978 - val_sensitivity_at_specificity: 0.9968 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 30/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9950 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 30: val_loss did not improve from 0.00503
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9950 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0051 - val_accuracy: 0.9979 - val_auc: 0.9976 - val_sensitivity_at_specificity: 0.9964 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 31/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9968 - sensitivity_at_specificity: 0.9950 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 31: val_loss improved from 0.00503 to 0.00502, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9968 - sensitivity_at_specificity: 0.9950 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9979 - val_auc: 0.9974 - val_sensitivity_at_specificity: 0.9959 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 32/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9968 - sensitivity_at_specificity: 0.9949 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 32: val_loss improved from 0.00502 to 0.00495, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9968 - sensitivity_at_specificity: 0.9949 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9980 - val_auc: 0.9969 - val_sensitivity_at_specificity: 0.9950 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 33/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 33: val_loss did not improve from 0.00495
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9979 - val_auc: 0.9974 - val_sensitivity_at_specificity: 0.9960 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 34/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9968 - sensitivity_at_specificity: 0.9950 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 34: val_loss improved from 0.00495 to 0.00495, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9968 - sensitivity_at_specificity: 0.9950 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9979 - val_auc: 0.9971 - val_sensitivity_at_specificity: 0.9954 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 35/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 35: val_loss did not improve from 0.00495
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9979 - val_auc: 0.9973 - val_sensitivity_at_specificity: 0.9957 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 36/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 36: val_loss did not improve from 0.00495
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9979 - val_auc: 0.9977 - val_sensitivity_at_specificity: 0.9965 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 37/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9950 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 37: val_loss did not improve from 0.00495
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9950 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9979 - val_auc: 0.9977 - val_sensitivity_at_specificity: 0.9967 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 38/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 38: val_loss improved from 0.00495 to 0.00494, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9975 - val_sensitivity_at_specificity: 0.9961 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 39/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 39: val_loss did not improve from 0.00494
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9979 - val_auc: 0.9975 - val_sensitivity_at_specificity: 0.9962 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 40/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 40: val_loss did not improve from 0.00494
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9979 - val_auc: 0.9976 - val_sensitivity_at_specificity: 0.9963 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 41/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9971 - sensitivity_at_specificity: 0.9956 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 41: val_loss did not improve from 0.00494
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9971 - sensitivity_at_specificity: 0.9956 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9980 - val_auc: 0.9978 - val_sensitivity_at_specificity: 0.9967 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 42/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 42: val_loss improved from 0.00494 to 0.00488, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9969 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9971 - val_sensitivity_at_specificity: 0.9954 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 43/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 43: val_loss did not improve from 0.00488
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9977 - val_sensitivity_at_specificity: 0.9965 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 44/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 44: val_loss improved from 0.00488 to 0.00487, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9974 - val_sensitivity_at_specificity: 0.9960 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 45/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9952 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 45: val_loss improved from 0.00487 to 0.00486, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9952 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9975 - val_sensitivity_at_specificity: 0.9962 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 46/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9954 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 46: val_loss improved from 0.00486 to 0.00485, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0053 - accuracy: 0.9978 - auc: 0.9970 - sensitivity_at_specificity: 0.9954 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9973 - val_sensitivity_at_specificity: 0.9957 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 47/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 47: val_loss improved from 0.00485 to 0.00484, saving model to model-Unet.h5
# 396/396 [==============================] - 58s 146ms/step - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0048 - val_accuracy: 0.9980 - val_auc: 0.9970 - val_sensitivity_at_specificity: 0.9952 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 48/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9971 - sensitivity_at_specificity: 0.9954 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 48: val_loss did not improve from 0.00484
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9971 - sensitivity_at_specificity: 0.9954 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9979 - val_auc: 0.9978 - val_sensitivity_at_specificity: 0.9968 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 49/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 49: val_loss did not improve from 0.00484
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9970 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9975 - val_sensitivity_at_specificity: 0.9961 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05
# Epoch 50/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9979 - auc: 0.9971 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 50: val_loss did not improve from 0.00484
# 396/396 [==============================] - 57s 145ms/step - loss: 0.0052 - accuracy: 0.9979 - auc: 0.9971 - sensitivity_at_specificity: 0.9953 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9974 - val_sensitivity_at_specificity: 0.9960 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4969 - lr: 1.0000e-05

# %%
df_result = pd.DataFrame(results.history)
df_result.sort_values('val_loss', ascending=True, inplace = True)
df_result
# Out:
#         loss  accuracy       auc  sensitivity_at_specificity  \
# 46  0.005265  0.997851  0.997017                    0.995286
# 45  0.005279  0.997845  0.997049                    0.995355
# 48  0.005258  0.997857  0.997029                    0.995306
# 44  0.005285  0.997845  0.996955                    0.995173
# 43  0.005261  0.997850  0.997030                    0.995312
# 41  0.005301  0.997838  0.996899                    0.995065
# 49  0.005209  0.997877  0.997055                    0.995335
# 42  0.005276  0.997852  0.997034                    0.995326
# 37  0.005338  0.997838  0.996903                    0.995094
# 33  0.005369  0.997813  0.996837                    0.994973
# 31  0.005398  0.997803  0.996802                    0.994917
# 40  0.005336  0.997823  0.997144                    0.995576
# 32  0.005389  0.997805  0.996983                    0.995277
# 38  0.005304  0.997837  0.997012                    0.995295
# 34  0.005383  0.997814  0.996906                    0.995123
# 39  0.005325  0.997828  0.997030                    0.995344
# 47  0.005253  0.997854  0.997053                    0.995353
# 30  0.005416  0.997802  0.996833                    0.994987
# 36  0.005346  0.997828  0.996856                    0.995002
# 35  0.005356  0.997824  0.996913                    0.995121
# 27  0.005441  0.997791  0.996975                    0.995292
# 26  0.005518  0.997768  0.996707                    0.994790
# 28  0.005411  0.997804  0.997016                    0.995358
# 29  0.005420  0.997798  0.996854                    0.995036
# 24  0.005741  0.997685  0.996565                    0.994627
# 25  0.005698  0.997710  0.996492                    0.994465
# 22  0.005825  0.997664  0.996340                    0.994221
# 20  0.005891  0.997638  0.996319                    0.994224
# 21  0.005885  0.997639  0.996276                    0.994125
# 19  0.005995  0.997593  0.996469                    0.994593
# 23  0.005786  0.997680  0.996406                    0.994334
# 16  0.006909  0.997328  0.994779                    0.991819
# 18  0.006156  0.997564  0.995849                    0.993438
# 17  0.006333  0.997485  0.995817                    0.993487
# 10  0.008188  0.996936  0.992102                    0.987413
# 15  0.007646  0.997107  0.992572                    0.987909
# 6   0.009330  0.996629  0.989707                    0.983693
# 7   0.009439  0.996654  0.988563                    0.981564
# 11  0.007473  0.997156  0.993362                    0.989324
# 9   0.008162  0.996961  0.992384                    0.987967
# 4   0.010948  0.996238  0.986157                    0.978628
# 12  0.007773  0.997092  0.992144                    0.987137
# 8   0.008774  0.996807  0.990633                    0.985008
# 14  0.007638  0.997126  0.992199                    0.987140
# 13  0.007732  0.997089  0.992170                    0.987149
# 2   0.013245  0.995578  0.981831                    0.973821
# 1   0.016893  0.994808  0.966201                    0.952038
# 3   0.011672  0.996018  0.984841                    0.977157
# 0   0.092116  0.983975  0.829454                    0.862295
# 5   0.009726  0.996580  0.987986                    0.980732
#
#     specificity_at_sensitivity  mean_io_u  val_loss  val_accuracy   val_auc  \
# 46                    0.999919   0.496679  0.004841      0.997998  0.997032
# 45                    0.999917   0.496679  0.004851      0.997994  0.997295
# 48                    0.999914   0.496679  0.004851      0.997994  0.997490
# 44                    0.999917   0.496679  0.004861      0.997995  0.997529
# 43                    0.999923   0.496679  0.004871      0.997983  0.997444
# 41                    0.999919   0.496679  0.004877      0.997987  0.997136
# 49                    0.999924   0.496679  0.004887      0.997980  0.997432
# 42                    0.999919   0.496679  0.004918      0.997966  0.997676
# 37                    0.999915   0.496679  0.004936      0.997963  0.997473
# 33                    0.999912   0.496679  0.004948      0.997950  0.997132
# 31                    0.999911   0.496679  0.004953      0.997964  0.996938
# 40                    0.999914   0.496679  0.004954      0.997953  0.997794
# 32                    0.999908   0.496679  0.004965      0.997948  0.997409
# 38                    0.999919   0.496679  0.004974      0.997946  0.997538
# 34                    0.999917   0.496679  0.004985      0.997949  0.997254
# 39                    0.999921   0.496679  0.004990      0.997932  0.997580
# 47                    0.999919   0.496679  0.004995      0.997936  0.997812
# 30                    0.999909   0.496679  0.005018      0.997922  0.997373
# 36                    0.999916   0.496679  0.005028      0.997930  0.997740
# 35                    0.999914   0.496679  0.005029      0.997935  0.997671
# 27                    0.999905   0.496679  0.005032      0.997923  0.997310
# 26                    0.999908   0.496679  0.005056      0.997919  0.997472
# 28                    0.999910   0.496679  0.005057      0.997925  0.997801
# 29                    0.999916   0.496679  0.005086      0.997902  0.997589
# 24                    0.999896   0.496679  0.005196      0.997894  0.995827
# 25                    0.999901   0.496679  0.005223      0.997867  0.997735
# 22                    0.999885   0.496679  0.005264      0.997871  0.997416
# 20                    0.999888   0.496679  0.005277      0.997862  0.996578
# 21                    0.999882   0.496679  0.005293      0.997862  0.997041
# 19                    0.999883   0.496679  0.005431      0.997809  0.996816
# 23                    0.999891   0.496679  0.005555      0.997759  0.997764
# 16                    0.999819   0.496679  0.005760      0.997717  0.996096
# 18                    0.999865   0.496679  0.005768      0.997730  0.997508
# 17                    0.999855   0.496679  0.005964      0.997661  0.996497
# 10                    0.999689   0.496679  0.007241      0.997375  0.985453
# 15                    0.999759   0.496679  0.007444      0.997287  0.987456
# 6                     0.999566   0.496679  0.007779      0.997198  0.989256
# 7                     0.999585   0.496679  0.008027      0.997227  0.993915
# 11                    0.999763   0.496679  0.008570      0.997104  0.977304
# 9                     0.999696   0.496679  0.009020      0.996922  0.975834
# 4                     0.999369   0.496679  0.009841      0.996694  0.989907
# 12                    0.999751   0.496679  0.010324      0.996609  0.967615
# 8                     0.999645   0.496679  0.010704      0.996235  0.988533
# 14                    0.999758   0.496679  0.010829      0.996198  0.995195
# 13                    0.999749   0.496679  0.014430      0.996026  0.933972
# 2                     0.998882   0.496679  0.014646      0.994890  0.990981
# 1                     0.997746   0.496679  0.016578      0.994955  0.955336
# 3                     0.999238   0.496679  0.018597      0.993709  0.960957
# 0                     0.914023   0.496817  0.025519      0.993649  0.937460
# 5                     0.999548   0.496679  0.050048      0.981744  0.991086
#
#     val_sensitivity_at_specificity  val_specificity_at_sensitivity  \
# 46                        0.995173                        0.999919
# 45                        0.995707                        0.999922
# 48                        0.996099                        0.999919
# 44                        0.996184                        0.999922
# 43                        0.996015                        0.999919
# 41                        0.995398                        0.999921
# 49                        0.995987                        0.999916
# 42                        0.996492                        0.999916
# 37                        0.996099                        0.999914
# 33                        0.995426                        0.999909
# 31                        0.995033                        0.999911
# 40                        0.996745                        0.999918
# 32                        0.995987                        0.999911
# 38                        0.996240                        0.999915
# 34                        0.995679                        0.999915
# 39                        0.996324                        0.999912
# 47                        0.996773                        0.999916
# 30                        0.995931                        0.999906
# 36                        0.996661                        0.999909
# 35                        0.996520                        0.999909
# 27                        0.995819                        0.999902
# 26                        0.996156                        0.999903
# 28                        0.996801                        0.999903
# 29                        0.996380                        0.999901
# 24                        0.992900                        0.999890
# 25                        0.996745                        0.999896
# 22                        0.996127                        0.999878
# 20                        0.994472                        0.999886
# 21                        0.995398                        0.999875
# 19                        0.995033                        0.999883
# 23                        0.996885                        0.999874
# 16                        0.993798                        0.999851
# 18                        0.996576                        0.999854
# 17                        0.994668                        0.999862
# 10                        0.972696                        0.999787
# 15                        0.977410                        0.999743
# 6                         0.981311                        0.999715
# 7                         0.991245                        0.999718
# 11                        0.957375                        0.999704
# 9                         0.953951                        0.999718
# 4                         0.985745                        0.999538
# 12                        0.938405                        0.999573
# 8                         0.981227                        0.999501
# 14                        0.994837                        0.999678
# 13                        0.873892                        0.999123
# 2                         0.991020                        0.998926
# 1                         0.930071                        0.997078
# 3                         0.941211                        0.997556
# 0                         0.943007                        0.990535
# 5                         0.995173                        0.998859
#
#     val_mean_io_u       lr
# 46        0.49691  0.00001
# 45        0.49691  0.00001
# 48        0.49691  0.00001
# 44        0.49691  0.00001
# 43        0.49691  0.00001
# 41        0.49691  0.00001
# 49        0.49691  0.00001
# 42        0.49691  0.00001
# 37        0.49691  0.00001
# 33        0.49691  0.00001
# 31        0.49691  0.00001
# 40        0.49691  0.00001
# 32        0.49691  0.00001
# 38        0.49691  0.00001
# 34        0.49691  0.00001
# 39        0.49691  0.00001
# 47        0.49691  0.00001
# 30        0.49691  0.00001
# 36        0.49691  0.00001
# 35        0.49691  0.00001
# 27        0.49691  0.00001
# 26        0.49691  0.00001
# 28        0.49691  0.00001
# 29        0.49691  0.00001
# 24        0.49691  0.00010
# 25        0.49691  0.00010
# 22        0.49691  0.00010
# 20        0.49691  0.00010
# 21        0.49691  0.00010
# 19        0.49691  0.00010
# 23        0.49691  0.00010
# 16        0.49691  0.00010
# 18        0.49691  0.00010
# 17        0.49691  0.00010
# 10        0.49691  0.00100
# 15        0.49691  0.00100
# 6         0.49691  0.00100
# 7         0.49691  0.00100
# 11        0.49691  0.00100
# 9         0.49691  0.00100
# 4         0.49691  0.00100
# 12        0.49691  0.00100
# 8         0.49691  0.00100
# 14        0.49691  0.00100
# 13        0.49691  0.00100
# 2         0.49691  0.00100
# 1         0.49691  0.00100
# 3         0.49691  0.00100
# 0         0.49691  0.00100
# 5         0.49691  0.00100

# %%
model.save("Recurrent_UNet.h5")

# %%
plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["accuracy"], label="Accuracy")
plt.plot(results.history["val_accuracy"], label="val_Accuracy")
plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %%
# Calculate metrics
predicted = model.predict(lung_test)

# Flatten the predicted and true masks
predicted_flat = np.round(predicted.flatten())
infect_test_flat = infect_test.flatten()

# %%
device = "CPU:0"

# %%
with tf.device(device):
    # Calculate metrics for training data
    train_predicted = model.predict(lung_train)

    # Flatten the predicted and true masks
    train_predicted_flat = np.round(train_predicted.flatten())
    infect_train_flat = infect_train.flatten()

    # Calculate precision and recall for training data
    train_precision = Precision()
    train_recall = Recall()
    train_precision.update_state(infect_train_flat, train_predicted_flat)
    train_recall.update_state(infect_train_flat, train_predicted_flat)

    # Calculate F1 score for training data
    train_f1_score = 2 * (train_precision.result() * train_recall.result()) / (train_precision.result() + train_recall.result())

    # Calculate accuracy for training data
    train_accuracy = np.mean(train_predicted_flat == infect_train_flat)

    # Calculate metrics for testing data
    test_predicted = model.predict(lung_test)

    # Flatten the predicted and true masks for testing data
    test_predicted_flat = np.round(test_predicted.flatten())
    infect_test_flat = infect_test.flatten()

    # Calculate precision and recall for testing data
    test_precision = Precision()
    test_recall = Recall()
    test_precision.update_state(infect_test_flat, test_predicted_flat)
    test_recall.update_state(infect_test_flat, test_predicted_flat)

    # Calculate F1 score for testing data
    test_f1_score = 2 * (test_precision.result() * test_recall.result()) / (test_precision.result() + test_recall.result())

    # Calculate accuracy for testing data
    test_accuracy = np.mean(test_predicted_flat == infect_test_flat)

    # Calculate parameters
    total_parameters = np.sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])

    # Calculate FLOPs
    flops = get_flops(model, batch_size=1)  # Assuming batch_size = 1

    # Print the metrics for training data
    print("Training Metrics:")
    print("Precision: ", train_precision.result().numpy())
    print("Recall: ", train_recall.result().numpy())
    print("F1 Score: ", train_f1_score.numpy())
    print("Accuracy: ", train_accuracy)

    # Print the metrics for testing data
    print("\nTesting Metrics:")
    print("Precision: ", test_precision.result().numpy())
    print("Recall: ", test_recall.result().numpy())
    print("F1 Score: ", test_f1_score.numpy())
    print("Accuracy: ", test_accuracy)

    # Print the other metrics
    print("\nTotal Parameters: ", total_parameters)
    print("FLOPs: ", flops)
# Out:
# WARNING:tensorflow:From c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\ops\nn_ops.py:5214: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# Training Metrics:
# Precision:  0.8487551
# Recall:  0.84526616
# F1 Score:  0.8470071
# Accuracy:  0.9979720645480685
#
# Testing Metrics:
# Precision:  0.832497
# Recall:  0.8426591
# F1 Score:  0.83754724
# Accuracy:  0.9979801177978516
#
# Total Parameters:  5325827
# FLOPs:  3611152832

# %%
with tf.device("CPU"):
    # Calculate Jaccard Index (MeanIoU) for training data
    train_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    train_iou.update_state(infect_train_flat, train_predicted_flat)
    train_mean_iou = train_iou.result().numpy()

    # Calculate Jaccard Index (MeanIoU) for testing data
    test_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    test_iou.update_state(infect_test_flat, test_predicted_flat)
    test_mean_iou = test_iou.result().numpy()

    # Print the Jaccard Index (MeanIoU) for training and testing data
    print("Training Jaccard Index (MeanIoU): ", train_mean_iou)
    print("Testing Jaccard Index (MeanIoU): ", test_mean_iou)
# Out:
# Training Jaccard Index (MeanIoU):  0.8641907
# Testing Jaccard Index (MeanIoU):  0.8592348

# %%
# Plot accuracy
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
# Make predictions
predicted = model.predict(lung_test)

# %%
with tf.device(device):
    # Make predictions and visualize
    img_num = 8
    predicted = model.predict(lung_test)

    # Visualize results
    fig = plt.figure(figsize=(18, 15))
    plt.subplot(1, 3, 1)
    plt.imshow(lung_test[img_num], cmap='bone')
    plt.title('Original lung')

    plt.subplot(1, 3, 2)
    plt.imshow(lung_test[img_num], cmap='bone')
    plt.imshow(infect_test[img_num][..., 0], alpha=0.5, cmap="nipy_spectral")
    plt.title('Original infection mask')

    plt.subplot(1, 3, 3)
    plt.imshow(lung_test[img_num], cmap='bone')
    plt.imshow(predicted[img_num], alpha=0.5, cmap="nipy_spectral")
    plt.title('Predicted infection mask')

# %%
# Plot Jaccard Index (MeanIoU)
plt.plot(results.history['mean_io_u'])
plt.plot(results.history['val_mean_io_u'])
plt.title('MeanIoU (Jaccard Index) vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('MeanIoU (Jaccard Index)')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
