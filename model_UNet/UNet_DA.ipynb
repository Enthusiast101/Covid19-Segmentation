# %%
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras.metrics import Precision, Recall
from keras_flops import get_flops

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, Input, MaxPooling2D, Dropout, concatenate, UpSampling2D, BatchNormalization, Activation, Conv2DTranspose
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import gc

# %%
# Read and examine metadata
#raw_data = pd.read_csv(r"D:\NITK\COVID-19 Lung CT Scan Segmentation\COVID-19 Lung CT Scan Segmentation\metadata.csv")
raw_data = pd.read_csv(r'../COVID-19 Lung CT Scan Segmentation/COVID-19 Lung CT Scan Segmentation/metadata_temp.csv')
raw_data.sample(5)
# Out:
#                                               ct_scan  \
# 0   C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 8   C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...
# 4   C:\Application\Programming\Research\Lung_Segme...
#
#                                             lung_mask  \
# 0   C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 8   C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...
# 4   C:\Application\Programming\Research\Lung_Segme...
#
#                                        infection_mask  \
# 0   C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 8   C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...
# 4   C:\Application\Programming\Research\Lung_Segme...
#
#                               lung_and_infection_mask
# 0   C:\Application\Programming\Research\Lung_Segme...
# 10  C:\Application\Programming\Research\Lung_Segme...
# 8   C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...
# 4   C:\Application\Programming\Research\Lung_Segme...

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
# Read sample
sample_ct   = read_nii(raw_data.loc[1,'ct_scan'])
sample_lung = read_nii(raw_data.loc[1,'lung_mask'])
sample_infe = read_nii(raw_data.loc[1,'infection_mask'])
sample_all  = read_nii(raw_data.loc[1,'lung_and_infection_mask'])

# Examine Shape
sample_ct.shape
# Out:
# (512, 512, 200)

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %%
IMG_SIZE = 128
IMG_HEIGHT = IMG_SIZE
IMG_WIDTH = IMG_SIZE
IMG_CHANNELS = 1

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

def get_data():
    lungs_data = []
    infections_data  = []

    for row in range(len(raw_data)):
        lungs_image = read_nii(raw_data['ct_scan'][row])
        infection_image = read_nii(raw_data['infection_mask'][row])

        for slice_no in range(lungs_image.shape[2]):
            lung_slice = cv2.resize(lungs_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA)
            infection_slice = cv2.resize(infection_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')

            lung_slice_temp = lung_slice.reshape(-1, 2)
            lung_slice_temp = scaler.fit_transform(lung_slice_temp)
            lung_slice = lung_slice_temp.reshape(lung_slice.shape)
            lungs_data.append(lung_slice[..., np.newaxis])

            infections_data.append(infection_slice[..., np.newaxis])
    return lungs_data, infections_data

# %%
data = get_data()
lungs = np.array(data[0])
infections = np.array(data[1])

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,2,1)
plt.imshow(lungs[451], cmap = 'bone')
plt.title('Transformed Image')

plt.subplot(1,2,2)
plt.imshow(lungs[451], cmap = 'bone')
plt.imshow(infections[451],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Transformed Infection Mask')
# Out:
# Text(0.5, 1.0, 'Transformed Infection Mask')

# %%
# Split the data into train and test sets
lung_train, lung_test, infect_train, infect_test = train_test_split(lungs, infections, test_size=0.1, shuffle=True)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
"""Modified"""
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, RandomContrast, RandomCrop, GaussianNoise

# %%
def Unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Augmentation
    aug = RandomRotation(10)(input_img)
    aug = RandomZoom(0.1)(aug)
    aug = RandomContrast(0.1)(aug)
    aug = GaussianNoise(10)(aug)
    input_img = aug  

    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
import tensorflow.keras.backend as K

def jaccard_loss(y_true, y_pred, smooth=1e-7):
    y_true = K.cast(y_true, dtype='float32')  # Cast y_true to float32
    intersection = K.sum(y_true * y_pred, axis=(1, 2, 3))
    union = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3)) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    return 1 - jaccard

# %%
from keras import backend as K
K.clear_session()

# Define the UNET model with TensorFlow's MeanIoU metric
input_img = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), name='img')
model = Unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
metrics = ["accuracy", 
           tf.keras.metrics.AUC(), 
           tf.keras.metrics.SensitivityAtSpecificity(0.5), 
           tf.keras.metrics.SpecificityAtSensitivity(0.5),
           tf.keras.metrics.MeanIoU(num_classes=2)]  # Use MeanIoU as the Jaccard Index metric
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=metrics)  # Use custom Jaccard loss

gc.collect()
# Out:
# 918

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 16  160         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 16  64         ['conv2d[1][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 16  0           ['batch_normalization[1][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  2320        ['activation[1][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 16  64         ['conv2d_1[1][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_1[1][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['activation_1[1][0]']
#
#  dropout (Dropout)              (None, 64, 64, 16)   0           ['max_pooling2d[1][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   4640        ['dropout[1][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_2[1][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_2[1][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   9248        ['activation_2[1][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_3[1][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_3[1][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['activation_3[1][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 32)   0           ['max_pooling2d_1[1][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   18496       ['dropout_1[1][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_4[1][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_4[1][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   36928       ['activation_4[1][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_5[1][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_5[1][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['activation_5[1][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 64)   0           ['max_pooling2d_2[1][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 128)  73856       ['dropout_2[1][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_6[1][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 128)  0           ['batch_normalization_6[1][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 128)  147584      ['activation_6[1][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_7[1][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 16, 16, 128)  0           ['batch_normalization_7[1][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['activation_7[1][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 128)    0           ['max_pooling2d_3[1][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    295168      ['dropout_3[1][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_8[1][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 8, 8, 256)    0           ['batch_normalization_8[1][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['activation_8[1][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_9[1][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 8, 8, 256)    0           ['batch_normalization_9[1][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  295040     ['activation_9[1][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[1][0]',
#                                                                   'activation_7[1][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 256)  0           ['concatenate[1][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  295040      ['dropout_4[1][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 128)  512        ['conv2d_10[1][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_10[1][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_10[1][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 128)  512        ['conv2d_11[1][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_11[1][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  73792       ['activation_11[1][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[1][0]',
#                                                                   'activation_5[1][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['concatenate_1[1][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_5[1][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['conv2d_12[1][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_12[1][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_12[1][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 64)  256         ['conv2d_13[1][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_13[1][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  18464       ['activation_13[1][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[1][0]',
#                                                                   'activation_3[1][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 64)   0           ['concatenate_2[1][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_6[1][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 32)  128         ['conv2d_14[1][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_14[1][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_14[1][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 32)  128         ['conv2d_15[1][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_15[1][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  4624       ['activation_15[1][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[1][0]',
#                                 )                                 'activation_1[1][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['concatenate_3[1][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 16  4624        ['dropout_7[1][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 16  64         ['conv2d_16[1][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_16[1][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 16  2320        ['activation_16[1][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 16  64         ['conv2d_17[1][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_17[1][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  17          ['activation_17[1][0]']
#
# ==================================================================================================
# Total params: 2,164,305
# Trainable params: 2,161,361
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
# Define callbacks
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-Unet.h5', verbose=1, save_best_only=True, save_weights_only=True),
]

# %%
results = model.fit(lung_train, infect_train, batch_size=8, epochs=50, callbacks=callbacks, validation_data=(lung_test, infect_test), use_multiprocessing=True)
# Out:
# Epoch 1/50
# 396/396 [==============================] - ETA: 0s - loss: 0.1852 - accuracy: 0.9817 - auc: 0.5469 - sensitivity_at_specificity: 0.5212 - specificity_at_sensitivity: 0.5134 - mean_io_u: 0.4967
# Epoch 1: val_loss improved from inf to 0.06351, saving model to model-Unet.h5
# 396/396 [==============================] - 34s 62ms/step - loss: 0.1852 - accuracy: 0.9817 - auc: 0.5469 - sensitivity_at_specificity: 0.5212 - specificity_at_sensitivity: 0.5134 - mean_io_u: 0.4967 - val_loss: 0.0635 - val_accuracy: 0.9935 - val_auc: 0.8686 - val_sensitivity_at_specificity: 0.9345 - val_specificity_at_sensitivity: 0.9889 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 2/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9934 - auc: 0.9155 - sensitivity_at_specificity: 0.9169 - specificity_at_sensitivity: 0.9915 - mean_io_u: 0.4967
# Epoch 2: val_loss improved from 0.06351 to 0.02763, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 62ms/step - loss: 0.0451 - accuracy: 0.9934 - auc: 0.9155 - sensitivity_at_specificity: 0.9169 - specificity_at_sensitivity: 0.9915 - mean_io_u: 0.4967 - val_loss: 0.0276 - val_accuracy: 0.9936 - val_auc: 0.9514 - val_sensitivity_at_specificity: 0.9450 - val_specificity_at_sensitivity: 0.9981 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 3/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9943 - auc: 0.9731 - sensitivity_at_specificity: 0.9822 - specificity_at_sensitivity: 0.9980 - mean_io_u: 0.4967
# Epoch 3: val_loss did not improve from 0.02763
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0236 - accuracy: 0.9943 - auc: 0.9731 - sensitivity_at_specificity: 0.9822 - specificity_at_sensitivity: 0.9980 - mean_io_u: 0.4967 - val_loss: 0.0372 - val_accuracy: 0.9935 - val_auc: 0.7125 - val_sensitivity_at_specificity: 0.6105 - val_specificity_at_sensitivity: 0.9001 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 4/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9959 - auc: 0.9848 - sensitivity_at_specificity: 0.9907 - specificity_at_sensitivity: 0.9991 - mean_io_u: 0.4967
# Epoch 4: val_loss improved from 0.02763 to 0.01200, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0160 - accuracy: 0.9959 - auc: 0.9848 - sensitivity_at_specificity: 0.9907 - specificity_at_sensitivity: 0.9991 - mean_io_u: 0.4967 - val_loss: 0.0120 - val_accuracy: 0.9966 - val_auc: 0.9878 - val_sensitivity_at_specificity: 0.9867 - val_specificity_at_sensitivity: 0.9995 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 5/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9963 - auc: 0.9893 - sensitivity_at_specificity: 0.9863 - specificity_at_sensitivity: 0.9994 - mean_io_u: 0.4967
# Epoch 5: val_loss improved from 0.01200 to 0.00951, saving model to model-Unet.h5
# 396/396 [==============================] - 27s 68ms/step - loss: 0.0125 - accuracy: 0.9963 - auc: 0.9893 - sensitivity_at_specificity: 0.9863 - specificity_at_sensitivity: 0.9994 - mean_io_u: 0.4967 - val_loss: 0.0095 - val_accuracy: 0.9970 - val_auc: 0.9938 - val_sensitivity_at_specificity: 0.9908 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 6/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9967 - auc: 0.9919 - sensitivity_at_specificity: 0.9881 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967
# Epoch 6: val_loss did not improve from 0.00951
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0103 - accuracy: 0.9967 - auc: 0.9919 - sensitivity_at_specificity: 0.9881 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967 - val_loss: 0.0098 - val_accuracy: 0.9966 - val_auc: 0.9911 - val_sensitivity_at_specificity: 0.9864 - val_specificity_at_sensitivity: 0.9996 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 7/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9970 - auc: 0.9928 - sensitivity_at_specificity: 0.9889 - specificity_at_sensitivity: 0.9997 - mean_io_u: 0.4967
# Epoch 7: val_loss improved from 0.00951 to 0.00793, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 66ms/step - loss: 0.0090 - accuracy: 0.9970 - auc: 0.9928 - sensitivity_at_specificity: 0.9889 - specificity_at_sensitivity: 0.9997 - mean_io_u: 0.4967 - val_loss: 0.0079 - val_accuracy: 0.9972 - val_auc: 0.9911 - val_sensitivity_at_specificity: 0.9843 - val_specificity_at_sensitivity: 0.9998 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 8/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9972 - auc: 0.9941 - sensitivity_at_specificity: 0.9906 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 8: val_loss improved from 0.00793 to 0.00743, saving model to model-Unet.h5
# 396/396 [==============================] - 27s 68ms/step - loss: 0.0079 - accuracy: 0.9972 - auc: 0.9941 - sensitivity_at_specificity: 0.9906 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0074 - val_accuracy: 0.9973 - val_auc: 0.9958 - val_sensitivity_at_specificity: 0.9939 - val_specificity_at_sensitivity: 0.9998 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 9/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9973 - auc: 0.9943 - sensitivity_at_specificity: 0.9908 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 9: val_loss improved from 0.00743 to 0.00677, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 64ms/step - loss: 0.0074 - accuracy: 0.9973 - auc: 0.9943 - sensitivity_at_specificity: 0.9908 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0068 - val_accuracy: 0.9975 - val_auc: 0.9944 - val_sensitivity_at_specificity: 0.9907 - val_specificity_at_sensitivity: 0.9998 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 10/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9975 - auc: 0.9946 - sensitivity_at_specificity: 0.9912 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 10: val_loss improved from 0.00677 to 0.00631, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0068 - accuracy: 0.9975 - auc: 0.9946 - sensitivity_at_specificity: 0.9912 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0063 - val_accuracy: 0.9977 - val_auc: 0.9912 - val_sensitivity_at_specificity: 0.9839 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 11/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9974 - auc: 0.9940 - sensitivity_at_specificity: 0.9901 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 11: val_loss improved from 0.00631 to 0.00599, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0070 - accuracy: 0.9974 - auc: 0.9940 - sensitivity_at_specificity: 0.9901 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0060 - val_accuracy: 0.9976 - val_auc: 0.9950 - val_sensitivity_at_specificity: 0.9914 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 12/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9976 - auc: 0.9955 - sensitivity_at_specificity: 0.9927 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 12: val_loss improved from 0.00599 to 0.00566, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0063 - accuracy: 0.9976 - auc: 0.9955 - sensitivity_at_specificity: 0.9927 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0057 - val_accuracy: 0.9978 - val_auc: 0.9962 - val_sensitivity_at_specificity: 0.9938 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 13/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9977 - auc: 0.9957 - sensitivity_at_specificity: 0.9930 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 13: val_loss did not improve from 0.00566
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0060 - accuracy: 0.9977 - auc: 0.9957 - sensitivity_at_specificity: 0.9930 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0058 - val_accuracy: 0.9977 - val_auc: 0.9957 - val_sensitivity_at_specificity: 0.9930 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 14/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9977 - auc: 0.9960 - sensitivity_at_specificity: 0.9934 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 14: val_loss improved from 0.00566 to 0.00519, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0058 - accuracy: 0.9977 - auc: 0.9960 - sensitivity_at_specificity: 0.9934 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0052 - val_accuracy: 0.9979 - val_auc: 0.9975 - val_sensitivity_at_specificity: 0.9962 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 15/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9978 - auc: 0.9964 - sensitivity_at_specificity: 0.9941 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 15: val_loss did not improve from 0.00519
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0056 - accuracy: 0.9978 - auc: 0.9964 - sensitivity_at_specificity: 0.9941 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0053 - val_accuracy: 0.9978 - val_auc: 0.9976 - val_sensitivity_at_specificity: 0.9965 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 16/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9966 - sensitivity_at_specificity: 0.9945 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 16: val_loss improved from 0.00519 to 0.00500, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0053 - accuracy: 0.9979 - auc: 0.9966 - sensitivity_at_specificity: 0.9945 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9980 - val_auc: 0.9969 - val_sensitivity_at_specificity: 0.9948 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 17/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9963 - sensitivity_at_specificity: 0.9939 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 17: val_loss improved from 0.00500 to 0.00500, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9963 - sensitivity_at_specificity: 0.9939 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9979 - val_auc: 0.9977 - val_sensitivity_at_specificity: 0.9965 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 18/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9979 - auc: 0.9967 - sensitivity_at_specificity: 0.9946 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 18: val_loss improved from 0.00500 to 0.00489, saving model to model-Unet.h5
# 396/396 [==============================] - 28s 71ms/step - loss: 0.0052 - accuracy: 0.9979 - auc: 0.9967 - sensitivity_at_specificity: 0.9946 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9964 - val_sensitivity_at_specificity: 0.9938 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 19/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9980 - auc: 0.9970 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 19: val_loss did not improve from 0.00489
# 396/396 [==============================] - 26s 66ms/step - loss: 0.0050 - accuracy: 0.9980 - auc: 0.9970 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0053 - val_accuracy: 0.9979 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9945 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 20/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9980 - auc: 0.9972 - sensitivity_at_specificity: 0.9954 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 20: val_loss improved from 0.00489 to 0.00482, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 66ms/step - loss: 0.0049 - accuracy: 0.9980 - auc: 0.9972 - sensitivity_at_specificity: 0.9954 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0048 - val_accuracy: 0.9980 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9940 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 21/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9980 - auc: 0.9972 - sensitivity_at_specificity: 0.9954 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 21: val_loss did not improve from 0.00482
# 396/396 [==============================] - 27s 67ms/step - loss: 0.0049 - accuracy: 0.9980 - auc: 0.9972 - sensitivity_at_specificity: 0.9954 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9953 - val_sensitivity_at_specificity: 0.9915 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 22/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9981 - auc: 0.9974 - sensitivity_at_specificity: 0.9958 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 22: val_loss did not improve from 0.00482
# 396/396 [==============================] - 26s 67ms/step - loss: 0.0047 - accuracy: 0.9981 - auc: 0.9974 - sensitivity_at_specificity: 0.9958 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9952 - val_sensitivity_at_specificity: 0.9915 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 23/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9981 - auc: 0.9975 - sensitivity_at_specificity: 0.9959 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 23: val_loss did not improve from 0.00482
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0046 - accuracy: 0.9981 - auc: 0.9975 - sensitivity_at_specificity: 0.9959 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0051 - val_accuracy: 0.9979 - val_auc: 0.9969 - val_sensitivity_at_specificity: 0.9949 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4968 - lr: 0.0010
# Epoch 24/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9983 - auc: 0.9983 - sensitivity_at_specificity: 0.9974 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 24: val_loss improved from 0.00482 to 0.00436, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0041 - accuracy: 0.9983 - auc: 0.9983 - sensitivity_at_specificity: 0.9974 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0044 - val_accuracy: 0.9982 - val_auc: 0.9964 - val_sensitivity_at_specificity: 0.9937 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-04
# Epoch 25/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9984 - auc: 0.9983 - sensitivity_at_specificity: 0.9973 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 25: val_loss improved from 0.00436 to 0.00434, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0040 - accuracy: 0.9984 - auc: 0.9983 - sensitivity_at_specificity: 0.9973 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9964 - val_sensitivity_at_specificity: 0.9936 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-04
# Epoch 26/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9984 - auc: 0.9985 - sensitivity_at_specificity: 0.9976 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 26: val_loss improved from 0.00434 to 0.00430, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0039 - accuracy: 0.9984 - auc: 0.9985 - sensitivity_at_specificity: 0.9976 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9970 - val_sensitivity_at_specificity: 0.9949 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-04
# Epoch 27/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9984 - auc: 0.9984 - sensitivity_at_specificity: 0.9975 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 27: val_loss improved from 0.00430 to 0.00430, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0039 - accuracy: 0.9984 - auc: 0.9984 - sensitivity_at_specificity: 0.9975 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9940 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-04
# Epoch 28/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9984 - auc: 0.9985 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 28: val_loss did not improve from 0.00430
# 396/396 [==============================] - 26s 64ms/step - loss: 0.0038 - accuracy: 0.9984 - auc: 0.9985 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9969 - val_sensitivity_at_specificity: 0.9946 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-04
# Epoch 29/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9984 - auc: 0.9985 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 29: val_loss improved from 0.00430 to 0.00429, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0038 - accuracy: 0.9984 - auc: 0.9985 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9937 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-04
# Epoch 30/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9984 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 30: val_loss improved from 0.00429 to 0.00427, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9984 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9968 - val_sensitivity_at_specificity: 0.9944 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 31/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 31: val_loss did not improve from 0.00427
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9967 - val_sensitivity_at_specificity: 0.9942 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 32/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9984 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 32: val_loss improved from 0.00427 to 0.00427, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9984 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9940 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 33/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9984 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 33: val_loss did not improve from 0.00427
# 396/396 [==============================] - 26s 64ms/step - loss: 0.0037 - accuracy: 0.9984 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9967 - val_sensitivity_at_specificity: 0.9942 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 34/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 34: val_loss did not improve from 0.00427
# 396/396 [==============================] - 28s 71ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9964 - val_sensitivity_at_specificity: 0.9936 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 35/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 35: val_loss did not improve from 0.00427
# 396/396 [==============================] - 27s 68ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9938 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 36/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 36: val_loss did not improve from 0.00427
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9938 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 37/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 37: val_loss did not improve from 0.00427
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9940 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 38/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 38: val_loss did not improve from 0.00427
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9938 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 39/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9985 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 39: val_loss improved from 0.00427 to 0.00427, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9985 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9940 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 40/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9987 - sensitivity_at_specificity: 0.9980 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 40: val_loss did not improve from 0.00427
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9987 - sensitivity_at_specificity: 0.9980 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9939 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 41/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 41: val_loss improved from 0.00427 to 0.00426, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9940 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 42/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 42: val_loss improved from 0.00426 to 0.00425, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9967 - val_sensitivity_at_specificity: 0.9943 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 43/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9987 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 43: val_loss did not improve from 0.00425
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9987 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9939 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 44/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 44: val_loss did not improve from 0.00425
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9967 - val_sensitivity_at_specificity: 0.9943 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 45/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9987 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 45: val_loss did not improve from 0.00425
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9987 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9939 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 46/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9987 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 46: val_loss improved from 0.00425 to 0.00425, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9987 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9940 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 47/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 47: val_loss did not improve from 0.00425
# 396/396 [==============================] - 26s 64ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9938 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 48/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9987 - sensitivity_at_specificity: 0.9980 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 48: val_loss improved from 0.00425 to 0.00425, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9987 - sensitivity_at_specificity: 0.9980 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9964 - val_sensitivity_at_specificity: 0.9937 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 49/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 49: val_loss did not improve from 0.00425
# 396/396 [==============================] - 26s 66ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9940 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05
# Epoch 50/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 50: val_loss did not improve from 0.00425
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9986 - sensitivity_at_specificity: 0.9978 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9939 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4968 - lr: 1.0000e-05

# %%
df_result = pd.DataFrame(results.history)
df_result.sort_values('val_loss', ascending=True, inplace = True)
df_result
# Out:
#         loss  accuracy       auc  sensitivity_at_specificity  \
# 47  0.003651  0.998475  0.998676                    0.997956
# 45  0.003660  0.998468  0.998651                    0.997909
# 41  0.003674  0.998472  0.998604                    0.997819
# 48  0.003662  0.998472  0.998635                    0.997877
# 46  0.003664  0.998471  0.998610                    0.997828
# 42  0.003678  0.998464  0.998658                    0.997929
# 21                        0.991450                        0.999938
# 16                        0.996483                        0.999923
# 15                        0.994832                        0.999916
# 22                        0.994859                        0.999949
# 13                        0.996212                        0.999918
# 14                        0.996456                        0.999912
# 18                        0.994480                        0.999925
# 11                        0.993804                        0.999920
# 12                        0.992992                        0.999902
# 10                        0.991423                        0.999864
# 9                         0.983929                        0.999896
# 8                         0.990720                        0.999841
# 7                         0.993858                        0.999786
# 6                         0.984307                        0.999775
# 4                         0.990774                        0.999694
# 5                         0.986445                        0.999646
# 3                         0.986715                        0.999521
# 1                         0.944995                        0.998093
# 2                         0.610471                        0.900126
# 0                         0.934470                        0.988896
#
#     val_mean_io_u       lr
# 47       0.496796  0.00001
# 45       0.496796  0.00001
# 41       0.496796  0.00001
# 48       0.496796  0.00001
# 46       0.496796  0.00001
# 42       0.496796  0.00001
# 49       0.496796  0.00001
# 40       0.496796  0.00001
# 44       0.496796  0.00001
# 43       0.496796  0.00001
# 38       0.496796  0.00001
# 39       0.496796  0.00001
# 31       0.496796  0.00001
# 37       0.496796  0.00001
# 29       0.496796  0.00001
# 36       0.496796  0.00001
# 30       0.496796  0.00001
# 34       0.496796  0.00001
# 32       0.496796  0.00001
# 35       0.496796  0.00001
# 33       0.496796  0.00001
# 28       0.496796  0.00010
# 26       0.496796  0.00010
# 25       0.496796  0.00010
# 27       0.496796  0.00010
# 24       0.496796  0.00010
# 23       0.496796  0.00010
# 19       0.496796  0.00100
# 17       0.496796  0.00100
# 20       0.496796  0.00100
# 21       0.496796  0.00100
# 16       0.496796  0.00100
# 15       0.496796  0.00100
# 22       0.496796  0.00100
# 13       0.496796  0.00100
# 14       0.496796  0.00100
# 18       0.496796  0.00100
# 11       0.496796  0.00100
# 12       0.496796  0.00100
# 10       0.496796  0.00100
# 9        0.496796  0.00100
# 8        0.496796  0.00100
# 7        0.496796  0.00100
# 6        0.496796  0.00100
# 4        0.496796  0.00100
# 5        0.496796  0.00100
# 3        0.496796  0.00100
# 1        0.496796  0.00100
# 2        0.496796  0.00100
# 0        0.496796  0.00100

# %%
plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["accuracy"], label="Accuracy")
plt.plot(results.history["val_accuracy"], label="val_Accuracy")
plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %%
model.save("UNet.h5")

# %%
# Calculate metrics
predicted = model.predict(lung_test)

# Flatten the predicted and true masks
predicted_flat = np.round(predicted.flatten())
infect_test_flat = infect_test.flatten()

# %%
# Calculate metrics for training data
train_predicted = model.predict(lung_train)

# Flatten the predicted and true masks
train_predicted_flat = np.round(train_predicted.flatten())
infect_train_flat = infect_train.flatten()

# Calculate precision and recall for training data
train_precision = Precision()
train_recall = Recall()
train_precision.update_state(infect_train_flat, train_predicted_flat)
train_recall.update_state(infect_train_flat, train_predicted_flat)

# Calculate F1 score for training data
train_f1_score = 2 * (train_precision.result() * train_recall.result()) / (train_precision.result() + train_recall.result())

# Calculate accuracy for training data
train_accuracy = np.mean(train_predicted_flat == infect_train_flat)

# Calculate metrics for testing data
test_predicted = model.predict(lung_test)

# Flatten the predicted and true masks for testing data
test_predicted_flat = np.round(test_predicted.flatten())
infect_test_flat = infect_test.flatten()

# Calculate precision and recall for testing data
test_precision = Precision()
test_recall = Recall()
test_precision.update_state(infect_test_flat, test_predicted_flat)
test_recall.update_state(infect_test_flat, test_predicted_flat)

# Calculate F1 score for testing data
test_f1_score = 2 * (test_precision.result() * test_recall.result()) / (test_precision.result() + test_recall.result())

# Calculate accuracy for testing data
test_accuracy = np.mean(test_predicted_flat == infect_test_flat)

# Calculate parameters
total_parameters = np.sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])

# Calculate FLOPs
flops = get_flops(model, batch_size=1)  # Assuming batch_size = 1

# Print the metrics for training data
print("Training Metrics:")
print("Precision: ", train_precision.result().numpy())
print("Recall: ", train_recall.result().numpy())
print("F1 Score: ", train_f1_score.numpy())
print("Accuracy: ", train_accuracy)

# Print the metrics for testing data
print("\nTesting Metrics:")
print("Precision: ", test_precision.result().numpy())
print("Recall: ", test_recall.result().numpy())
print("F1 Score: ", test_f1_score.numpy())
print("Accuracy: ", test_accuracy)

# Print the other metrics
print("\nTotal Parameters: ", total_parameters)
print("FLOPs: ", flops)
# Out:
# WARNING:tensorflow:From c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\ops\nn_ops.py:5214: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# Training Metrics:
# Precision:  0.8909276
# Recall:  0.8902686
# F1 Score:  0.890598
# Accuracy:  0.9985529967028686
#
# Testing Metrics:
# Precision:  0.868452
# Recall:  0.8580898
# F1 Score:  0.8632398
# Accuracy:  0.9982575503262606
#
# Total Parameters:  2161361
# FLOPs:  1597694592

# %%
device = "CPU:0"

# %%
with tf.device(device):
    # Calculate Jaccard Index (MeanIoU) for training data
    train_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    train_iou.update_state(infect_train_flat, train_predicted_flat)
    train_mean_iou = train_iou.result().numpy()

    # Calculate Jaccard Index (MeanIoU) for testing data
    test_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    test_iou.update_state(infect_test_flat, test_predicted_flat)
    test_mean_iou = test_iou.result().numpy()

    # Print the Jaccard Index (MeanIoU) for training and testing data
    print("Training Jaccard Index (MeanIoU): ", train_mean_iou)
    print("Testing Jaccard Index (MeanIoU): ", test_mean_iou)
# Out:
# Training Jaccard Index (MeanIoU):  0.89915824
# Testing Jaccard Index (MeanIoU):  0.87881696

# %%
# Plot accuracy
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
with tf.device(device):
    # Make predictions
    predicted = model.predict(lung_test)

# %%
# Make predictions and visualize
img_num = 3
predicted = model.predict(lung_test)

# Visualize results
fig = plt.figure(figsize=(18, 15))
plt.subplot(1, 3, 1)
plt.imshow(lung_test[img_num], cmap='bone')
plt.title('Original lung')

plt.subplot(1, 3, 2)
plt.imshow(lung_test[img_num], cmap='bone')
plt.imshow(infect_test[img_num][..., 0], alpha=0.5, cmap="nipy_spectral")
plt.title('Original infection mask')

plt.subplot(1, 3, 3)
plt.imshow(lung_test[img_num], cmap='bone')
plt.imshow(predicted[img_num], alpha=0.5, cmap="nipy_spectral")
plt.title('Predicted infection mask')
# Out:
# Text(0.5, 1.0, 'Predicted infection mask')

# %%
# Plot Jaccard Index (MeanIoU)
plt.plot(results.history['mean_io_u'])
plt.plot(results.history['val_mean_io_u'])
plt.title('MeanIoU (Jaccard Index) vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('MeanIoU (Jaccard Index)')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
