# %%
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras.metrics import Precision, Recall
from keras_flops import get_flops

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, Input, MaxPooling2D, Dropout, concatenate, UpSampling2D, BatchNormalization, Activation, Conv2DTranspose
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import gc

# %%
# Read and examine metadata
#raw_data = pd.read_csv(r"D:\NITK\COVID-19 Lung CT Scan Segmentation\COVID-19 Lung CT Scan Segmentation\metadata.csv")
raw_data = pd.read_csv(r'COVID-19 Lung CT Scan Segmentation/COVID-19 Lung CT Scan Segmentation/metadata_temp.csv')
raw_data.sample(5)
# Out:
#                                               ct_scan  \
# 1   C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...
# 8   C:\Application\Programming\Research\Lung_Segme...
# 19  C:\Application\Programming\Research\Lung_Segme...
# 13  C:\Application\Programming\Research\Lung_Segme...
#
#                                             lung_mask  \
# 1   C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...
# 8   C:\Application\Programming\Research\Lung_Segme...
# 19  C:\Application\Programming\Research\Lung_Segme...
# 13  C:\Application\Programming\Research\Lung_Segme...
#
#                                        infection_mask  \
# 1   C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...
# 8   C:\Application\Programming\Research\Lung_Segme...
# 19  C:\Application\Programming\Research\Lung_Segme...
# 13  C:\Application\Programming\Research\Lung_Segme...
#
#                               lung_and_infection_mask
# 1   C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...
# 8   C:\Application\Programming\Research\Lung_Segme...
# 19  C:\Application\Programming\Research\Lung_Segme...
# 13  C:\Application\Programming\Research\Lung_Segme...

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
# Read sample
sample_ct   = read_nii(raw_data.loc[1,'ct_scan'])
sample_lung = read_nii(raw_data.loc[1,'lung_mask'])
sample_infe = read_nii(raw_data.loc[1,'infection_mask'])
sample_all  = read_nii(raw_data.loc[1,'lung_and_infection_mask'])

# Examine Shape
sample_ct.shape
# Out:
# (512, 512, 200)

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %%
IMG_SIZE = 128
IMG_HEIGHT = IMG_SIZE
IMG_WIDTH = IMG_SIZE
IMG_CHANNELS = 1

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

def get_data():
    lungs_data = []
    infections_data  = []

    for row in range(len(raw_data)):
        lungs_image = read_nii(raw_data['ct_scan'][row])
        infection_image = read_nii(raw_data['infection_mask'][row])

        for slice_no in range(lungs_image.shape[2]):
            lung_slice = cv2.resize(lungs_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA)
            infection_slice = cv2.resize(infection_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')

            lung_slice_temp = lung_slice.reshape(-1, 2)
            lung_slice_temp = scaler.fit_transform(lung_slice_temp)
            lung_slice = lung_slice_temp.reshape(lung_slice.shape)
            lungs_data.append(lung_slice[..., np.newaxis])

            infections_data.append(infection_slice[..., np.newaxis])
    return lungs_data, infections_data

# %%
data = get_data()
lungs = np.array(data[0])
infections = np.array(data[1])

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,2,1)
plt.imshow(lungs[451], cmap = 'bone')
plt.title('Transformed Image')

plt.subplot(1,2,2)
plt.imshow(lungs[451], cmap = 'bone')
plt.imshow(infections[451],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Transformed Infection Mask')
# Out:
# Text(0.5, 1.0, 'Transformed Infection Mask')

# %%
# Split the data into train and test sets
lung_train, lung_test, infect_train, infect_test = train_test_split(lungs, infections, test_size=0.1, shuffle=True)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
"""Modified"""
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, RandomContrast, RandomCrop, GaussianNoise

# %%
def Unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Augmentation
    aug = RandomRotation(10)(input_img)
    aug = RandomZoom(0.1)(aug)
    aug = RandomContrast(0.1)(aug)
    aug = GaussianNoise(10)(aug)
    input_img = aug  

    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
import tensorflow.keras.backend as K

def jaccard_loss(y_true, y_pred, smooth=1e-7):
    y_true = K.cast(y_true, dtype='float32')  # Cast y_true to float32
    intersection = K.sum(y_true * y_pred, axis=(1, 2, 3))
    union = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3)) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    return 1 - jaccard

# %%
from keras import backend as K
K.clear_session()

# Define the UNET model with TensorFlow's MeanIoU metric
input_img = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), name='img')
model = Unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
metrics = ["accuracy", 
           tf.keras.metrics.AUC(), 
           tf.keras.metrics.SensitivityAtSpecificity(0.5), 
           tf.keras.metrics.SpecificityAtSensitivity(0.5),
           tf.keras.metrics.MeanIoU(num_classes=2)]  # Use MeanIoU as the Jaccard Index metric
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=metrics)  # Use custom Jaccard loss

gc.collect()
# Out:
# 57

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  160         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 16  64         ['conv2d_1[1][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_1[1][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['activation_1[1][0]']
#
#  dropout (Dropout)              (None, 64, 64, 16)   0           ['max_pooling2d[1][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   4640        ['dropout[1][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_3[1][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_3[1][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['activation_3[1][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 32)   0           ['max_pooling2d_1[1][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   18496       ['dropout_1[1][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_5[1][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_5[1][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['activation_5[1][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 64)   0           ['max_pooling2d_2[1][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 128)  73856       ['dropout_2[1][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_7[1][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 16, 16, 128)  0           ['batch_normalization_7[1][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['activation_7[1][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 128)    0           ['max_pooling2d_3[1][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    295168      ['dropout_3[1][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_9[1][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 8, 8, 256)    0           ['batch_normalization_9[1][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  295040     ['activation_9[1][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[1][0]',
#                                                                   'activation_7[1][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 256)  0           ['concatenate[1][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  295040      ['dropout_4[1][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 128)  512        ['conv2d_11[1][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_11[1][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  73792       ['activation_11[1][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[1][0]',
#                                                                   'activation_5[1][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['concatenate_1[1][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_5[1][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 64)  256         ['conv2d_13[1][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_13[1][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  18464       ['activation_13[1][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[1][0]',
#                                                                   'activation_3[1][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 64)   0           ['concatenate_2[1][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_6[1][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 32)  128         ['conv2d_15[1][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_15[1][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  4624       ['activation_15[1][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[1][0]',
#                                 )                                 'activation_1[1][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['concatenate_3[1][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 16  4624        ['dropout_7[1][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 16  64         ['conv2d_17[1][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_17[1][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  17          ['activation_17[1][0]']
#
# ==================================================================================================
# Total params: 1,179,121
# Trainable params: 1,177,649
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
# Define callbacks
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-Unet__da_ss.h5', verbose=1, save_best_only=True, save_weights_only=False),
]

# %%
results = model.fit(lung_train, infect_train, batch_size=8, epochs=50, callbacks=callbacks, validation_data=(lung_test, infect_test), use_multiprocessing=True)
# Out:
# Epoch 1/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.2224 - accuracy: 0.9702 - auc: 0.6551 - sensitivity_at_specificity: 0.7854 - specificity_at_sensitivity: 0.6447 - mean_io_u: 0.4967
# Epoch 1: val_loss improved from inf to 0.06669, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 29s 47ms/step - loss: 0.2220 - accuracy: 0.9702 - auc: 0.6561 - sensitivity_at_specificity: 0.7855 - specificity_at_sensitivity: 0.6456 - mean_io_u: 0.4967 - val_loss: 0.0667 - val_accuracy: 0.9929 - val_auc: 0.8966 - val_sensitivity_at_specificity: 0.9259 - val_specificity_at_sensitivity: 0.9725 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 2/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.9951 - auc: 0.9761 - sensitivity_at_specificity: 0.9891 - specificity_at_sensitivity: 0.9986 - mean_io_u: 0.4967
# Epoch 2: val_loss improved from 0.06669 to 0.02470, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 18s 46ms/step - loss: 0.0391 - accuracy: 0.9951 - auc: 0.9761 - sensitivity_at_specificity: 0.9891 - specificity_at_sensitivity: 0.9986 - mean_io_u: 0.4967 - val_loss: 0.0247 - val_accuracy: 0.9949 - val_auc: 0.9853 - val_sensitivity_at_specificity: 0.9809 - val_specificity_at_sensitivity: 0.9995 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 3/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0172 - accuracy: 0.9967 - auc: 0.9931 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967
# Epoch 3: val_loss improved from 0.02470 to 0.01322, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 18s 45ms/step - loss: 0.0172 - accuracy: 0.9967 - auc: 0.9931 - sensitivity_at_specificity: 0.9951 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967 - val_loss: 0.0132 - val_accuracy: 0.9969 - val_auc: 0.9973 - val_sensitivity_at_specificity: 0.9970 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 4/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0110 - accuracy: 0.9973 - auc: 0.9971 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 4: val_loss improved from 0.01322 to 0.00975, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 18s 46ms/step - loss: 0.0110 - accuracy: 0.9973 - auc: 0.9970 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0098 - val_accuracy: 0.9971 - val_auc: 0.9982 - val_sensitivity_at_specificity: 0.9989 - val_specificity_at_sensitivity: 0.9998 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 5/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 0.9975 - auc: 0.9973 - sensitivity_at_specificity: 0.9969 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 5: val_loss did not improve from 0.00975
# 396/396 [==============================] - 18s 45ms/step - loss: 0.0086 - accuracy: 0.9975 - auc: 0.9973 - sensitivity_at_specificity: 0.9969 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0131 - val_accuracy: 0.9958 - val_auc: 0.9977 - val_sensitivity_at_specificity: 0.9989 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 6/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9976 - auc: 0.9973 - sensitivity_at_specificity: 0.9966 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 6: val_loss improved from 0.00975 to 0.00831, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 18s 46ms/step - loss: 0.0076 - accuracy: 0.9976 - auc: 0.9973 - sensitivity_at_specificity: 0.9966 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0083 - val_accuracy: 0.9970 - val_auc: 0.9984 - val_sensitivity_at_specificity: 0.9988 - val_specificity_at_sensitivity: 0.9998 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 7/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9978 - auc: 0.9975 - sensitivity_at_specificity: 0.9965 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 7: val_loss improved from 0.00831 to 0.00812, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 19s 47ms/step - loss: 0.0065 - accuracy: 0.9978 - auc: 0.9975 - sensitivity_at_specificity: 0.9965 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0081 - val_accuracy: 0.9970 - val_auc: 0.9967 - val_sensitivity_at_specificity: 0.9957 - val_specificity_at_sensitivity: 0.9998 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 8/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9979 - auc: 0.9977 - sensitivity_at_specificity: 0.9968 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 8: val_loss improved from 0.00812 to 0.00611, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 18s 46ms/step - loss: 0.0058 - accuracy: 0.9979 - auc: 0.9977 - sensitivity_at_specificity: 0.9968 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0061 - val_accuracy: 0.9976 - val_auc: 0.9986 - val_sensitivity_at_specificity: 0.9985 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 9/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9980 - auc: 0.9979 - sensitivity_at_specificity: 0.9969 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 9: val_loss improved from 0.00611 to 0.00587, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 18s 46ms/step - loss: 0.0054 - accuracy: 0.9980 - auc: 0.9979 - sensitivity_at_specificity: 0.9969 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0059 - val_accuracy: 0.9978 - val_auc: 0.9982 - val_sensitivity_at_specificity: 0.9976 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 10/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0051 - accuracy: 0.9980 - auc: 0.9980 - sensitivity_at_specificity: 0.9971 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 10: val_loss did not improve from 0.00587
# 396/396 [==============================] - 18s 46ms/step - loss: 0.0052 - accuracy: 0.9980 - auc: 0.9980 - sensitivity_at_specificity: 0.9971 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0073 - val_accuracy: 0.9972 - val_auc: 0.9958 - val_sensitivity_at_specificity: 0.9934 - val_specificity_at_sensitivity: 0.9998 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 11/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0051 - accuracy: 0.9980 - auc: 0.9978 - sensitivity_at_specificity: 0.9966 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 11: val_loss did not improve from 0.00587
# 396/396 [==============================] - 18s 45ms/step - loss: 0.0051 - accuracy: 0.9980 - auc: 0.9978 - sensitivity_at_specificity: 0.9966 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0074 - val_accuracy: 0.9970 - val_auc: 0.9985 - val_sensitivity_at_specificity: 0.9986 - val_specificity_at_sensitivity: 0.9998 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 12/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9981 - auc: 0.9980 - sensitivity_at_specificity: 0.9969 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 12: val_loss improved from 0.00587 to 0.00547, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 19s 48ms/step - loss: 0.0048 - accuracy: 0.9981 - auc: 0.9980 - sensitivity_at_specificity: 0.9969 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0055 - val_accuracy: 0.9979 - val_auc: 0.9963 - val_sensitivity_at_specificity: 0.9938 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 13/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9982 - auc: 0.9980 - sensitivity_at_specificity: 0.9970 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 13: val_loss improved from 0.00547 to 0.00525, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 18s 45ms/step - loss: 0.0046 - accuracy: 0.9982 - auc: 0.9980 - sensitivity_at_specificity: 0.9970 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0052 - val_accuracy: 0.9979 - val_auc: 0.9983 - val_sensitivity_at_specificity: 0.9978 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 14/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9982 - auc: 0.9983 - sensitivity_at_specificity: 0.9974 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 14: val_loss improved from 0.00525 to 0.00522, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 18s 45ms/step - loss: 0.0044 - accuracy: 0.9982 - auc: 0.9982 - sensitivity_at_specificity: 0.9973 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0052 - val_accuracy: 0.9979 - val_auc: 0.9977 - val_sensitivity_at_specificity: 0.9965 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 15/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0044 - accuracy: 0.9982 - auc: 0.9982 - sensitivity_at_specificity: 0.9972 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 15: val_loss did not improve from 0.00522
# 396/396 [==============================] - 18s 45ms/step - loss: 0.0044 - accuracy: 0.9982 - auc: 0.9982 - sensitivity_at_specificity: 0.9972 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0054 - val_accuracy: 0.9978 - val_auc: 0.9981 - val_sensitivity_at_specificity: 0.9973 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 16/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9983 - auc: 0.9985 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 16: val_loss did not improve from 0.00522
# 396/396 [==============================] - 20s 52ms/step - loss: 0.0041 - accuracy: 0.9983 - auc: 0.9985 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0063 - val_accuracy: 0.9975 - val_auc: 0.9946 - val_sensitivity_at_specificity: 0.9907 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 17/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9983 - auc: 0.9985 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 17: val_loss improved from 0.00522 to 0.00483, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 21s 54ms/step - loss: 0.0041 - accuracy: 0.9983 - auc: 0.9985 - sensitivity_at_specificity: 0.9977 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0048 - val_accuracy: 0.9980 - val_auc: 0.9983 - val_sensitivity_at_specificity: 0.9976 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 18/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9984 - auc: 0.9986 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 18: val_loss improved from 0.00483 to 0.00480, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 21s 53ms/step - loss: 0.0040 - accuracy: 0.9984 - auc: 0.9986 - sensitivity_at_specificity: 0.9979 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0048 - val_accuracy: 0.9980 - val_auc: 0.9986 - val_sensitivity_at_specificity: 0.9982 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 19/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9984 - auc: 0.9987 - sensitivity_at_specificity: 0.9980 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 19: val_loss did not improve from 0.00480
# 396/396 [==============================] - 25s 62ms/step - loss: 0.0039 - accuracy: 0.9984 - auc: 0.9987 - sensitivity_at_specificity: 0.9980 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0051 - val_accuracy: 0.9979 - val_auc: 0.9982 - val_sensitivity_at_specificity: 0.9974 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 20/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9984 - auc: 0.9987 - sensitivity_at_specificity: 0.9981 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 20: val_loss did not improve from 0.00480
# 396/396 [==============================] - 24s 61ms/step - loss: 0.0039 - accuracy: 0.9984 - auc: 0.9987 - sensitivity_at_specificity: 0.9981 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0049 - val_accuracy: 0.9980 - val_auc: 0.9963 - val_sensitivity_at_specificity: 0.9935 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 21/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9984 - auc: 0.9988 - sensitivity_at_specificity: 0.9982 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 21: val_loss did not improve from 0.00480
# 396/396 [==============================] - 22s 56ms/step - loss: 0.0038 - accuracy: 0.9984 - auc: 0.9988 - sensitivity_at_specificity: 0.9982 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0051 - val_accuracy: 0.9979 - val_auc: 0.9984 - val_sensitivity_at_specificity: 0.9977 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 22/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9988 - sensitivity_at_specificity: 0.9982 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 22: val_loss improved from 0.00480 to 0.00480, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 21s 54ms/step - loss: 0.0037 - accuracy: 0.9985 - auc: 0.9988 - sensitivity_at_specificity: 0.9982 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0048 - val_accuracy: 0.9980 - val_auc: 0.9978 - val_sensitivity_at_specificity: 0.9966 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 23/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.9986 - auc: 0.9992 - sensitivity_at_specificity: 0.9988 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 23: val_loss improved from 0.00480 to 0.00453, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 22s 55ms/step - loss: 0.0032 - accuracy: 0.9986 - auc: 0.9992 - sensitivity_at_specificity: 0.9988 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0045 - val_accuracy: 0.9982 - val_auc: 0.9976 - val_sensitivity_at_specificity: 0.9959 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 24/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9987 - auc: 0.9993 - sensitivity_at_specificity: 0.9989 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 24: val_loss improved from 0.00453 to 0.00453, saving model to model-Unet__da_ss.h5
# 396/396 [==============================] - 22s 55ms/step - loss: 0.0031 - accuracy: 0.9987 - auc: 0.9993 - sensitivity_at_specificity: 0.9989 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0045 - val_accuracy: 0.9982 - val_auc: 0.9973 - val_sensitivity_at_specificity: 0.9954 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 25/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9987 - auc: 0.9992 - sensitivity_at_specificity: 0.9989 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 25: val_loss did not improve from 0.00453
# 396/396 [==============================] - 22s 54ms/step - loss: 0.0030 - accuracy: 0.9987 - auc: 0.9992 - sensitivity_at_specificity: 0.9989 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0045 - val_accuracy: 0.9982 - val_auc: 0.9971 - val_sensitivity_at_specificity: 0.9951 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 26/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9987 - auc: 0.9992 - sensitivity_at_specificity: 0.9989 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 26: val_loss did not improve from 0.00453
# 396/396 [==============================] - 20s 51ms/step - loss: 0.0030 - accuracy: 0.9987 - auc: 0.9992 - sensitivity_at_specificity: 0.9989 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0046 - val_accuracy: 0.9982 - val_auc: 0.9972 - val_sensitivity_at_specificity: 0.9952 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 27/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9988 - auc: 0.9993 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 27: val_loss did not improve from 0.00453
# 396/396 [==============================] - 22s 55ms/step - loss: 0.0030 - accuracy: 0.9988 - auc: 0.9993 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0046 - val_accuracy: 0.9982 - val_auc: 0.9971 - val_sensitivity_at_specificity: 0.9950 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 28/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9988 - auc: 0.9993 - sensitivity_at_specificity: 0.9989 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 28: val_loss did not improve from 0.00453
# 396/396 [==============================] - 20s 50ms/step - loss: 0.0029 - accuracy: 0.9988 - auc: 0.9993 - sensitivity_at_specificity: 0.9989 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0046 - val_accuracy: 0.9982 - val_auc: 0.9970 - val_sensitivity_at_specificity: 0.9948 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 29/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9988 - auc: 0.9994 - sensitivity_at_specificity: 0.9991 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968
# Epoch 29: val_loss did not improve from 0.00453
# 396/396 [==============================] - 23s 57ms/step - loss: 0.0029 - accuracy: 0.9988 - auc: 0.9994 - sensitivity_at_specificity: 0.9991 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968 - val_loss: 0.0046 - val_accuracy: 0.9982 - val_auc: 0.9970 - val_sensitivity_at_specificity: 0.9947 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 30/50
# 395/396 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9988 - auc: 0.9994 - sensitivity_at_specificity: 0.9991 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968
# Epoch 30: val_loss did not improve from 0.00453
# 396/396 [==============================] - 21s 53ms/step - loss: 0.0029 - accuracy: 0.9988 - auc: 0.9994 - sensitivity_at_specificity: 0.9991 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968 - val_loss: 0.0046 - val_accuracy: 0.9982 - val_auc: 0.9969 - val_sensitivity_at_specificity: 0.9946 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 31/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9988 - auc: 0.9994 - sensitivity_at_specificity: 0.9991 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968
# Epoch 31: val_loss did not improve from 0.00453
# 396/396 [==============================] - 20s 49ms/step - loss: 0.0029 - accuracy: 0.9988 - auc: 0.9994 - sensitivity_at_specificity: 0.9991 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968 - val_loss: 0.0046 - val_accuracy: 0.9982 - val_auc: 0.9969 - val_sensitivity_at_specificity: 0.9947 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 32/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9988 - auc: 0.9993 - sensitivity_at_specificity: 0.9989 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968
# Epoch 32: val_loss did not improve from 0.00453
# 396/396 [==============================] - 20s 52ms/step - loss: 0.0028 - accuracy: 0.9988 - auc: 0.9993 - sensitivity_at_specificity: 0.9989 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968 - val_loss: 0.0046 - val_accuracy: 0.9982 - val_auc: 0.9968 - val_sensitivity_at_specificity: 0.9944 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 33/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9988 - auc: 0.9994 - sensitivity_at_specificity: 0.9991 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 33: val_loss did not improve from 0.00453
# 396/396 [==============================] - 20s 49ms/step - loss: 0.0029 - accuracy: 0.9988 - auc: 0.9994 - sensitivity_at_specificity: 0.9991 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968 - val_loss: 0.0046 - val_accuracy: 0.9982 - val_auc: 0.9968 - val_sensitivity_at_specificity: 0.9943 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 34/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9988 - auc: 0.9993 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968
# Epoch 34: val_loss did not improve from 0.00453
# 396/396 [==============================] - 20s 50ms/step - loss: 0.0028 - accuracy: 0.9988 - auc: 0.9993 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4968 - val_loss: 0.0046 - val_accuracy: 0.9982 - val_auc: 0.9967 - val_sensitivity_at_specificity: 0.9943 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 34: early stopping

# %%
df_result = pd.DataFrame(results.history)
df_result.sort_values('val_loss', ascending=True, inplace = True)
df_result
# Out:
#         loss  accuracy       auc  sensitivity_at_specificity  \
# 23  0.003087  0.998704  0.999255                    0.998943
# 22  0.003229  0.998648  0.999186                    0.998845
# 24  0.003028  0.998732  0.999243                    0.998901
# 28  0.002870  0.998796  0.999374                    0.999122
# 25  0.002994  0.998743  0.999235                    0.998878
# 27  0.002932  0.998764  0.999274                    0.998940
# 26  0.002967  0.998755  0.999299                    0.998999
# 29  0.002865  0.998794  0.999373                    0.999119
# 31  0.002846  0.998801  0.999283                    0.998934
# 32  0.002862  0.998793  0.999364                    0.999102
# 33  0.002829  0.998810  0.999329                    0.999022
# 30  0.002852  0.998801  0.999361                    0.999093
# 21  0.003693  0.998464  0.998790                    0.998197
# 17  0.003994  0.998355  0.998582                    0.997879
# 16  0.004105  0.998324  0.998455                    0.997658
# 19  0.003867  0.998398  0.998704                    0.998079
# 20  0.003765  0.998440  0.998794                    0.998230
# 18  0.003880  0.998394  0.998685                    0.998047
# 13  0.004412  0.998231  0.998218                    0.997284
# 12  0.004588  0.998181  0.998048                    0.997001
# 14  0.004409  0.998230  0.998179                    0.997213
# 11  0.004799  0.998123  0.997966                    0.996910
# 8   0.005372  0.998012  0.997883                    0.996892
# 7   0.005821  0.997920  0.997744                    0.996754
# 15  0.004104  0.998330  0.998453                    0.997652
# 9   0.005164  0.998043  0.997987                    0.997057
# 10  0.005121  0.998025  0.997776                    0.996648
# 6   0.006531  0.997780  0.997465                    0.996456
# 5   0.007633  0.997567  0.997299                    0.996598
# 3   0.010999  0.997296  0.997045                    0.998539
# 4   0.008647  0.997505  0.997288                    0.996901
# 2   0.017170  0.996725  0.993143                    0.995087
# 1   0.039147  0.995123  0.976097                    0.989098
# 0   0.222003  0.970223  0.656099                    0.785532
#
#     specificity_at_sensitivity  mean_io_u  val_loss  val_accuracy   val_auc  \
# 23                    0.999991   0.496730  0.004530      0.998171  0.997287
# 22                    0.999987   0.496730  0.004535      0.998159  0.997562
# 24                    0.999990   0.496730  0.004549      0.998167  0.997140
# 28                    0.999993   0.496753  0.004560      0.998186  0.996950
# 25                    0.999990   0.496730  0.004567      0.998163  0.997178
# 27                    0.999992   0.496736  0.004571      0.998176  0.997010
# 26                    0.999993   0.496731  0.004576      0.998165  0.997105
# 29                    0.999993   0.496753  0.004577      0.998182  0.996926
# 31                    0.999993   0.496761  0.004580      0.998181  0.996817
# 32                    0.999993   0.496776  0.004590      0.998178  0.996780
# 33                    0.999993   0.496764  0.004592      0.998183  0.996744
# 30                    0.999993   0.496774  0.004599      0.998175  0.996950
# 21                    0.999975   0.496730  0.004802      0.998039  0.997814
# 17                    0.999972   0.496730  0.004804      0.998031  0.998623
# 16                    0.999965   0.496730  0.004826      0.998013  0.998286
# 19                    0.999968   0.496730  0.004917      0.998027  0.996280
# 20                    0.999975   0.496730  0.005094      0.997878  0.998352
# 18                    0.999972   0.496730  0.005112      0.997912  0.998179
# 13                    0.999956   0.496730  0.005216      0.997904  0.997707
# 12                    0.999953   0.496730  0.005249      0.997883  0.998341
# 14                    0.999955   0.496730  0.005359      0.997796  0.998102
# 11                    0.999945   0.496730  0.005472      0.997850  0.996334
# 8                     0.999935   0.496730  0.005873      0.997751  0.998172
# 7                     0.999925   0.496730  0.006106      0.997634  0.998584
# 15                    0.999967   0.496730  0.006317      0.997503  0.994625
# 9                     0.999934   0.496730  0.007263      0.997186  0.995849
# 10                    0.999938   0.496730  0.007392      0.996957  0.998475
# 6                     0.999896   0.496730  0.008123      0.997033  0.996746
# 5                     0.999852   0.496730  0.008313      0.997012  0.998416
# 3                     0.999796   0.496730  0.009751      0.997082  0.998182
# 4                     0.999849   0.496730  0.013062      0.995814  0.997707
# 2                     0.999590   0.496730  0.013221      0.996919  0.997324
# 1                     0.998630   0.496730  0.024699      0.994889  0.985326
# 0                     0.645553   0.496730  0.066690      0.992916  0.896558
#
#     val_sensitivity_at_specificity  val_specificity_at_sensitivity  \
# 23                        0.995374                        0.999955
# 22                        0.995937                        0.999956
# 24                        0.995080                        0.999953
# 28                        0.994688                        0.999957
# 25                        0.995153                        0.999958
# 27                        0.994811                        0.999956
# 26                        0.995006                        0.999955
# 29                        0.994639                        0.999955
# 31                        0.994419                        0.999955
# 32                        0.994345                        0.999952
# 33                        0.994272                        0.999953
# 30                        0.994688                        0.999952
# 21                        0.996573                        0.999935
# 17                        0.998189                        0.999957
# 16                        0.997552                        0.999952
# 19                        0.993513                        0.999950
# 20                        0.997699                        0.999923
# 18                        0.997381                        0.999914
# 13                        0.996500                        0.999926
# 12                        0.997797                        0.999929
# 14                        0.997332                        0.999925
# 11                        0.993758                        0.999938
# 8                         0.997626                        0.999897
# 7                         0.998507                        0.999906
# 15                        0.990723                        0.999851
# 9                         0.993440                        0.999840
# 10                        0.998605                        0.999827
# 6                         0.995667                        0.999794
# 5                         0.998776                        0.999795
# 3                         0.998923                        0.999792
# 4                         0.998874                        0.999677
# 2                         0.997038                        0.999710
# 1                         0.980931                        0.999521
# 0                         0.925854                        0.972469
#
#     val_mean_io_u       lr
# 23       0.496458  0.00010
# 22       0.496458  0.00010
# 24       0.496458  0.00010
# 28       0.496495  0.00001
# 25       0.496458  0.00010
# 27       0.496495  0.00010
# 26       0.496471  0.00010
# 29       0.496520  0.00001
# 31       0.496520  0.00001
# 32       0.496520  0.00001
# 33       0.496520  0.00001
# 30       0.496532  0.00001
# 21       0.496458  0.00100
# 17       0.496458  0.00100
# 16       0.496458  0.00100
# 19       0.496458  0.00100
# 20       0.496458  0.00100
# 18       0.496458  0.00100
# 13       0.496458  0.00100
# 12       0.496458  0.00100
# 14       0.496458  0.00100
# 11       0.496458  0.00100
# 8        0.496458  0.00100
# 7        0.496458  0.00100
# 15       0.496458  0.00100
# 9        0.496458  0.00100
# 10       0.496458  0.00100
# 6        0.496458  0.00100
# 5        0.496458  0.00100
# 3        0.496458  0.00100
# 4        0.496458  0.00100
# 2        0.496458  0.00100
# 1        0.496458  0.00100
# 0        0.496458  0.00100

# %%
plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["accuracy"], label="Accuracy")
plt.plot(results.history["val_accuracy"], label="val_Accuracy")
plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %%
#model.save("Unet_DA_ss.h5")

# %%
# Calculate metrics
predicted = model.predict(lung_test)

# Flatten the predicted and true masks
predicted_flat = np.round(predicted.flatten())
infect_test_flat = infect_test.flatten()

# %%
# Calculate metrics for training data
train_predicted = model.predict(lung_train)

# Flatten the predicted and true masks
train_predicted_flat = np.round(train_predicted.flatten())
infect_train_flat = infect_train.flatten()

# Calculate precision and recall for training data
train_precision = Precision()
train_recall = Recall()
train_precision.update_state(infect_train_flat, train_predicted_flat)
train_recall.update_state(infect_train_flat, train_predicted_flat)

# Calculate F1 score for training data
train_f1_score = 2 * (train_precision.result() * train_recall.result()) / (train_precision.result() + train_recall.result())

# Calculate accuracy for training data
train_accuracy = np.mean(train_predicted_flat == infect_train_flat)

# Calculate metrics for testing data
test_predicted = model.predict(lung_test)

# Flatten the predicted and true masks for testing data
test_predicted_flat = np.round(test_predicted.flatten())
infect_test_flat = infect_test.flatten()

# Calculate precision and recall for testing data
test_precision = Precision()
test_recall = Recall()
test_precision.update_state(infect_test_flat, test_predicted_flat)
test_recall.update_state(infect_test_flat, test_predicted_flat)

# Calculate F1 score for testing data
test_f1_score = 2 * (test_precision.result() * test_recall.result()) / (test_precision.result() + test_recall.result())

# Calculate accuracy for testing data
test_accuracy = np.mean(test_predicted_flat == infect_test_flat)

# Calculate parameters
total_parameters = np.sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])

# Calculate FLOPs
flops = get_flops(model, batch_size=1)  # Assuming batch_size = 1

# Print the metrics for training data
print("Training Metrics:")
print("Precision: ", train_precision.result().numpy())
print("Recall: ", train_recall.result().numpy())
print("F1 Score: ", train_f1_score.numpy())
print("Accuracy: ", train_accuracy)

# Print the metrics for testing data
print("\nTesting Metrics:")
print("Precision: ", test_precision.result().numpy())
print("Recall: ", test_recall.result().numpy())
print("F1 Score: ", test_f1_score.numpy())
print("Accuracy: ", test_accuracy)

# Print the other metrics
print("\nTotal Parameters: ", total_parameters)
print("FLOPs: ", flops)
# Out:
# WARNING:tensorflow:From c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\ops\nn_ops.py:5214: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# Training Metrics:
# Precision:  0.9065356
# Recall:  0.92520887
# F1 Score:  0.9157771
# Accuracy:  0.9988868983104976
#
# Testing Metrics:
# Precision:  0.86392504
# Recall:  0.88242924
# F1 Score:  0.87307906
# Accuracy:  0.9981826435435902
#
# Total Parameters:  1177649
# FLOPs:  915214656

# %%
device = "CPU:0"

# %%
with tf.device(device):
    # Calculate Jaccard Index (MeanIoU) for training data
    train_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    train_iou.update_state(infect_train_flat, train_predicted_flat)
    train_mean_iou = train_iou.result().numpy()

    # Calculate Jaccard Index (MeanIoU) for testing data
    test_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    test_iou.update_state(infect_test_flat, test_predicted_flat)
    test_mean_iou = test_iou.result().numpy()

    # Print the Jaccard Index (MeanIoU) for training and testing data
    print("Training Jaccard Index (MeanIoU): ", train_mean_iou)
    print("Testing Jaccard Index (MeanIoU): ", test_mean_iou)
# Out:
# Training Jaccard Index (MeanIoU):  0.9206036
# Testing Jaccard Index (MeanIoU):  0.88645935

# %%
# Plot accuracy
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
with tf.device(device):
    # Make predictions
    predicted = model.predict(lung_test)

# %%
# Make predictions and visualize
img_num = 20
predicted = model.predict(lung_test)

# Visualize results
fig = plt.figure(figsize=(18, 15))
plt.subplot(1, 3, 1)
plt.imshow(lung_test[img_num], cmap='bone')
plt.title('Original lung')

plt.subplot(1, 3, 2)
plt.imshow(lung_test[img_num], cmap='bone')
plt.imshow(infect_test[img_num][..., 0], alpha=0.5, cmap="nipy_spectral")
plt.title('Original infection mask')

plt.subplot(1, 3, 3)
plt.imshow(lung_test[img_num], cmap='bone')
plt.imshow(predicted[img_num], alpha=0.5, cmap="nipy_spectral")
plt.title('Predicted infection mask')
# Out:
# Text(0.5, 1.0, 'Predicted infection mask')

# %%
# Plot Jaccard Index (MeanIoU)
plt.plot(results.history['mean_io_u'])
plt.plot(results.history['val_mean_io_u'])
plt.title('MeanIoU (Jaccard Index) vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('MeanIoU (Jaccard Index)')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
