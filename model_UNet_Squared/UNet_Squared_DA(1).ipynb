# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras.metrics import Precision, Recall

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, Input, MaxPooling2D, Dropout, Concatenate, UpSampling2D, BatchNormalization, Activation, Conv2DTranspose, Add, MaxPool2D, ZeroPadding2D
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import gc

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout, SpatialDropout2D

# %%
# Read and examine metadata
# raw_data = pd.read_csv(r"/content/drive/MyDrive/COVID-19 Lung CT Scan Segmentation/metadata_COLAB.csv")
raw_data = pd.read_csv(r"../COVID-19 Lung CT Scan Segmentation/COVID-19 Lung CT Scan Segmentation/metadata_temp.csv")
raw_data.sample(5)
# Out:
#                                               ct_scan  \
# 11  C:\Application\Programming\Research\Lung_Segme...
# 13  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
#
#                                             lung_mask  \
# 11  C:\Application\Programming\Research\Lung_Segme...
# 13  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
#
#                                        infection_mask  \
# 11  C:\Application\Programming\Research\Lung_Segme...
# 13  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...
#
#                               lung_and_infection_mask
# 11  C:\Application\Programming\Research\Lung_Segme...
# 13  C:\Application\Programming\Research\Lung_Segme...
# 17  C:\Application\Programming\Research\Lung_Segme...
# 9   C:\Application\Programming\Research\Lung_Segme...
# 16  C:\Application\Programming\Research\Lung_Segme...

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
# Read sample
sample_ct   = read_nii(raw_data.loc[1,'ct_scan'])
sample_lung = read_nii(raw_data.loc[1,'lung_mask'])
sample_infe = read_nii(raw_data.loc[1,'infection_mask'])
sample_all  = read_nii(raw_data.loc[1,'lung_and_infection_mask'])

# Examine Shape
sample_ct.shape
# Out:
# (512, 512, 200)

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %%
IMG_SIZE = 128
IMG_HEIGHT = IMG_SIZE
IMG_WIDTH = IMG_SIZE
IMG_CHANNELS = 1

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

def get_data():
    lungs_data = []
    infections_data  = []

    for row in range(len(raw_data)):
        lungs_image = read_nii(raw_data['ct_scan'][row])
        infection_image = read_nii(raw_data['infection_mask'][row])

        for slice_no in range(lungs_image.shape[2]):
            lung_slice = cv2.resize(lungs_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA)
            infection_slice = cv2.resize(infection_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')

            lung_slice_temp = lung_slice.reshape(-1, 2)
            lung_slice_temp = scaler.fit_transform(lung_slice_temp)
            lung_slice = lung_slice_temp.reshape(lung_slice.shape)
            lungs_data.append(lung_slice[..., np.newaxis])

            infections_data.append(infection_slice[..., np.newaxis])
    return lungs_data, infections_data

# %%
data = get_data()
lungs = np.array(data[0])
infections = np.array(data[1])

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,2,1)
plt.imshow(lungs[451], cmap = 'bone')
plt.title('Transformed Image')

plt.subplot(1,2,2)
plt.imshow(lungs[451], cmap = 'bone')
plt.imshow(infections[451],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Transformed Infection Mask')
# Out:
# Text(0.5, 1.0, 'Transformed Infection Mask')

# %%
# Split the data into train and test sets
lung_train, lung_test, infect_train, infect_test = train_test_split(lungs, infections, test_size=0.1, shuffle=True)

# %%
lung_train.shape, lung_test.shape, infect_train.shape, infect_test.shape
# Out:
# ((3168, 128, 128, 1),
#  (352, 128, 128, 1),
#  (3168, 128, 128, 1),
#  (352, 128, 128, 1))

# %%
"""Modified"""
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom, RandomContrast, RandomCrop, GaussianNoise

# %%
def conv_block(inputs, out_ch, rate=1):
    x = Conv2D(out_ch, 3, padding="same", dilation_rate=1)(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def RSU_L(inputs, out_ch, int_ch, num_layers, rate=2):
    """ Initial Conv """
    x = conv_block(inputs, out_ch)
    init_feats = x

    """ Encoder """
    skip = []
    x = conv_block(x, int_ch)
    skip.append(x)

    for i in range(num_layers-2):
        x = MaxPool2D((2, 2))(x)
        x = conv_block(x, int_ch)
        skip.append(x)

    """ Bridge """
    x = conv_block(x, int_ch, rate=rate)

    """ Decoder """
    skip.reverse()

    x = Concatenate()([x, skip[0]])
    x = conv_block(x, int_ch)

    for i in range(num_layers-3):
        x = UpSampling2D(size=(2, 2), interpolation="bilinear")(x)
        x = Concatenate()([x, skip[i+1]])
        x = conv_block(x, int_ch)

    x = UpSampling2D(size=(2, 2), interpolation="bilinear")(x)
    x = Concatenate()([x, skip[-1]])
    x = conv_block(x, out_ch)

    """ Add """
    x = Add()([x, init_feats])
    return x

def RSU_4F(inputs, out_ch, int_ch):
    """ Initial Conv """
    x0 = conv_block(inputs, out_ch, rate=1)

    """ Encoder """
    x1 = conv_block(x0, int_ch, rate=1)
    x2 = conv_block(x1, int_ch, rate=2)
    x3 = conv_block(x2, int_ch, rate=4)

    """ Bridge """
    x4 = conv_block(x3, int_ch, rate=8)

    """ Decoder """
    x = Concatenate()([x4, x3])
    x = conv_block(x, int_ch, rate=4)

    x = Concatenate()([x, x2])
    x = conv_block(x, int_ch, rate=2)

    x = Concatenate()([x, x1])
    x = conv_block(x, out_ch, rate=1)

    """ Addition """
    x = Add()([x, x0])
    return x

def u2net(input_shape, out_ch, int_ch, num_classes=1):
    """ Input Layer """
    inputs = Input(input_shape)
    s0 = inputs

    """Augmentation"""
    # aug = RandomRotation(10)(s0)
    # aug = RandomZoom(0.1)(aug)
    # aug = RandomContrast(0.1)(aug)
    # aug = GaussianNoise(10)(aug)
    # s0 = aug

    """ Encoder """
    s1 = RSU_L(s0, out_ch[0], int_ch[0], 7)
    p1 = MaxPool2D((2, 2))(s1)

    s2 = RSU_L(p1, out_ch[1], int_ch[1], 6)
    p2 = MaxPool2D((2, 2))(s2)

    s3 = RSU_L(p2, out_ch[2], int_ch[2], 5)
    p3 = MaxPool2D((2, 2))(s3)

    s4 = RSU_L(p3, out_ch[3], int_ch[3], 4)
    p4 = MaxPool2D((2, 2))(s4)

    s5 = RSU_4F(p4, out_ch[4], int_ch[4])
    p5 = MaxPool2D((2, 2))(s5)

    """ Bridge """
    b1 = RSU_4F(p5, out_ch[5], int_ch[5])
    b2 = UpSampling2D(size=(2, 2), interpolation="bilinear")(b1)

    """ Decoder """
    d1 = Concatenate()([b2, s5])
    d1 = RSU_4F(d1, out_ch[6], int_ch[6])
    u1 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d1)

    d2 = Concatenate()([u1, s4])
    d2 = RSU_L(d2, out_ch[7], int_ch[7], 4)
    u2 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d2)

    d3 = Concatenate()([u2, s3])
    d3 = RSU_L(d3, out_ch[8], int_ch[8], 5)
    u3 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d3)

    d4 = Concatenate()([u3, s2])
    d4 = RSU_L(d4, out_ch[9], int_ch[9], 6)
    u4 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d4)

    d5 = Concatenate()([u4, s1])
    d5 = RSU_L(d5, out_ch[10], int_ch[10], 7)

    """ Side Outputs """
    y1 = Conv2D(num_classes, 3, padding="same")(d5)

    y2 = Conv2D(num_classes, 3, padding="same")(d4)
    y2 = UpSampling2D(size=(2, 2), interpolation="bilinear")(y2)

    y3 = Conv2D(num_classes, 3, padding="same")(d3)
    y3 = UpSampling2D(size=(4, 4), interpolation="bilinear")(y3)

    y4 = Conv2D(num_classes, 3, padding="same")(d2)
    y4 = UpSampling2D(size=(8, 8), interpolation="bilinear")(y4)

    y5 = Conv2D(num_classes, 3, padding="same")(d1)
    y5 = UpSampling2D(size=(16, 16), interpolation="bilinear")(y5)

    y6 = Conv2D(num_classes, 3, padding="same")(b1)
    y6 = UpSampling2D(size=(32, 32), interpolation="bilinear")(y6)

    y0 = Concatenate()([y1, y2, y3, y4, y5, y6])
    y0 = Conv2D(num_classes, 3, padding="same")(y0)

    y0 = Activation("sigmoid")(y0)
    y1 = Activation("sigmoid")(y1)
    y2 = Activation("sigmoid")(y2)
    y3 = Activation("sigmoid")(y3)
    y4 = Activation("sigmoid")(y4)
    y5 = Activation("sigmoid")(y5)
    y6 = Activation("sigmoid")(y6)

    model = tf.keras.models.Model(inputs, outputs=[y0, y1, y2, y3, y4, y5, y6])
    return model

def build_u2net(input_shape, num_classes=1):
    out_ch = [64, 128, 256, 512, 512, 512, 512, 256, 128, 64, 64]
    int_ch = [32, 32, 64, 128, 256, 256, 256, 128, 64, 32, 16]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model

def build_u2net_lite(input_shape, num_classes=1):
    out_ch = [64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64]
    int_ch = [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model

# %%
if __name__ == "__main__":
    model = build_u2net_lite((128, 128, 1))
    model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  9232        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 16)   2320        ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 16)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 16)  0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 16)   2320        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 16)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 16)   2320        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 16, 16, 16)   0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 16)    0           ['activation_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 16)     2320        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 16)    64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 8, 8, 16)     0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 16)    0           ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 4, 4, 16)     2320        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4, 4, 16)    64          ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 4, 4, 16)     0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 4, 4, 16)     2320        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 4, 4, 16)    64          ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 4, 4, 16)     0           ['batch_normalization_7[0][0]']
#
#  concatenate (Concatenate)      (None, 4, 4, 32)     0           ['activation_7[0][0]',
#                                                                   'activation_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 16)     4624        ['concatenate[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 4, 4, 16)    64          ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 4, 4, 16)     0           ['batch_normalization_8[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 8, 8, 16)     0           ['activation_8[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 32)     0           ['up_sampling2d[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 16)     4624        ['concatenate_1[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 16)    64          ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 8, 8, 16)     0           ['batch_normalization_9[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 16)  0           ['activation_9[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 16, 16, 32)   0           ['up_sampling2d_1[0][0]',
#                                                                   'activation_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 16)   4624        ['concatenate_2[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 16)  64          ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_10[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 16)  0           ['activation_10[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 32)   0           ['up_sampling2d_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 16)   4624        ['concatenate_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_11[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 16)  0           ['activation_11[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 32)   0           ['up_sampling2d_3[0][0]',
#                                                                   'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 16)   4624        ['concatenate_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 16)  64          ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_12[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 16  0          ['activation_12[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 32  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 64  18496       ['concatenate_5[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 64  256        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  activation_13 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  add (Add)                      (None, 128, 128, 64  0           ['activation_13[0][0]',
#                                 )                                 'activation[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)  0           ['add[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   36928       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 16)   9232        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_15[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 16)  0           ['activation_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 16)   2320        ['max_pooling2d_6[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 16)  64          ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_16[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 16)  0           ['activation_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 16)   2320        ['max_pooling2d_7[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_17[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 16)    0           ['activation_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 8, 8, 16)    64          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_18[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 4, 4, 16)    0           ['activation_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 4, 4, 16)     2320        ['max_pooling2d_9[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 4, 4, 16)    64          ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 4, 4, 16)     2320        ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 4, 4, 16)    64          ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_20[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 4, 4, 32)     0           ['activation_20[0][0]',
#                                                                   'activation_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 4, 4, 16)     4624        ['concatenate_6[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 4, 4, 16)    64          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_21[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 8, 8, 16)    0           ['activation_21[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 8, 8, 32)     0           ['up_sampling2d_5[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 16)     4624        ['concatenate_7[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 16)    64          ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_22[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 16, 16, 16)  0           ['activation_22[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 16, 16, 32)   0           ['up_sampling2d_6[0][0]',
#                                                                   'activation_17[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 16)   4624        ['concatenate_8[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 16)  64          ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_23[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 32, 32, 16)  0           ['activation_23[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 32)   0           ['up_sampling2d_7[0][0]',
#                                                                   'activation_16[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 16)   4624        ['concatenate_9[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 16)  64          ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_24[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 64, 64, 16)  0           ['activation_24[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 64, 64, 32)   0           ['up_sampling2d_8[0][0]',
#                                                                   'activation_15[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 64)   18496       ['concatenate_10[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_25[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 64)   0           ['activation_25[0][0]',
#                                                                   'activation_14[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 32, 32, 64)  0           ['add_1[0][0]']
#  )
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 64)   36928       ['max_pooling2d_10[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 16)   9232        ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 16)  64          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_27[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 16, 16, 16)  0           ['activation_27[0][0]']
#  )
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 16)   2320        ['max_pooling2d_11[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 16)  64          ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_28[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 8, 8, 16)    0           ['activation_28[0][0]']
#  )
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_12[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 16)    64          ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 4, 4, 16)    0           ['activation_29[0][0]']
#  )
#
#  conv2d_30 (Conv2D)             (None, 4, 4, 16)     2320        ['max_pooling2d_13[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 4, 4, 16)    64          ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 4, 4, 16)     2320        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 4, 4, 16)    64          ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_31[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 4, 4, 32)     0           ['activation_31[0][0]',
#                                                                   'activation_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 4, 4, 16)     4624        ['concatenate_11[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 4, 4, 16)    64          ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_32[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 8, 8, 16)    0           ['activation_32[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 8, 8, 32)     0           ['up_sampling2d_9[0][0]',
#                                                                   'activation_29[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 16)     4624        ['concatenate_12[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 16)    64          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_33[0][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 16, 16, 16)  0           ['activation_33[0][0]']
#  )
#
#  concatenate_13 (Concatenate)   (None, 16, 16, 32)   0           ['up_sampling2d_10[0][0]',
#                                                                   'activation_28[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 16)   4624        ['concatenate_13[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 16)  64          ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_34[0][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 32, 32, 16)  0           ['activation_34[0][0]']
#  )
#
#  concatenate_14 (Concatenate)   (None, 32, 32, 32)   0           ['up_sampling2d_11[0][0]',
#                                                                   'activation_27[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 64)   18496       ['concatenate_14[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 32, 32, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_35[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 64)   0           ['activation_35[0][0]',
#                                                                   'activation_26[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 16, 16, 64)  0           ['add_2[0][0]']
#  )
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 64)   36928       ['max_pooling2d_14[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 64)  256         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 16)   9232        ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 16)  64          ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_37[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 8, 8, 16)    0           ['activation_37[0][0]']
#  )
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_15[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 16)    64          ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_38[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 4, 4, 16)    0           ['activation_38[0][0]']
#  )
#
#  conv2d_39 (Conv2D)             (None, 4, 4, 16)     2320        ['max_pooling2d_16[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 4, 4, 16)    64          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 4, 4, 16)     2320        ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 4, 4, 16)    64          ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_40[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 4, 4, 32)     0           ['activation_40[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 4, 4, 16)     4624        ['concatenate_15[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 4, 4, 16)    64          ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_41[0][0]']
#
#  up_sampling2d_12 (UpSampling2D  (None, 8, 8, 16)    0           ['activation_41[0][0]']
#  )
#
#  concatenate_16 (Concatenate)   (None, 8, 8, 32)     0           ['up_sampling2d_12[0][0]',
#                                                                   'activation_38[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 16)     4624        ['concatenate_16[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 8, 16)    64          ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_42[0][0]']
#
#  up_sampling2d_13 (UpSampling2D  (None, 16, 16, 16)  0           ['activation_42[0][0]']
#  )
#
#  concatenate_17 (Concatenate)   (None, 16, 16, 32)   0           ['up_sampling2d_13[0][0]',
#                                                                   'activation_37[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 64)   18496       ['concatenate_17[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_43[0][0]']
#
#  add_3 (Add)                    (None, 16, 16, 64)   0           ['activation_43[0][0]',
#                                                                   'activation_36[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 8, 8, 64)    0           ['add_3[0][0]']
#  )
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 64)     36928       ['max_pooling2d_17[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 64)    256         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 16)     9232        ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 16)    64          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 16)     2320        ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 8, 8, 16)    64          ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_46[0][0]']
#
# ...
#
#  max_pooling2d_31 (MaxPooling2D  (None, 8, 8, 16)    0           ['activation_102[0][0]']
#  )
#
#  conv2d_103 (Conv2D)            (None, 8, 8, 16)     2320        ['max_pooling2d_31[0][0]']
#
#  batch_normalization_103 (Batch  (None, 8, 8, 16)    64          ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 8, 8, 16)     0           ['batch_normalization_103[0][0]']
#
#  max_pooling2d_32 (MaxPooling2D  (None, 4, 4, 16)    0           ['activation_103[0][0]']
#  )
#
#  conv2d_104 (Conv2D)            (None, 4, 4, 16)     2320        ['max_pooling2d_32[0][0]']
#
#  batch_normalization_104 (Batch  (None, 4, 4, 16)    64          ['conv2d_104[0][0]']
#  Normalization)
#
#  activation_104 (Activation)    (None, 4, 4, 16)     0           ['batch_normalization_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 4, 4, 16)     2320        ['activation_104[0][0]']
#
#  batch_normalization_105 (Batch  (None, 4, 4, 16)    64          ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 4, 4, 16)     0           ['batch_normalization_105[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 4, 4, 32)     0           ['activation_105[0][0]',
#                                                                   'activation_104[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 4, 4, 16)     4624        ['concatenate_44[0][0]']
#
#  batch_normalization_106 (Batch  (None, 4, 4, 16)    64          ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 4, 4, 16)     0           ['batch_normalization_106[0][0]']
#
#  up_sampling2d_28 (UpSampling2D  (None, 8, 8, 16)    0           ['activation_106[0][0]']
#  )
#
#  concatenate_45 (Concatenate)   (None, 8, 8, 32)     0           ['up_sampling2d_28[0][0]',
#                                                                   'activation_103[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 8, 8, 16)     4624        ['concatenate_45[0][0]']
#
#  batch_normalization_107 (Batch  (None, 8, 8, 16)    64          ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 8, 8, 16)     0           ['batch_normalization_107[0][0]']
#
#  up_sampling2d_29 (UpSampling2D  (None, 16, 16, 16)  0           ['activation_107[0][0]']
#  )
#
#  concatenate_46 (Concatenate)   (None, 16, 16, 32)   0           ['up_sampling2d_29[0][0]',
#                                                                   'activation_102[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 16, 16, 16)   4624        ['concatenate_46[0][0]']
#
#  batch_normalization_108 (Batch  (None, 16, 16, 16)  64          ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 16, 16, 16)   0           ['batch_normalization_108[0][0]']
#
#  up_sampling2d_30 (UpSampling2D  (None, 32, 32, 16)  0           ['activation_108[0][0]']
#  )
#
#  concatenate_47 (Concatenate)   (None, 32, 32, 32)   0           ['up_sampling2d_30[0][0]',
#                                                                   'activation_101[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 32, 32, 16)   4624        ['concatenate_47[0][0]']
#
#  batch_normalization_109 (Batch  (None, 32, 32, 16)  64          ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_109[0][0]']
#
#  up_sampling2d_31 (UpSampling2D  (None, 64, 64, 16)  0           ['activation_109[0][0]']
#  )
#
#  concatenate_48 (Concatenate)   (None, 64, 64, 32)   0           ['up_sampling2d_31[0][0]',
#                                                                   'activation_100[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 64, 64, 16)   4624        ['concatenate_48[0][0]']
#
#  batch_normalization_110 (Batch  (None, 64, 64, 16)  64          ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_110 (Activation)    (None, 64, 64, 16)   0           ['batch_normalization_110[0][0]']
#
#  up_sampling2d_32 (UpSampling2D  (None, 128, 128, 16  0          ['activation_110[0][0]']
#  )                              )
#
#  concatenate_49 (Concatenate)   (None, 128, 128, 32  0           ['up_sampling2d_32[0][0]',
#                                 )                                 'activation_99[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 128, 128, 64  18496       ['concatenate_49[0][0]']
#                                 )
#
#  batch_normalization_111 (Batch  (None, 128, 128, 64  256        ['conv2d_111[0][0]']
#  Normalization)                 )
#
#  activation_111 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_111[0][0]']
#                                 )
#
#  add_10 (Add)                   (None, 128, 128, 64  0           ['activation_111[0][0]',
#                                 )                                 'activation_98[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 64, 64, 1)    577         ['add_9[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 32, 32, 1)    577         ['add_8[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 16, 16, 1)    577         ['add_7[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 8, 8, 1)      577         ['add_6[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 4, 4, 1)      577         ['add_5[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 128, 128, 1)  577         ['add_10[0][0]']
#
#  up_sampling2d_33 (UpSampling2D  (None, 128, 128, 1)  0          ['conv2d_113[0][0]']
#  )
#
#  up_sampling2d_34 (UpSampling2D  (None, 128, 128, 1)  0          ['conv2d_114[0][0]']
#  )
#
#  up_sampling2d_35 (UpSampling2D  (None, 128, 128, 1)  0          ['conv2d_115[0][0]']
#  )
#
#  up_sampling2d_36 (UpSampling2D  (None, 128, 128, 1)  0          ['conv2d_116[0][0]']
#  )
#
#  up_sampling2d_37 (UpSampling2D  (None, 128, 128, 1)  0          ['conv2d_117[0][0]']
#  )
#
#  concatenate_50 (Concatenate)   (None, 128, 128, 6)  0           ['conv2d_112[0][0]',
#                                                                   'up_sampling2d_33[0][0]',
#                                                                   'up_sampling2d_34[0][0]',
#                                                                   'up_sampling2d_35[0][0]',
#                                                                   'up_sampling2d_36[0][0]',
#                                                                   'up_sampling2d_37[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 128, 128, 1)  55          ['concatenate_50[0][0]']
#
#  activation_112 (Activation)    (None, 128, 128, 1)  0           ['conv2d_118[0][0]']
#
#  activation_113 (Activation)    (None, 128, 128, 1)  0           ['conv2d_112[0][0]']
#
#  activation_114 (Activation)    (None, 128, 128, 1)  0           ['up_sampling2d_33[0][0]']
#
#  activation_115 (Activation)    (None, 128, 128, 1)  0           ['up_sampling2d_34[0][0]']
#
#  activation_116 (Activation)    (None, 128, 128, 1)  0           ['up_sampling2d_35[0][0]']
#
#  activation_117 (Activation)    (None, 128, 128, 1)  0           ['up_sampling2d_36[0][0]']
#
#  activation_118 (Activation)    (None, 128, 128, 1)  0           ['up_sampling2d_37[0][0]']
#
# ==================================================================================================
# Total params: 1,135,773
# Trainable params: 1,130,077
# Non-trainable params: 5,696
# __________________________________________________________________________________________________

# %%
import tensorflow.keras.backend as K

def jaccard_loss(y_true, y_pred, smooth=1e-7):
    y_true = K.cast(y_true, dtype='float32')  # Cast y_true to float32
    intersection = K.sum(y_true * y_pred, axis=(1, 2, 3))
    union = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3)) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    return 1 - jaccard

# %%
from keras import backend as K
K.clear_session()
metrics = ["accuracy",
           tf.keras.metrics.AUC(),
           tf.keras.metrics.SensitivityAtSpecificity(0.5),
           tf.keras.metrics.SpecificityAtSensitivity(0.5),
           tf.keras.metrics.MeanIoU(num_classes=2)]  # Use MeanIoU as the Jaccard Index metric
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=metrics)  # Use custom Jaccard loss

gc.collect()
# Out:
# 1139

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  9232        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 16)   2320        ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 16)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 16)  0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 16)   2320        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 16)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 16)   2320        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 16, 16, 16)   0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 16)    0           ['activation_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 16)     2320        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 16)    64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 8, 8, 16)     0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 16)    0           ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 4, 4, 16)     2320        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4, 4, 16)    64          ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 4, 4, 16)     0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 4, 4, 16)     2320        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 4, 4, 16)    64          ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 4, 4, 16)     0           ['batch_normalization_7[0][0]']
#
#  concatenate (Concatenate)      (None, 4, 4, 32)     0           ['activation_7[0][0]',
#                                                                   'activation_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 16)     4624        ['concatenate[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 4, 4, 16)    64          ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 4, 4, 16)     0           ['batch_normalization_8[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 8, 8, 16)     0           ['activation_8[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 32)     0           ['up_sampling2d[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 16)     4624        ['concatenate_1[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 16)    64          ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 8, 8, 16)     0           ['batch_normalization_9[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 16)  0           ['activation_9[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 16, 16, 32)   0           ['up_sampling2d_1[0][0]',
#                                                                   'activation_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 16)   4624        ['concatenate_2[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 16)  64          ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_10[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 16)  0           ['activation_10[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 32)   0           ['up_sampling2d_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 16)   4624        ['concatenate_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_11[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 16)  0           ['activation_11[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 32)   0           ['up_sampling2d_3[0][0]',
#                                                                   'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 16)   4624        ['concatenate_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 16)  64          ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_12[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 16  0          ['activation_12[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 32  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 64  18496       ['concatenate_5[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 64  256        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  activation_13 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  add (Add)                      (None, 128, 128, 64  0           ['activation_13[0][0]',
#                                 )                                 'activation[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)  0           ['add[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   36928       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 16)   9232        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 16)   0           ['batch_normalization_15[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 16)  0           ['activation_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 16)   2320        ['max_pooling2d_6[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 16)  64          ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_16[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 16)  0           ['activation_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 16)   2320        ['max_pooling2d_7[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_17[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 16)    0           ['activation_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 8, 8, 16)    64          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_18[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 4, 4, 16)    0           ['activation_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 4, 4, 16)     2320        ['max_pooling2d_9[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 4, 4, 16)    64          ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 4, 4, 16)     2320        ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 4, 4, 16)    64          ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_20[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 4, 4, 32)     0           ['activation_20[0][0]',
#                                                                   'activation_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 4, 4, 16)     4624        ['concatenate_6[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 4, 4, 16)    64          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_21[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 8, 8, 16)    0           ['activation_21[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 8, 8, 32)     0           ['up_sampling2d_5[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 16)     4624        ['concatenate_7[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 16)    64          ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_22[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 16, 16, 16)  0           ['activation_22[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 16, 16, 32)   0           ['up_sampling2d_6[0][0]',
#                                                                   'activation_17[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 16)   4624        ['concatenate_8[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 16)  64          ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_23[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 32, 32, 16)  0           ['activation_23[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 32)   0           ['up_sampling2d_7[0][0]',
#                                                                   'activation_16[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 16)   4624        ['concatenate_9[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 16)  64          ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_24[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 64, 64, 16)  0           ['activation_24[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 64, 64, 32)   0           ['up_sampling2d_8[0][0]',
#                                                                   'activation_15[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 64)   18496       ['concatenate_10[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_25[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 64)   0           ['activation_25[0][0]',
#                                                                   'activation_14[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 32, 32, 64)  0           ['add_1[0][0]']
#  )
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 64)   36928       ['max_pooling2d_10[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 16)   9232        ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 16)  64          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_27[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 16, 16, 16)  0           ['activation_27[0][0]']
#  )
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 16)   2320        ['max_pooling2d_11[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 16)  64          ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_28[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 8, 8, 16)    0           ['activation_28[0][0]']
#  )
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_12[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 16)    64          ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 4, 4, 16)    0           ['activation_29[0][0]']
#  )
#
#  conv2d_30 (Conv2D)             (None, 4, 4, 16)     2320        ['max_pooling2d_13[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 4, 4, 16)    64          ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 4, 4, 16)     2320        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 4, 4, 16)    64          ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_31[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 4, 4, 32)     0           ['activation_31[0][0]',
#                                                                   'activation_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 4, 4, 16)     4624        ['concatenate_11[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 4, 4, 16)    64          ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_32[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 8, 8, 16)    0           ['activation_32[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 8, 8, 32)     0           ['up_sampling2d_9[0][0]',
#                                                                   'activation_29[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 16)     4624        ['concatenate_12[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 16)    64          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_33[0][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 16, 16, 16)  0           ['activation_33[0][0]']
#  )
#
#  concatenate_13 (Concatenate)   (None, 16, 16, 32)   0           ['up_sampling2d_10[0][0]',
#                                                                   'activation_28[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 16)   4624        ['concatenate_13[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 16)  64          ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_34[0][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 32, 32, 16)  0           ['activation_34[0][0]']
#  )
#
#  concatenate_14 (Concatenate)   (None, 32, 32, 32)   0           ['up_sampling2d_11[0][0]',
#                                                                   'activation_27[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 64)   18496       ['concatenate_14[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 32, 32, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_35[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 64)   0           ['activation_35[0][0]',
#                                                                   'activation_26[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 16, 16, 64)  0           ['add_2[0][0]']
#  )
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 64)   36928       ['max_pooling2d_14[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 64)  256         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 16)   9232        ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 16)  64          ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 16, 16, 16)   0           ['batch_normalization_37[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 8, 8, 16)    0           ['activation_37[0][0]']
#  )
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 16)     2320        ['max_pooling2d_15[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 16)    64          ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_38[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 4, 4, 16)    0           ['activation_38[0][0]']
#  )
#
#  conv2d_39 (Conv2D)             (None, 4, 4, 16)     2320        ['max_pooling2d_16[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 4, 4, 16)    64          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 4, 4, 16)     2320        ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 4, 4, 16)    64          ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_40[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 4, 4, 32)     0           ['activation_40[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 4, 4, 16)     4624        ['concatenate_15[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 4, 4, 16)    64          ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 4, 4, 16)     0           ['batch_normalization_41[0][0]']
#
#  up_sampling2d_12 (UpSampling2D  (None, 8, 8, 16)    0           ['activation_41[0][0]']
#  )
#
#  concatenate_16 (Concatenate)   (None, 8, 8, 32)     0           ['up_sampling2d_12[0][0]',
#                                                                   'activation_38[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 16)     4624        ['concatenate_16[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 8, 16)    64          ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_42[0][0]']
#
#  up_sampling2d_13 (UpSampling2D  (None, 16, 16, 16)  0           ['activation_42[0][0]']
#  )
#
#  concatenate_17 (Concatenate)   (None, 16, 16, 32)   0           ['up_sampling2d_13[0][0]',
#                                                                   'activation_37[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 64)   18496       ['concatenate_17[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 64)  256         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_43[0][0]']
#
#  add_3 (Add)                    (None, 16, 16, 64)   0           ['activation_43[0][0]',
#                                                                   'activation_36[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 8, 8, 64)    0           ['add_3[0][0]']
#  )
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 64)     36928       ['max_pooling2d_17[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 8, 64)    256         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 16)     9232        ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 8, 16)    64          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 16)     2320        ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 8, 8, 16)    64          ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 8, 8, 16)     0           ['batch_normalization_46[0][0]']
#
# ...
#
#  max_pooling2d_31 (MaxPooling2D  (None, 8, 8, 16)    0           ['activation_102[0][0]']
#  )
#
#  conv2d_103 (Conv2D)            (None, 8, 8, 16)     2320        ['max_pooling2d_31[0][0]']
#
#  batch_normalization_103 (Batch  (None, 8, 8, 16)    64          ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 8, 8, 16)     0           ['batch_normalization_103[0][0]']
#
#  max_pooling2d_32 (MaxPooling2D  (None, 4, 4, 16)    0           ['activation_103[0][0]']
#  )
#
#  conv2d_104 (Conv2D)            (None, 4, 4, 16)     2320        ['max_pooling2d_32[0][0]']
#
#  batch_normalization_104 (Batch  (None, 4, 4, 16)    64          ['conv2d_104[0][0]']
#  Normalization)
#
#  activation_104 (Activation)    (None, 4, 4, 16)     0           ['batch_normalization_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 4, 4, 16)     2320        ['activation_104[0][0]']
#
#  batch_normalization_105 (Batch  (None, 4, 4, 16)    64          ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 4, 4, 16)     0           ['batch_normalization_105[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 4, 4, 32)     0           ['activation_105[0][0]',
#                                                                   'activation_104[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 4, 4, 16)     4624        ['concatenate_44[0][0]']
#
#  batch_normalization_106 (Batch  (None, 4, 4, 16)    64          ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 4, 4, 16)     0           ['batch_normalization_106[0][0]']
#
#  up_sampling2d_28 (UpSampling2D  (None, 8, 8, 16)    0           ['activation_106[0][0]']
#  )
#
#  concatenate_45 (Concatenate)   (None, 8, 8, 32)     0           ['up_sampling2d_28[0][0]',
#                                                                   'activation_103[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 8, 8, 16)     4624        ['concatenate_45[0][0]']
#
#  batch_normalization_107 (Batch  (None, 8, 8, 16)    64          ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 8, 8, 16)     0           ['batch_normalization_107[0][0]']
#
#  up_sampling2d_29 (UpSampling2D  (None, 16, 16, 16)  0           ['activation_107[0][0]']
#  )
#
#  concatenate_46 (Concatenate)   (None, 16, 16, 32)   0           ['up_sampling2d_29[0][0]',
#                                                                   'activation_102[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 16, 16, 16)   4624        ['concatenate_46[0][0]']
#
#  batch_normalization_108 (Batch  (None, 16, 16, 16)  64          ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_108 (Activation)    (None, 16, 16, 16)   0           ['batch_normalization_108[0][0]']
#
#  up_sampling2d_30 (UpSampling2D  (None, 32, 32, 16)  0           ['activation_108[0][0]']
#  )
#
#  concatenate_47 (Concatenate)   (None, 32, 32, 32)   0           ['up_sampling2d_30[0][0]',
#                                                                   'activation_101[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 32, 32, 16)   4624        ['concatenate_47[0][0]']
#
#  batch_normalization_109 (Batch  (None, 32, 32, 16)  64          ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_109[0][0]']
#
#  up_sampling2d_31 (UpSampling2D  (None, 64, 64, 16)  0           ['activation_109[0][0]']
#  )
#
#  concatenate_48 (Concatenate)   (None, 64, 64, 32)   0           ['up_sampling2d_31[0][0]',
#                                                                   'activation_100[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 64, 64, 16)   4624        ['concatenate_48[0][0]']
#
#  batch_normalization_110 (Batch  (None, 64, 64, 16)  64          ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_110 (Activation)    (None, 64, 64, 16)   0           ['batch_normalization_110[0][0]']
#
#  up_sampling2d_32 (UpSampling2D  (None, 128, 128, 16  0          ['activation_110[0][0]']
#  )                              )
#
#  concatenate_49 (Concatenate)   (None, 128, 128, 32  0           ['up_sampling2d_32[0][0]',
#                                 )                                 'activation_99[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 128, 128, 64  18496       ['concatenate_49[0][0]']
#                                 )
#
#  batch_normalization_111 (Batch  (None, 128, 128, 64  256        ['conv2d_111[0][0]']
#  Normalization)                 )
#
#  activation_111 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_111[0][0]']
#                                 )
#
#  add_10 (Add)                   (None, 128, 128, 64  0           ['activation_111[0][0]',
#                                 )                                 'activation_98[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 64, 64, 1)    577         ['add_9[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 32, 32, 1)    577         ['add_8[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 16, 16, 1)    577         ['add_7[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 8, 8, 1)      577         ['add_6[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 4, 4, 1)      577         ['add_5[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 128, 128, 1)  577         ['add_10[0][0]']
#
#  up_sampling2d_33 (UpSampling2D  (None, 128, 128, 1)  0          ['conv2d_113[0][0]']
#  )
#
#  up_sampling2d_34 (UpSampling2D  (None, 128, 128, 1)  0          ['conv2d_114[0][0]']
#  )
#
#  up_sampling2d_35 (UpSampling2D  (None, 128, 128, 1)  0          ['conv2d_115[0][0]']
#  )
#
#  up_sampling2d_36 (UpSampling2D  (None, 128, 128, 1)  0          ['conv2d_116[0][0]']
#  )
#
#  up_sampling2d_37 (UpSampling2D  (None, 128, 128, 1)  0          ['conv2d_117[0][0]']
#  )
#
#  concatenate_50 (Concatenate)   (None, 128, 128, 6)  0           ['conv2d_112[0][0]',
#                                                                   'up_sampling2d_33[0][0]',
#                                                                   'up_sampling2d_34[0][0]',
#                                                                   'up_sampling2d_35[0][0]',
#                                                                   'up_sampling2d_36[0][0]',
#                                                                   'up_sampling2d_37[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 128, 128, 1)  55          ['concatenate_50[0][0]']
#
#  activation_112 (Activation)    (None, 128, 128, 1)  0           ['conv2d_118[0][0]']
#
#  activation_113 (Activation)    (None, 128, 128, 1)  0           ['conv2d_112[0][0]']
#
#  activation_114 (Activation)    (None, 128, 128, 1)  0           ['up_sampling2d_33[0][0]']
#
#  activation_115 (Activation)    (None, 128, 128, 1)  0           ['up_sampling2d_34[0][0]']
#
#  activation_116 (Activation)    (None, 128, 128, 1)  0           ['up_sampling2d_35[0][0]']
#
#  activation_117 (Activation)    (None, 128, 128, 1)  0           ['up_sampling2d_36[0][0]']
#
#  activation_118 (Activation)    (None, 128, 128, 1)  0           ['up_sampling2d_37[0][0]']
#
# ==================================================================================================
# Total params: 1,135,773
# Trainable params: 1,130,077
# Non-trainable params: 5,696
# __________________________________________________________________________________________________

# %%
# Define callbacks
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-Unet.h5', verbose=1, save_best_only=True, save_weights_only=True),
]

# %%
results = model.fit(lung_train, infect_train, batch_size=8, epochs=50, callbacks=[callbacks], validation_data=(lung_test, infect_test), use_multiprocessing=True)
# Out:
# Epoch 1/50
# 396/396 [==============================] - ETA: 0s - loss: 0.2418 - activation_112_loss: 0.0461 - activation_113_loss: 0.0240 - activation_114_loss: 0.0206 - activation_115_loss: 0.0212 - activation_116_loss: 0.0390 - activation_117_loss: 0.0290 - activation_118_loss: 0.0618 - activation_112_accuracy: 0.9831 - activation_112_auc: 0.9580 - activation_112_sensitivity_at_specificity: 0.9793 - activation_112_specificity_at_sensitivity: 0.9836 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9936 - activation_113_auc: 0.9669 - activation_113_sensitivity_at_specificity: 0.9796 - activation_113_specificity_at_sensitivity: 0.9948 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9946 - activation_114_auc: 0.9211 - activation_114_sensitivity_at_specificity: 0.8667 - activation_114_specificity_at_sensitivity: 0.9953 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9940 - activation_115_auc: 0.9450 - activation_115_sensitivity_at_specificity: 0.9280 - activation_115_specificity_at_sensitivity: 0.9923 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9893 - activation_116_auc: 0.9370 - activation_116_sensitivity_at_specificity: 0.9816 - activation_116_specificity_at_sensitivity: 0.9611 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9917 - activation_117_auc: 0.9013 - activation_117_sensitivity_at_specificity: 0.8679 - activation_117_specificity_at_sensitivity: 0.9769 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9771 - activation_118_auc: 0.8650 - activation_118_sensitivity_at_specificity: 0.9796 - activation_118_specificity_at_sensitivity: 0.8973 - activation_118_mean_io_u: 0.4967
# Epoch 1: val_loss improved from inf to 0.25054, saving model to model-Unet.h5
# 396/396 [==============================] - 142s 293ms/step - loss: 0.2418 - activation_112_loss: 0.0461 - activation_113_loss: 0.0240 - activation_114_loss: 0.0206 - activation_115_loss: 0.0212 - activation_116_loss: 0.0390 - activation_117_loss: 0.0290 - activation_118_loss: 0.0618 - activation_112_accuracy: 0.9831 - activation_112_auc: 0.9580 - activation_112_sensitivity_at_specificity: 0.9793 - activation_112_specificity_at_sensitivity: 0.9836 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9936 - activation_113_auc: 0.9669 - activation_113_sensitivity_at_specificity: 0.9796 - activation_113_specificity_at_sensitivity: 0.9948 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9946 - activation_114_auc: 0.9211 - activation_114_sensitivity_at_specificity: 0.8667 - activation_114_specificity_at_sensitivity: 0.9953 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9940 - activation_115_auc: 0.9450 - activation_115_sensitivity_at_specificity: 0.9280 - activation_115_specificity_at_sensitivity: 0.9923 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9893 - activation_116_auc: 0.9370 - activation_116_sensitivity_at_specificity: 0.9816 - activation_116_specificity_at_sensitivity: 0.9611 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9917 - activation_117_auc: 0.9013 - activation_117_sensitivity_at_specificity: 0.8679 - activation_117_specificity_at_sensitivity: 0.9769 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9771 - activation_118_auc: 0.8650 - activation_118_sensitivity_at_specificity: 0.9796 - activation_118_specificity_at_sensitivity: 0.8973 - activation_118_mean_io_u: 0.4967 - val_loss: 0.2505 - val_activation_112_loss: 0.0387 - val_activation_113_loss: 0.0397 - val_activation_114_loss: 0.0378 - val_activation_115_loss: 0.0328 - val_activation_116_loss: 0.0307 - val_activation_117_loss: 0.0356 - val_activation_118_loss: 0.0352 - val_activation_112_accuracy: 0.9906 - val_activation_112_auc: 0.7933 - val_activation_112_sensitivity_at_specificity: 0.6264 - val_activation_112_specificity_at_sensitivity: 0.9709 - val_activation_112_mean_io_u: 0.4967 - val_activation_113_accuracy: 0.9886 - val_activation_113_auc: 0.8066 - val_activation_113_sensitivity_at_specificity: 0.6536 - val_activation_113_specificity_at_sensitivity: 0.9714 - val_activation_113_mean_io_u: 0.4967 - val_activation_114_accuracy: 0.9912 - val_activation_114_auc: 0.7973 - val_activation_114_sensitivity_at_specificity: 0.6345 - val_activation_114_specificity_at_sensitivity: 0.9730 - val_activation_114_mean_io_u: 0.4967 - val_activation_115_accuracy: 0.9922 - val_activation_115_auc: 0.8275 - val_activation_115_sensitivity_at_specificity: 0.6987 - val_activation_115_specificity_at_sensitivity: 0.9699 - val_activation_115_mean_io_u: 0.4967 - val_activation_116_accuracy: 0.9931 - val_activation_116_auc: 0.8772 - val_activation_116_sensitivity_at_specificity: 0.8159 - val_activation_116_specificity_at_sensitivity: 0.9652 - val_activation_116_mean_io_u: 0.4967 - val_activation_117_accuracy: 0.9933 - val_activation_117_auc: 0.7356 - val_activation_117_sensitivity_at_specificity: 0.5170 - val_activation_117_specificity_at_sensitivity: 0.9470 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9933 - val_activation_118_auc: 0.7852 - val_activation_118_sensitivity_at_specificity: 0.7065 - val_activation_118_specificity_at_sensitivity: 0.8431 - val_activation_118_mean_io_u: 0.4967 - lr: 0.0010
# Epoch 2/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0912 - activation_112_loss: 0.0097 - activation_113_loss: 0.0087 - activation_114_loss: 0.0092 - activation_115_loss: 0.0109 - activation_116_loss: 0.0130 - activation_117_loss: 0.0162 - activation_118_loss: 0.0235 - activation_112_accuracy: 0.9963 - activation_112_auc: 0.9894 - activation_112_sensitivity_at_specificity: 0.9837 - activation_112_specificity_at_sensitivity: 0.9994 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9967 - activation_113_auc: 0.9920 - activation_113_sensitivity_at_specificity: 0.9879 - activation_113_specificity_at_sensitivity: 0.9996 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9965 - activation_114_auc: 0.9912 - activation_114_sensitivity_at_specificity: 0.9868 - activation_114_specificity_at_sensitivity: 0.9995 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9959 - activation_115_auc: 0.9900 - activation_115_sensitivity_at_specificity: 0.9867 - activation_115_specificity_at_sensitivity: 0.9991 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9952 - activation_116_auc: 0.9859 - activation_116_sensitivity_at_specificity: 0.9818 - activation_116_specificity_at_sensitivity: 0.9984 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9942 - activation_117_auc: 0.9808 - activation_117_sensitivity_at_specificity: 0.9792 - activation_117_specificity_at_sensitivity: 0.9964 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9572 - activation_118_sensitivity_at_specificity: 0.9660 - activation_118_specificity_at_sensitivity: 0.9852 - activation_118_mean_io_u: 0.4967
# Epoch 2: val_loss improved from 0.25054 to 0.08499, saving model to model-Unet.h5
# 396/396 [==============================] - 110s 278ms/step - loss: 0.0912 - activation_112_loss: 0.0097 - activation_113_loss: 0.0087 - activation_114_loss: 0.0092 - activation_115_loss: 0.0109 - activation_116_loss: 0.0130 - activation_117_loss: 0.0162 - activation_118_loss: 0.0235 - activation_112_accuracy: 0.9963 - activation_112_auc: 0.9894 - activation_112_sensitivity_at_specificity: 0.9837 - activation_112_specificity_at_sensitivity: 0.9994 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9967 - activation_113_auc: 0.9920 - activation_113_sensitivity_at_specificity: 0.9879 - activation_113_specificity_at_sensitivity: 0.9996 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9965 - activation_114_auc: 0.9912 - activation_114_sensitivity_at_specificity: 0.9868 - activation_114_specificity_at_sensitivity: 0.9995 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9959 - activation_115_auc: 0.9900 - activation_115_sensitivity_at_specificity: 0.9867 - activation_115_specificity_at_sensitivity: 0.9991 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9952 - activation_116_auc: 0.9859 - activation_116_sensitivity_at_specificity: 0.9818 - activation_116_specificity_at_sensitivity: 0.9984 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9942 - activation_117_auc: 0.9808 - activation_117_sensitivity_at_specificity: 0.9792 - activation_117_specificity_at_sensitivity: 0.9964 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9572 - activation_118_sensitivity_at_specificity: 0.9660 - activation_118_specificity_at_sensitivity: 0.9852 - activation_118_mean_io_u: 0.4967 - val_loss: 0.0850 - val_activation_112_loss: 0.0087 - val_activation_113_loss: 0.0071 - val_activation_114_loss: 0.0082 - val_activation_115_loss: 0.0098 - val_activation_116_loss: 0.0125 - val_activation_117_loss: 0.0156 - val_activation_118_loss: 0.0231 - val_activation_112_accuracy: 0.9966 - val_activation_112_auc: 0.9883 - val_activation_112_sensitivity_at_specificity: 0.9799 - val_activation_112_specificity_at_sensitivity: 0.9995 - val_activation_112_mean_io_u: 0.4967 - val_activation_113_accuracy: 0.9972 - val_activation_113_auc: 0.9953 - val_activation_113_sensitivity_at_specificity: 0.9930 - val_activation_113_specificity_at_sensitivity: 0.9998 - val_activation_113_mean_io_u: 0.4967 - val_activation_114_accuracy: 0.9968 - val_activation_114_auc: 0.9919 - val_activation_114_sensitivity_at_specificity: 0.9871 - val_activation_114_specificity_at_sensitivity: 0.9997 - val_activation_114_mean_io_u: 0.4967 - val_activation_115_accuracy: 0.9962 - val_activation_115_auc: 0.9888 - val_activation_115_sensitivity_at_specificity: 0.9824 - val_activation_115_specificity_at_sensitivity: 0.9994 - val_activation_115_mean_io_u: 0.4967 - val_activation_116_accuracy: 0.9953 - val_activation_116_auc: 0.9822 - val_activation_116_sensitivity_at_specificity: 0.9724 - val_activation_116_specificity_at_sensitivity: 0.9986 - val_activation_116_mean_io_u: 0.4967 - val_activation_117_accuracy: 0.9943 - val_activation_117_auc: 0.9731 - val_activation_117_sensitivity_at_specificity: 0.9604 - val_activation_117_specificity_at_sensitivity: 0.9971 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9933 - val_activation_118_auc: 0.9471 - val_activation_118_sensitivity_at_specificity: 0.9365 - val_activation_118_specificity_at_sensitivity: 0.9880 - val_activation_118_mean_io_u: 0.4967 - lr: 0.0010
# Epoch 3/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0798 - activation_112_loss: 0.0081 - activation_113_loss: 0.0072 - activation_114_loss: 0.0077 - activation_115_loss: 0.0090 - activation_116_loss: 0.0110 - activation_117_loss: 0.0146 - activation_118_loss: 0.0223 - activation_112_accuracy: 0.9969 - activation_112_auc: 0.9917 - activation_112_sensitivity_at_specificity: 0.9865 - activation_112_specificity_at_sensitivity: 0.9997 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9972 - activation_113_auc: 0.9944 - activation_113_sensitivity_at_specificity: 0.9912 - activation_113_specificity_at_sensitivity: 0.9998 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9970 - activation_114_auc: 0.9943 - activation_114_sensitivity_at_specificity: 0.9916 - activation_114_specificity_at_sensitivity: 0.9997 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9965 - activation_115_auc: 0.9925 - activation_115_sensitivity_at_specificity: 0.9892 - activation_115_specificity_at_sensitivity: 0.9995 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9958 - activation_116_auc: 0.9893 - activation_116_sensitivity_at_specificity: 0.9850 - activation_116_specificity_at_sensitivity: 0.9990 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9944 - activation_117_auc: 0.9849 - activation_117_sensitivity_at_specificity: 0.9827 - activation_117_specificity_at_sensitivity: 0.9973 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9635 - activation_118_sensitivity_at_specificity: 0.9702 - activation_118_specificity_at_sensitivity: 0.9872 - activation_118_mean_io_u: 0.4967
# Epoch 3: val_loss improved from 0.08499 to 0.07934, saving model to model-Unet.h5
# 396/396 [==============================] - 109s 274ms/step - loss: 0.0798 - activation_112_loss: 0.0081 - activation_113_loss: 0.0072 - activation_114_loss: 0.0077 - activation_115_loss: 0.0090 - activation_116_loss: 0.0110 - activation_117_loss: 0.0146 - activation_118_loss: 0.0223 - activation_112_accuracy: 0.9969 - activation_112_auc: 0.9917 - activation_112_sensitivity_at_specificity: 0.9865 - activation_112_specificity_at_sensitivity: 0.9997 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9972 - activation_113_auc: 0.9944 - activation_113_sensitivity_at_specificity: 0.9912 - activation_113_specificity_at_sensitivity: 0.9998 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9970 - activation_114_auc: 0.9943 - activation_114_sensitivity_at_specificity: 0.9916 - activation_114_specificity_at_sensitivity: 0.9997 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9965 - activation_115_auc: 0.9925 - activation_115_sensitivity_at_specificity: 0.9892 - activation_115_specificity_at_sensitivity: 0.9995 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9958 - activation_116_auc: 0.9893 - activation_116_sensitivity_at_specificity: 0.9850 - activation_116_specificity_at_sensitivity: 0.9990 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9944 - activation_117_auc: 0.9849 - activation_117_sensitivity_at_specificity: 0.9827 - activation_117_specificity_at_sensitivity: 0.9973 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9635 - activation_118_sensitivity_at_specificity: 0.9702 - activation_118_specificity_at_sensitivity: 0.9872 - activation_118_mean_io_u: 0.4967 - val_loss: 0.0793 - val_activation_112_loss: 0.0077 - val_activation_113_loss: 0.0068 - val_activation_114_loss: 0.0077 - val_activation_115_loss: 0.0090 - val_activation_116_loss: 0.0109 - val_activation_117_loss: 0.0149 - val_activation_118_loss: 0.0223 - val_activation_112_accuracy: 0.9969 - val_activation_112_auc: 0.9936 - val_activation_112_sensitivity_at_specificity: 0.9901 - val_activation_112_specificity_at_sensitivity: 0.9997 - val_activation_112_mean_io_u: 0.4967 - val_activation_113_accuracy: 0.9973 - val_activation_113_auc: 0.9958 - val_activation_113_sensitivity_at_specificity: 0.9938 - val_activation_113_specificity_at_sensitivity: 0.9998 - val_activation_113_mean_io_u: 0.4967 - val_activation_114_accuracy: 0.9970 - val_activation_114_auc: 0.9956 - val_activation_114_sensitivity_at_specificity: 0.9939 - val_activation_114_specificity_at_sensitivity: 0.9998 - val_activation_114_mean_io_u: 0.4967 - val_activation_115_accuracy: 0.9966 - val_activation_115_auc: 0.9921 - val_activation_115_sensitivity_at_specificity: 0.9885 - val_activation_115_specificity_at_sensitivity: 0.9996 - val_activation_115_mean_io_u: 0.4967 - val_activation_116_accuracy: 0.9958 - val_activation_116_auc: 0.9886 - val_activation_116_sensitivity_at_specificity: 0.9831 - val_activation_116_specificity_at_sensitivity: 0.9991 - val_activation_116_mean_io_u: 0.4967 - val_activation_117_accuracy: 0.9944 - val_activation_117_auc: 0.9791 - val_activation_117_sensitivity_at_specificity: 0.9703 - val_activation_117_specificity_at_sensitivity: 0.9972 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9933 - val_activation_118_auc: 0.9562 - val_activation_118_sensitivity_at_specificity: 0.9547 - val_activation_118_specificity_at_sensitivity: 0.9888 - val_activation_118_mean_io_u: 0.4967 - lr: 0.0010
# Epoch 4/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0712 - activation_112_loss: 0.0069 - activation_113_loss: 0.0061 - activation_114_loss: 0.0065 - activation_115_loss: 0.0075 - activation_116_loss: 0.0095 - activation_117_loss: 0.0133 - activation_118_loss: 0.0213 - activation_112_accuracy: 0.9973 - activation_112_auc: 0.9940 - activation_112_sensitivity_at_specificity: 0.9901 - activation_112_specificity_at_sensitivity: 0.9998 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9976 - activation_113_auc: 0.9961 - activation_113_sensitivity_at_specificity: 0.9940 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9974 - activation_114_auc: 0.9962 - activation_114_sensitivity_at_specificity: 0.9944 - activation_114_specificity_at_sensitivity: 0.9998 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9970 - activation_115_auc: 0.9952 - activation_115_sensitivity_at_specificity: 0.9932 - activation_115_specificity_at_sensitivity: 0.9997 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9962 - activation_116_auc: 0.9924 - activation_116_sensitivity_at_specificity: 0.9895 - activation_116_specificity_at_sensitivity: 0.9993 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9947 - activation_117_auc: 0.9889 - activation_117_sensitivity_at_specificity: 0.9880 - activation_117_specificity_at_sensitivity: 0.9978 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9698 - activation_118_sensitivity_at_specificity: 0.9776 - activation_118_specificity_at_sensitivity: 0.9883 - activation_118_mean_io_u: 0.4967
# Epoch 4: val_loss improved from 0.07934 to 0.07839, saving model to model-Unet.h5
# 396/396 [==============================] - 108s 273ms/step - loss: 0.0712 - activation_112_loss: 0.0069 - activation_113_loss: 0.0061 - activation_114_loss: 0.0065 - activation_115_loss: 0.0075 - activation_116_loss: 0.0095 - activation_117_loss: 0.0133 - activation_118_loss: 0.0213 - activation_112_accuracy: 0.9973 - activation_112_auc: 0.9940 - activation_112_sensitivity_at_specificity: 0.9901 - activation_112_specificity_at_sensitivity: 0.9998 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9976 - activation_113_auc: 0.9961 - activation_113_sensitivity_at_specificity: 0.9940 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9974 - activation_114_auc: 0.9962 - activation_114_sensitivity_at_specificity: 0.9944 - activation_114_specificity_at_sensitivity: 0.9998 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9970 - activation_115_auc: 0.9952 - activation_115_sensitivity_at_specificity: 0.9932 - activation_115_specificity_at_sensitivity: 0.9997 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9962 - activation_116_auc: 0.9924 - activation_116_sensitivity_at_specificity: 0.9895 - activation_116_specificity_at_sensitivity: 0.9993 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9947 - activation_117_auc: 0.9889 - activation_117_sensitivity_at_specificity: 0.9880 - activation_117_specificity_at_sensitivity: 0.9978 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9698 - activation_118_sensitivity_at_specificity: 0.9776 - activation_118_specificity_at_sensitivity: 0.9883 - activation_118_mean_io_u: 0.4967 - val_loss: 0.0784 - val_activation_112_loss: 0.0082 - val_activation_113_loss: 0.0069 - val_activation_114_loss: 0.0077 - val_activation_115_loss: 0.0090 - val_activation_116_loss: 0.0110 - val_activation_117_loss: 0.0142 - val_activation_118_loss: 0.0214 - val_activation_112_accuracy: 0.9966 - val_activation_112_auc: 0.9961 - val_activation_112_sensitivity_at_specificity: 0.9949 - val_activation_112_specificity_at_sensitivity: 0.9997 - val_activation_112_mean_io_u: 0.4967 - val_activation_113_accuracy: 0.9971 - val_activation_113_auc: 0.9979 - val_activation_113_sensitivity_at_specificity: 0.9977 - val_activation_113_specificity_at_sensitivity: 0.9999 - val_activation_113_mean_io_u: 0.4967 - val_activation_114_accuracy: 0.9967 - val_activation_114_auc: 0.9980 - val_activation_114_sensitivity_at_specificity: 0.9983 - val_activation_114_specificity_at_sensitivity: 0.9998 - val_activation_114_mean_io_u: 0.4967 - val_activation_115_accuracy: 0.9962 - val_activation_115_auc: 0.9961 - val_activation_115_sensitivity_at_specificity: 0.9957 - val_activation_115_specificity_at_sensitivity: 0.9996 - val_activation_115_mean_io_u: 0.4967 - val_activation_116_accuracy: 0.9955 - val_activation_116_auc: 0.9925 - val_activation_116_sensitivity_at_specificity: 0.9906 - val_activation_116_specificity_at_sensitivity: 0.9992 - val_activation_116_mean_io_u: 0.4967 - val_activation_117_accuracy: 0.9944 - val_activation_117_auc: 0.9905 - val_activation_117_sensitivity_at_specificity: 0.9922 - val_activation_117_specificity_at_sensitivity: 0.9976 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9932 - val_activation_118_auc: 0.9751 - val_activation_118_sensitivity_at_specificity: 0.9885 - val_activation_118_specificity_at_sensitivity: 0.9895 - val_activation_118_mean_io_u: 0.4967 - lr: 0.0010
# Epoch 5/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0675 - activation_112_loss: 0.0064 - activation_113_loss: 0.0057 - activation_114_loss: 0.0061 - activation_115_loss: 0.0069 - activation_116_loss: 0.0088 - activation_117_loss: 0.0127 - activation_118_loss: 0.0209 - activation_112_accuracy: 0.9974 - activation_112_auc: 0.9948 - activation_112_sensitivity_at_specificity: 0.9915 - activation_112_specificity_at_sensitivity: 0.9998 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9977 - activation_113_auc: 0.9968 - activation_113_sensitivity_at_specificity: 0.9951 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9975 - activation_114_auc: 0.9970 - activation_114_sensitivity_at_specificity: 0.9957 - activation_114_specificity_at_sensitivity: 0.9999 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9972 - activation_115_auc: 0.9961 - activation_115_sensitivity_at_specificity: 0.9946 - activation_115_specificity_at_sensitivity: 0.9998 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9964 - activation_116_auc: 0.9937 - activation_116_sensitivity_at_specificity: 0.9912 - activation_116_specificity_at_sensitivity: 0.9994 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9948 - activation_117_auc: 0.9904 - activation_117_sensitivity_at_specificity: 0.9898 - activation_117_specificity_at_sensitivity: 0.9980 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9721 - activation_118_sensitivity_at_specificity: 0.9800 - activation_118_specificity_at_sensitivity: 0.9887 - activation_118_mean_io_u: 0.4967
# Epoch 5: val_loss improved from 0.07839 to 0.07353, saving model to model-Unet.h5
# 396/396 [==============================] - 109s 275ms/step - loss: 0.0675 - activation_112_loss: 0.0064 - activation_113_loss: 0.0057 - activation_114_loss: 0.0061 - activation_115_loss: 0.0069 - activation_116_loss: 0.0088 - activation_117_loss: 0.0127 - activation_118_loss: 0.0209 - activation_112_accuracy: 0.9974 - activation_112_auc: 0.9948 - activation_112_sensitivity_at_specificity: 0.9915 - activation_112_specificity_at_sensitivity: 0.9998 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9977 - activation_113_auc: 0.9968 - activation_113_sensitivity_at_specificity: 0.9951 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9975 - activation_114_auc: 0.9970 - activation_114_sensitivity_at_specificity: 0.9957 - activation_114_specificity_at_sensitivity: 0.9999 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9972 - activation_115_auc: 0.9961 - activation_115_sensitivity_at_specificity: 0.9946 - activation_115_specificity_at_sensitivity: 0.9998 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9964 - activation_116_auc: 0.9937 - activation_116_sensitivity_at_specificity: 0.9912 - activation_116_specificity_at_sensitivity: 0.9994 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9948 - activation_117_auc: 0.9904 - activation_117_sensitivity_at_specificity: 0.9898 - activation_117_specificity_at_sensitivity: 0.9980 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9721 - activation_118_sensitivity_at_specificity: 0.9800 - activation_118_specificity_at_sensitivity: 0.9887 - activation_118_mean_io_u: 0.4967 - val_loss: 0.0735 - val_activation_112_loss: 0.0078 - val_activation_113_loss: 0.0064 - val_activation_114_loss: 0.0067 - val_activation_115_loss: 0.0080 - val_activation_116_loss: 0.0100 - val_activation_117_loss: 0.0135 - val_activation_118_loss: 0.0211 - val_activation_112_accuracy: 0.9969 - val_activation_112_auc: 0.9937 - val_activation_112_sensitivity_at_specificity: 0.9897 - val_activation_112_specificity_at_sensitivity: 0.9997 - val_activation_112_mean_io_u: 0.4967 - val_activation_113_accuracy: 0.9973 - val_activation_113_auc: 0.9974 - val_activation_113_sensitivity_at_specificity: 0.9965 - val_activation_113_specificity_at_sensitivity: 0.9998 - val_activation_113_mean_io_u: 0.4967 - val_activation_114_accuracy: 0.9972 - val_activation_114_auc: 0.9973 - val_activation_114_sensitivity_at_specificity: 0.9966 - val_activation_114_specificity_at_sensitivity: 0.9998 - val_activation_114_mean_io_u: 0.4967 - val_activation_115_accuracy: 0.9967 - val_activation_115_auc: 0.9959 - val_activation_115_sensitivity_at_specificity: 0.9946 - val_activation_115_specificity_at_sensitivity: 0.9996 - val_activation_115_mean_io_u: 0.4967 - val_activation_116_accuracy: 0.9959 - val_activation_116_auc: 0.9934 - val_activation_116_sensitivity_at_specificity: 0.9916 - val_activation_116_specificity_at_sensitivity: 0.9991 - val_activation_116_mean_io_u: 0.4967 - val_activation_117_accuracy: 0.9946 - val_activation_117_auc: 0.9883 - val_activation_117_sensitivity_at_specificity: 0.9869 - val_activation_117_specificity_at_sensitivity: 0.9976 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9932 - val_activation_118_auc: 0.9731 - val_activation_118_sensitivity_at_specificity: 0.9827 - val_activation_118_specificity_at_sensitivity: 0.9901 - val_activation_118_mean_io_u: 0.4967 - lr: 0.0010
# Epoch 6/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0647 - activation_112_loss: 0.0059 - activation_113_loss: 0.0053 - activation_114_loss: 0.0056 - activation_115_loss: 0.0065 - activation_116_loss: 0.0084 - activation_117_loss: 0.0123 - activation_118_loss: 0.0207 - activation_112_accuracy: 0.9976 - activation_112_auc: 0.9960 - activation_112_sensitivity_at_specificity: 0.9936 - activation_112_specificity_at_sensitivity: 0.9999 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9978 - activation_113_auc: 0.9973 - activation_113_sensitivity_at_specificity: 0.9959 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9977 - activation_114_auc: 0.9978 - activation_114_sensitivity_at_specificity: 0.9970 - activation_114_specificity_at_sensitivity: 0.9999 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9973 - activation_115_auc: 0.9968 - activation_115_sensitivity_at_specificity: 0.9957 - activation_115_specificity_at_sensitivity: 0.9998 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9965 - activation_116_auc: 0.9947 - activation_116_sensitivity_at_specificity: 0.9929 - activation_116_specificity_at_sensitivity: 0.9995 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9949 - activation_117_auc: 0.9910 - activation_117_sensitivity_at_specificity: 0.9904 - activation_117_specificity_at_sensitivity: 0.9981 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9729 - activation_118_sensitivity_at_specificity: 0.9804 - activation_118_specificity_at_sensitivity: 0.9895 - activation_118_mean_io_u: 0.4967
# Epoch 6: val_loss improved from 0.07353 to 0.06884, saving model to model-Unet.h5
# 396/396 [==============================] - 106s 268ms/step - loss: 0.0647 - activation_112_loss: 0.0059 - activation_113_loss: 0.0053 - activation_114_loss: 0.0056 - activation_115_loss: 0.0065 - activation_116_loss: 0.0084 - activation_117_loss: 0.0123 - activation_118_loss: 0.0207 - activation_112_accuracy: 0.9976 - activation_112_auc: 0.9960 - activation_112_sensitivity_at_specificity: 0.9936 - activation_112_specificity_at_sensitivity: 0.9999 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9978 - activation_113_auc: 0.9973 - activation_113_sensitivity_at_specificity: 0.9959 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9977 - activation_114_auc: 0.9978 - activation_114_sensitivity_at_specificity: 0.9970 - activation_114_specificity_at_sensitivity: 0.9999 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9973 - activation_115_auc: 0.9968 - activation_115_sensitivity_at_specificity: 0.9957 - activation_115_specificity_at_sensitivity: 0.9998 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9965 - activation_116_auc: 0.9947 - activation_116_sensitivity_at_specificity: 0.9929 - activation_116_specificity_at_sensitivity: 0.9995 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9949 - activation_117_auc: 0.9910 - activation_117_sensitivity_at_specificity: 0.9904 - activation_117_specificity_at_sensitivity: 0.9981 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9729 - activation_118_sensitivity_at_specificity: 0.9804 - activation_118_specificity_at_sensitivity: 0.9895 - activation_118_mean_io_u: 0.4967 - val_loss: 0.0688 - val_activation_112_loss: 0.0067 - val_activation_113_loss: 0.0062 - val_activation_114_loss: 0.0064 - val_activation_115_loss: 0.0071 - val_activation_116_loss: 0.0090 - val_activation_117_loss: 0.0126 - val_activation_118_loss: 0.0208 - val_activation_112_accuracy: 0.9972 - val_activation_112_auc: 0.9947 - val_activation_112_sensitivity_at_specificity: 0.9913 - val_activation_112_specificity_at_sensitivity: 0.9998 - val_activation_112_mean_io_u: 0.4967 - val_activation_113_accuracy: 0.9975 - val_activation_113_auc: 0.9965 - val_activation_113_sensitivity_at_specificity: 0.9946 - val_activation_113_specificity_at_sensitivity: 0.9999 - val_activation_113_mean_io_u: 0.4967 - val_activation_114_accuracy: 0.9974 - val_activation_114_auc: 0.9967 - val_activation_114_sensitivity_at_specificity: 0.9952 - val_activation_114_specificity_at_sensitivity: 0.9999 - val_activation_114_mean_io_u: 0.4967 - val_activation_115_accuracy: 0.9970 - val_activation_115_auc: 0.9972 - val_activation_115_sensitivity_at_specificity: 0.9968 - val_activation_115_specificity_at_sensitivity: 0.9998 - val_activation_115_mean_io_u: 0.4967 - val_activation_116_accuracy: 0.9962 - val_activation_116_auc: 0.9957 - val_activation_116_sensitivity_at_specificity: 0.9954 - val_activation_116_specificity_at_sensitivity: 0.9994 - val_activation_116_mean_io_u: 0.4967 - val_activation_117_accuracy: 0.9947 - val_activation_117_auc: 0.9923 - val_activation_117_sensitivity_at_specificity: 0.9935 - val_activation_117_specificity_at_sensitivity: 0.9979 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9933 - val_activation_118_auc: 0.9761 - val_activation_118_sensitivity_at_specificity: 0.9880 - val_activation_118_specificity_at_sensitivity: 0.9890 - val_activation_118_mean_io_u: 0.4967 - lr: 0.0010
# Epoch 7/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0626 - activation_112_loss: 0.0056 - activation_113_loss: 0.0051 - activation_114_loss: 0.0053 - activation_115_loss: 0.0062 - activation_116_loss: 0.0081 - activation_117_loss: 0.0119 - activation_118_loss: 0.0205 - activation_112_accuracy: 0.9977 - activation_112_auc: 0.9962 - activation_112_sensitivity_at_specificity: 0.9938 - activation_112_specificity_at_sensitivity: 0.9999 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9979 - activation_113_auc: 0.9976 - activation_113_sensitivity_at_specificity: 0.9964 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9978 - activation_114_auc: 0.9979 - activation_114_sensitivity_at_specificity: 0.9971 - activation_114_specificity_at_sensitivity: 0.9999 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9975 - activation_115_auc: 0.9971 - activation_115_sensitivity_at_specificity: 0.9961 - activation_115_specificity_at_sensitivity: 0.9998 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9967 - activation_116_auc: 0.9951 - activation_116_sensitivity_at_specificity: 0.9934 - activation_116_specificity_at_sensitivity: 0.9995 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9950 - activation_117_auc: 0.9916 - activation_117_sensitivity_at_specificity: 0.9910 - activation_117_specificity_at_sensitivity: 0.9983 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9745 - activation_118_sensitivity_at_specificity: 0.9828 - activation_118_specificity_at_sensitivity: 0.9894 - activation_118_mean_io_u: 0.4967
# Epoch 7: val_loss improved from 0.06884 to 0.06721, saving model to model-Unet.h5
# 396/396 [==============================] - 105s 266ms/step - loss: 0.0626 - activation_112_loss: 0.0056 - activation_113_loss: 0.0051 - activation_114_loss: 0.0053 - activation_115_loss: 0.0062 - activation_116_loss: 0.0081 - activation_117_loss: 0.0119 - activation_118_loss: 0.0205 - activation_112_accuracy: 0.9977 - activation_112_auc: 0.9962 - activation_112_sensitivity_at_specificity: 0.9938 - activation_112_specificity_at_sensitivity: 0.9999 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9979 - activation_113_auc: 0.9976 - activation_113_sensitivity_at_specificity: 0.9964 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9978 - activation_114_auc: 0.9979 - activation_114_sensitivity_at_specificity: 0.9971 - activation_114_specificity_at_sensitivity: 0.9999 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9975 - activation_115_auc: 0.9971 - activation_115_sensitivity_at_specificity: 0.9961 - activation_115_specificity_at_sensitivity: 0.9998 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9967 - activation_116_auc: 0.9951 - activation_116_sensitivity_at_specificity: 0.9934 - activation_116_specificity_at_sensitivity: 0.9995 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9950 - activation_117_auc: 0.9916 - activation_117_sensitivity_at_specificity: 0.9910 - activation_117_specificity_at_sensitivity: 0.9983 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9745 - activation_118_sensitivity_at_specificity: 0.9828 - activation_118_specificity_at_sensitivity: 0.9894 - activation_118_mean_io_u: 0.4967 - val_loss: 0.0672 - val_activation_112_loss: 0.0061 - val_activation_113_loss: 0.0057 - val_activation_114_loss: 0.0058 - val_activation_115_loss: 0.0068 - val_activation_116_loss: 0.0089 - val_activation_117_loss: 0.0126 - val_activation_118_loss: 0.0214 - val_activation_112_accuracy: 0.9975 - val_activation_112_auc: 0.9943 - val_activation_112_sensitivity_at_specificity: 0.9902 - val_activation_112_specificity_at_sensitivity: 0.9999 - val_activation_112_mean_io_u: 0.4967 - val_activation_113_accuracy: 0.9977 - val_activation_113_auc: 0.9955 - val_activation_113_sensitivity_at_specificity: 0.9924 - val_activation_113_specificity_at_sensitivity: 0.9999 - val_activation_113_mean_io_u: 0.4967 - val_activation_114_accuracy: 0.9976 - val_activation_114_auc: 0.9965 - val_activation_114_sensitivity_at_specificity: 0.9945 - val_activation_114_specificity_at_sensitivity: 0.9999 - val_activation_114_mean_io_u: 0.4967 - val_activation_115_accuracy: 0.9973 - val_activation_115_auc: 0.9955 - val_activation_115_sensitivity_at_specificity: 0.9930 - val_activation_115_specificity_at_sensitivity: 0.9998 - val_activation_115_mean_io_u: 0.4967 - val_activation_116_accuracy: 0.9963 - val_activation_116_auc: 0.9938 - val_activation_116_sensitivity_at_specificity: 0.9913 - val_activation_116_specificity_at_sensitivity: 0.9994 - val_activation_116_mean_io_u: 0.4967 - val_activation_117_accuracy: 0.9948 - val_activation_117_auc: 0.9926 - val_activation_117_sensitivity_at_specificity: 0.9942 - val_activation_117_specificity_at_sensitivity: 0.9981 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9932 - val_activation_118_auc: 0.9781 - val_activation_118_sensitivity_at_specificity: 0.9937 - val_activation_118_specificity_at_sensitivity: 0.9892 - val_activation_118_mean_io_u: 0.4967 - lr: 0.0010
# Epoch 8/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0627 - activation_112_loss: 0.0056 - activation_113_loss: 0.0051 - activation_114_loss: 0.0053 - activation_115_loss: 0.0062 - activation_116_loss: 0.0080 - activation_117_loss: 0.0119 - activation_118_loss: 0.0205 - activation_112_accuracy: 0.9977 - activation_112_auc: 0.9963 - activation_112_sensitivity_at_specificity: 0.9941 - activation_112_specificity_at_sensitivity: 0.9999 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9979 - activation_113_auc: 0.9976 - activation_113_sensitivity_at_specificity: 0.9963 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9978 - activation_114_auc: 0.9978 - activation_114_sensitivity_at_specificity: 0.9969 - activation_114_specificity_at_sensitivity: 0.9999 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9975 - activation_115_auc: 0.9971 - activation_115_sensitivity_at_specificity: 0.9960 - activation_115_specificity_at_sensitivity: 0.9998 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9967 - activation_116_auc: 0.9951 - activation_116_sensitivity_at_specificity: 0.9934 - activation_116_specificity_at_sensitivity: 0.9995 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9950 - activation_117_auc: 0.9915 - activation_117_sensitivity_at_specificity: 0.9908 - activation_117_specificity_at_sensitivity: 0.9983 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9742 - activation_118_sensitivity_at_specificity: 0.9823 - activation_118_specificity_at_sensitivity: 0.9892 - activation_118_mean_io_u: 0.4967
# Epoch 8: val_loss did not improve from 0.06721
# 396/396 [==============================] - 105s 265ms/step - loss: 0.0627 - activation_112_loss: 0.0056 - activation_113_loss: 0.0051 - activation_114_loss: 0.0053 - activation_115_loss: 0.0062 - activation_116_loss: 0.0080 - activation_117_loss: 0.0119 - activation_118_loss: 0.0205 - activation_112_accuracy: 0.9977 - activation_112_auc: 0.9963 - activation_112_sensitivity_at_specificity: 0.9941 - activation_112_specificity_at_sensitivity: 0.9999 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9979 - activation_113_auc: 0.9976 - activation_113_sensitivity_at_specificity: 0.9963 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9978 - activation_114_auc: 0.9978 - activation_114_sensitivity_at_specificity: 0.9969 - activation_114_specificity_at_sensitivity: 0.9999 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9975 - activation_115_auc: 0.9971 - activation_115_sensitivity_at_specificity: 0.9960 - activation_115_specificity_at_sensitivity: 0.9998 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9967 - activation_116_auc: 0.9951 - activation_116_sensitivity_at_specificity: 0.9934 - activation_116_specificity_at_sensitivity: 0.9995 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9950 - activation_117_auc: 0.9915 - activation_117_sensitivity_at_specificity: 0.9908 - activation_117_specificity_at_sensitivity: 0.9983 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9742 - activation_118_sensitivity_at_specificity: 0.9823 - activation_118_specificity_at_sensitivity: 0.9892 - activation_118_mean_io_u: 0.4967 - val_loss: 0.0683 - val_activation_112_loss: 0.0068 - val_activation_113_loss: 0.0059 - val_activation_114_loss: 0.0062 - val_activation_115_loss: 0.0070 - val_activation_116_loss: 0.0087 - val_activation_117_loss: 0.0126 - val_activation_118_loss: 0.0210 - val_activation_112_accuracy: 0.9973 - val_activation_112_auc: 0.9927 - val_activation_112_sensitivity_at_specificity: 0.9870 - val_activation_112_specificity_at_sensitivity: 0.9998 - val_activation_112_mean_io_u: 0.4967 - val_activation_113_accuracy: 0.9976 - val_activation_113_auc: 0.9944 - val_activation_113_sensitivity_at_specificity: 0.9901 - val_activation_113_specificity_at_sensitivity: 0.9999 - val_activation_113_mean_io_u: 0.4967 - val_activation_114_accuracy: 0.9975 - val_activation_114_auc: 0.9957 - val_activation_114_sensitivity_at_specificity: 0.9930 - val_activation_114_specificity_at_sensitivity: 0.9999 - val_activation_114_mean_io_u: 0.4967 - val_activation_115_accuracy: 0.9972 - val_activation_115_auc: 0.9958 - val_activation_115_sensitivity_at_specificity: 0.9938 - val_activation_115_specificity_at_sensitivity: 0.9998 - val_activation_115_mean_io_u: 0.4967 - val_activation_116_accuracy: 0.9964 - val_activation_116_auc: 0.9950 - val_activation_116_sensitivity_at_specificity: 0.9937 - val_activation_116_specificity_at_sensitivity: 0.9995 - val_activation_116_mean_io_u: 0.4967 - val_activation_117_accuracy: 0.9949 - val_activation_117_auc: 0.9896 - val_activation_117_sensitivity_at_specificity: 0.9878 - val_activation_117_specificity_at_sensitivity: 0.9981 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9933 - val_activation_118_auc: 0.9735 - val_activation_118_sensitivity_at_specificity: 0.9824 - val_activation_118_specificity_at_sensitivity: 0.9898 - val_activation_118_mean_io_u: 0.4967 - lr: 0.0010
# Epoch 9/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0611 - activation_112_loss: 0.0053 - activation_113_loss: 0.0049 - activation_114_loss: 0.0051 - activation_115_loss: 0.0059 - activation_116_loss: 0.0078 - activation_117_loss: 0.0117 - activation_118_loss: 0.0203 - activation_112_accuracy: 0.9978 - activation_112_auc: 0.9968 - activation_112_sensitivity_at_specificity: 0.9948 - activation_112_specificity_at_sensitivity: 0.9999 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9979 - activation_113_auc: 0.9977 - activation_113_sensitivity_at_specificity: 0.9966 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9979 - activation_114_auc: 0.9980 - activation_114_sensitivity_at_specificity: 0.9972 - activation_114_specificity_at_sensitivity: 0.9999 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9976 - activation_115_auc: 0.9972 - activation_115_sensitivity_at_specificity: 0.9961 - activation_115_specificity_at_sensitivity: 0.9999 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9968 - activation_116_auc: 0.9954 - activation_116_sensitivity_at_specificity: 0.9937 - activation_116_specificity_at_sensitivity: 0.9996 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9951 - activation_117_auc: 0.9915 - activation_117_sensitivity_at_specificity: 0.9904 - activation_117_specificity_at_sensitivity: 0.9984 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9753 - activation_118_sensitivity_at_specificity: 0.9838 - activation_118_specificity_at_sensitivity: 0.9894 - activation_118_mean_io_u: 0.4967
# Epoch 9: val_loss improved from 0.06721 to 0.06501, saving model to model-Unet.h5
# 396/396 [==============================] - 106s 269ms/step - loss: 0.0611 - activation_112_loss: 0.0053 - activation_113_loss: 0.0049 - activation_114_loss: 0.0051 - activation_115_loss: 0.0059 - activation_116_loss: 0.0078 - activation_117_loss: 0.0117 - activation_118_loss: 0.0203 - activation_112_accuracy: 0.9978 - activation_112_auc: 0.9968 - activation_112_sensitivity_at_specificity: 0.9948 - activation_112_specificity_at_sensitivity: 0.9999 - activation_112_mean_io_u: 0.4967 - activation_113_accuracy: 0.9979 - activation_113_auc: 0.9977 - activation_113_sensitivity_at_specificity: 0.9966 - activation_113_specificity_at_sensitivity: 0.9999 - activation_113_mean_io_u: 0.4967 - activation_114_accuracy: 0.9979 - activation_114_auc: 0.9980 - activation_114_sensitivity_at_specificity: 0.9972 - activation_114_specificity_at_sensitivity: 0.9999 - activation_114_mean_io_u: 0.4967 - activation_115_accuracy: 0.9976 - activation_115_auc: 0.9972 - activation_115_sensitivity_at_specificity: 0.9961 - activation_115_specificity_at_sensitivity: 0.9999 - activation_115_mean_io_u: 0.4967 - activation_116_accuracy: 0.9968 - activation_116_auc: 0.9954 - activation_116_sensitivity_at_specificity: 0.9937 - activation_116_specificity_at_sensitivity: 0.9996 - activation_116_mean_io_u: 0.4967 - activation_117_accuracy: 0.9951 - activation_117_auc: 0.9915 - activation_117_sensitivity_at_specificity: 0.9904 - activation_117_specificity_at_sensitivity: 0.9984 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9933 - activation_118_auc: 0.9753 - activation_118_sensitivity_at_specificity: 0.9838 - activation_118_specificity_at_sensitivity: 0.9894 - activation_118_mean_io_u: 0.4967 - val_loss: 0.0650 - val_activation_112_loss: 0.0059 - val_activation_113_loss: 0.0054 - val_activation_114_loss: 0.0056 - val_activation_115_loss: 0.0065 - val_activation_116_loss: 0.0085 - val_activation_117_loss: 0.0123 - val_activation_118_loss: 0.0207 - val_activation_112_accuracy: 0.9976 - val_activation_112_auc: 0.9949 - val_activation_112_sensitivity_at_specificity: 0.9912 - val_activation_112_specificity_at_sensitivity: 0.9999 - val_activation_112_mean_io_u: 0.4967 - val_activation_113_accuracy: 0.9977 - val_activation_113_auc: 0.9964 - val_activation_113_sensitivity_at_specificity: 0.9940 - val_activation_113_specificity_at_sensitivity: 0.9999 - val_activation_113_mean_io_u: 0.4967 - val_activation_114_accuracy: 0.9977 - val_activation_114_auc: 0.9967 - val_activation_114_sensitivity_at_specificity: 0.9949 - val_activation_114_specificity_at_sensitivity: 0.9999 - val_activation_114_mean_io_u: 0.4967 - val_activation_115_accuracy: 0.9973 - val_activation_115_auc: 0.9962 - val_activation_115_sensitivity_at_specificity: 0.9944 - val_activation_115_specificity_at_sensitivity: 0.9998 - val_activation_115_mean_io_u: 0.4967 - val_activation_116_accuracy: 0.9965 - val_activation_116_auc: 0.9928 - val_activation_116_sensitivity_at_specificity: 0.9891 - val_activation_116_specificity_at_sensitivity: 0.9995 - val_activation_116_mean_io_u: 0.4967 - val_activation_117_accuracy: 0.9949 - val_activation_117_auc: 0.9913 - val_activation_117_sensitivity_at_specificity: 0.9907 - val_activation_117_specificity_at_sensitivity: 0.9982 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9933 - val_activation_118_auc: 0.9743 - val_activation_118_sensitivity_at_specificity: 0.9826 - val_activation_118_specificity_at_sensitivity: 0.9894 - val_activation_118_mean_io_u: 0.4967 - lr: 0.0010
# Epoch 10/50
# ...
# Epoch 46/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0427 - activation_112_loss: 0.0020 - activation_113_loss: 0.0021 - activation_114_loss: 0.0022 - activation_115_loss: 0.0030 - activation_116_loss: 0.0051 - activation_117_loss: 0.0095 - activation_118_loss: 0.0189 - activation_112_accuracy: 0.9991 - activation_112_auc: 0.9997 - activation_112_sensitivity_at_specificity: 0.9995 - activation_112_specificity_at_sensitivity: 1.0000 - activation_112_mean_io_u: 0.5169 - activation_113_accuracy: 0.9991 - activation_113_auc: 0.9997 - activation_113_sensitivity_at_specificity: 0.9996 - activation_113_specificity_at_sensitivity: 1.0000 - activation_113_mean_io_u: 0.5168 - activation_114_accuracy: 0.9991 - activation_114_auc: 0.9996 - activation_114_sensitivity_at_specificity: 0.9995 - activation_114_specificity_at_sensitivity: 1.0000 - activation_114_mean_io_u: 0.4970 - activation_115_accuracy: 0.9987 - activation_115_auc: 0.9994 - activation_115_sensitivity_at_specificity: 0.9993 - activation_115_specificity_at_sensitivity: 1.0000 - activation_115_mean_io_u: 0.4968 - activation_116_accuracy: 0.9978 - activation_116_auc: 0.9986 - activation_116_sensitivity_at_specificity: 0.9984 - activation_116_specificity_at_sensitivity: 0.9999 - activation_116_mean_io_u: 0.4971 - activation_117_accuracy: 0.9958 - activation_117_auc: 0.9960 - activation_117_sensitivity_at_specificity: 0.9966 - activation_117_specificity_at_sensitivity: 0.9990 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9935 - activation_118_auc: 0.9828 - activation_118_sensitivity_at_specificity: 0.9927 - activation_118_specificity_at_sensitivity: 0.9915 - activation_118_mean_io_u: 0.4967
# Epoch 46: val_loss did not improve from 0.05605
# 396/396 [==============================] - 119s 301ms/step - loss: 0.0427 - activation_112_loss: 0.0020 - activation_113_loss: 0.0021 - activation_114_loss: 0.0022 - activation_115_loss: 0.0030 - activation_116_loss: 0.0051 - activation_117_loss: 0.0095 - activation_118_loss: 0.0189 - activation_112_accuracy: 0.9991 - activation_112_auc: 0.9997 - activation_112_sensitivity_at_specificity: 0.9995 - activation_112_specificity_at_sensitivity: 1.0000 - activation_112_mean_io_u: 0.5169 - activation_113_accuracy: 0.9991 - activation_113_auc: 0.9997 - activation_113_sensitivity_at_specificity: 0.9996 - activation_113_specificity_at_sensitivity: 1.0000 - activation_113_mean_io_u: 0.5168 - activation_114_accuracy: 0.9991 - activation_114_auc: 0.9996 - activation_114_sensitivity_at_specificity: 0.9995 - activation_114_specificity_at_sensitivity: 1.0000 - activation_114_mean_io_u: 0.4970 - activation_115_accuracy: 0.9987 - activation_115_auc: 0.9994 - activation_115_sensitivity_at_specificity: 0.9993 - activation_115_specificity_at_sensitivity: 1.0000 - activation_115_mean_io_u: 0.4968 - activation_116_accuracy: 0.9978 - activation_116_auc: 0.9986 - activation_116_sensitivity_at_specificity: 0.9984 - activation_116_specificity_at_sensitivity: 0.9999 - activation_116_mean_io_u: 0.4971 - activation_117_accuracy: 0.9958 - activation_117_auc: 0.9960 - activation_117_sensitivity_at_specificity: 0.9966 - activation_117_specificity_at_sensitivity: 0.9990 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9935 - activation_118_auc: 0.9828 - activation_118_sensitivity_at_specificity: 0.9927 - activation_118_specificity_at_sensitivity: 0.9915 - activation_118_mean_io_u: 0.4967 - val_loss: 0.0574 - val_activation_112_loss: 0.0052 - val_activation_113_loss: 0.0052 - val_activation_114_loss: 0.0050 - val_activation_115_loss: 0.0053 - val_activation_116_loss: 0.0068 - val_activation_117_loss: 0.0105 - val_activation_118_loss: 0.0194 - val_activation_112_accuracy: 0.9983 - val_activation_112_auc: 0.9916 - val_activation_112_sensitivity_at_specificity: 0.9839 - val_activation_112_specificity_at_sensitivity: 0.9999 - val_activation_112_mean_io_u: 0.5232 - val_activation_113_accuracy: 0.9983 - val_activation_113_auc: 0.9923 - val_activation_113_sensitivity_at_specificity: 0.9853 - val_activation_113_specificity_at_sensitivity: 0.9999 - val_activation_113_mean_io_u: 0.5230 - val_activation_114_accuracy: 0.9982 - val_activation_114_auc: 0.9931 - val_activation_114_sensitivity_at_specificity: 0.9871 - val_activation_114_specificity_at_sensitivity: 0.9999 - val_activation_114_mean_io_u: 0.4968 - val_activation_115_accuracy: 0.9979 - val_activation_115_auc: 0.9947 - val_activation_115_sensitivity_at_specificity: 0.9905 - val_activation_115_specificity_at_sensitivity: 0.9999 - val_activation_115_mean_io_u: 0.4968 - val_activation_116_accuracy: 0.9972 - val_activation_116_auc: 0.9950 - val_activation_116_sensitivity_at_specificity: 0.9919 - val_activation_116_specificity_at_sensitivity: 0.9997 - val_activation_116_mean_io_u: 0.4973 - val_activation_117_accuracy: 0.9955 - val_activation_117_auc: 0.9934 - val_activation_117_sensitivity_at_specificity: 0.9924 - val_activation_117_specificity_at_sensitivity: 0.9988 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9932 - val_activation_118_auc: 0.9810 - val_activation_118_sensitivity_at_specificity: 0.9904 - val_activation_118_specificity_at_sensitivity: 0.9918 - val_activation_118_mean_io_u: 0.4967 - lr: 1.0000e-05
# Epoch 47/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0427 - activation_112_loss: 0.0020 - activation_113_loss: 0.0020 - activation_114_loss: 0.0022 - activation_115_loss: 0.0030 - activation_116_loss: 0.0051 - activation_117_loss: 0.0095 - activation_118_loss: 0.0189 - activation_112_accuracy: 0.9991 - activation_112_auc: 0.9997 - activation_112_sensitivity_at_specificity: 0.9995 - activation_112_specificity_at_sensitivity: 1.0000 - activation_112_mean_io_u: 0.5166 - activation_113_accuracy: 0.9991 - activation_113_auc: 0.9997 - activation_113_sensitivity_at_specificity: 0.9996 - activation_113_specificity_at_sensitivity: 1.0000 - activation_113_mean_io_u: 0.5165 - activation_114_accuracy: 0.9991 - activation_114_auc: 0.9996 - activation_114_sensitivity_at_specificity: 0.9995 - activation_114_specificity_at_sensitivity: 1.0000 - activation_114_mean_io_u: 0.4969 - activation_115_accuracy: 0.9987 - activation_115_auc: 0.9994 - activation_115_sensitivity_at_specificity: 0.9992 - activation_115_specificity_at_sensitivity: 1.0000 - activation_115_mean_io_u: 0.4968 - activation_116_accuracy: 0.9978 - activation_116_auc: 0.9986 - activation_116_sensitivity_at_specificity: 0.9984 - activation_116_specificity_at_sensitivity: 0.9999 - activation_116_mean_io_u: 0.4971 - activation_117_accuracy: 0.9958 - activation_117_auc: 0.9960 - activation_117_sensitivity_at_specificity: 0.9966 - activation_117_specificity_at_sensitivity: 0.9990 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9935 - activation_118_auc: 0.9828 - activation_118_sensitivity_at_specificity: 0.9927 - activation_118_specificity_at_sensitivity: 0.9915 - activation_118_mean_io_u: 0.4967
# Epoch 47: val_loss did not improve from 0.05605
# 396/396 [==============================] - 116s 292ms/step - loss: 0.0427 - activation_112_loss: 0.0020 - activation_113_loss: 0.0020 - activation_114_loss: 0.0022 - activation_115_loss: 0.0030 - activation_116_loss: 0.0051 - activation_117_loss: 0.0095 - activation_118_loss: 0.0189 - activation_112_accuracy: 0.9991 - activation_112_auc: 0.9997 - activation_112_sensitivity_at_specificity: 0.9995 - activation_112_specificity_at_sensitivity: 1.0000 - activation_112_mean_io_u: 0.5166 - activation_113_accuracy: 0.9991 - activation_113_auc: 0.9997 - activation_113_sensitivity_at_specificity: 0.9996 - activation_113_specificity_at_sensitivity: 1.0000 - activation_113_mean_io_u: 0.5165 - activation_114_accuracy: 0.9991 - activation_114_auc: 0.9996 - activation_114_sensitivity_at_specificity: 0.9995 - activation_114_specificity_at_sensitivity: 1.0000 - activation_114_mean_io_u: 0.4969 - activation_115_accuracy: 0.9987 - activation_115_auc: 0.9994 - activation_115_sensitivity_at_specificity: 0.9992 - activation_115_specificity_at_sensitivity: 1.0000 - activation_115_mean_io_u: 0.4968 - activation_116_accuracy: 0.9978 - activation_116_auc: 0.9986 - activation_116_sensitivity_at_specificity: 0.9984 - activation_116_specificity_at_sensitivity: 0.9999 - activation_116_mean_io_u: 0.4971 - activation_117_accuracy: 0.9958 - activation_117_auc: 0.9960 - activation_117_sensitivity_at_specificity: 0.9966 - activation_117_specificity_at_sensitivity: 0.9990 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9935 - activation_118_auc: 0.9828 - activation_118_sensitivity_at_specificity: 0.9927 - activation_118_specificity_at_sensitivity: 0.9915 - activation_118_mean_io_u: 0.4967 - val_loss: 0.0574 - val_activation_112_loss: 0.0052 - val_activation_113_loss: 0.0052 - val_activation_114_loss: 0.0050 - val_activation_115_loss: 0.0053 - val_activation_116_loss: 0.0068 - val_activation_117_loss: 0.0105 - val_activation_118_loss: 0.0194 - val_activation_112_accuracy: 0.9983 - val_activation_112_auc: 0.9917 - val_activation_112_sensitivity_at_specificity: 0.9840 - val_activation_112_specificity_at_sensitivity: 0.9999 - val_activation_112_mean_io_u: 0.5235 - val_activation_113_accuracy: 0.9983 - val_activation_113_auc: 0.9922 - val_activation_113_sensitivity_at_specificity: 0.9852 - val_activation_113_specificity_at_sensitivity: 0.9999 - val_activation_113_mean_io_u: 0.5231 - val_activation_114_accuracy: 0.9982 - val_activation_114_auc: 0.9932 - val_activation_114_sensitivity_at_specificity: 0.9873 - val_activation_114_specificity_at_sensitivity: 0.9999 - val_activation_114_mean_io_u: 0.4968 - val_activation_115_accuracy: 0.9979 - val_activation_115_auc: 0.9948 - val_activation_115_sensitivity_at_specificity: 0.9906 - val_activation_115_specificity_at_sensitivity: 0.9999 - val_activation_115_mean_io_u: 0.4968 - val_activation_116_accuracy: 0.9972 - val_activation_116_auc: 0.9951 - val_activation_116_sensitivity_at_specificity: 0.9922 - val_activation_116_specificity_at_sensitivity: 0.9997 - val_activation_116_mean_io_u: 0.4973 - val_activation_117_accuracy: 0.9955 - val_activation_117_auc: 0.9935 - val_activation_117_sensitivity_at_specificity: 0.9926 - val_activation_117_specificity_at_sensitivity: 0.9988 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9932 - val_activation_118_auc: 0.9811 - val_activation_118_sensitivity_at_specificity: 0.9905 - val_activation_118_specificity_at_sensitivity: 0.9920 - val_activation_118_mean_io_u: 0.4967 - lr: 1.0000e-05
# Epoch 48/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0427 - activation_112_loss: 0.0020 - activation_113_loss: 0.0020 - activation_114_loss: 0.0022 - activation_115_loss: 0.0030 - activation_116_loss: 0.0051 - activation_117_loss: 0.0095 - activation_118_loss: 0.0189 - activation_112_accuracy: 0.9991 - activation_112_auc: 0.9997 - activation_112_sensitivity_at_specificity: 0.9995 - activation_112_specificity_at_sensitivity: 1.0000 - activation_112_mean_io_u: 0.5184 - activation_113_accuracy: 0.9991 - activation_113_auc: 0.9997 - activation_113_sensitivity_at_specificity: 0.9996 - activation_113_specificity_at_sensitivity: 1.0000 - activation_113_mean_io_u: 0.5183 - activation_114_accuracy: 0.9991 - activation_114_auc: 0.9996 - activation_114_sensitivity_at_specificity: 0.9995 - activation_114_specificity_at_sensitivity: 1.0000 - activation_114_mean_io_u: 0.4970 - activation_115_accuracy: 0.9987 - activation_115_auc: 0.9994 - activation_115_sensitivity_at_specificity: 0.9992 - activation_115_specificity_at_sensitivity: 1.0000 - activation_115_mean_io_u: 0.4968 - activation_116_accuracy: 0.9978 - activation_116_auc: 0.9986 - activation_116_sensitivity_at_specificity: 0.9984 - activation_116_specificity_at_sensitivity: 0.9999 - activation_116_mean_io_u: 0.4972 - activation_117_accuracy: 0.9958 - activation_117_auc: 0.9960 - activation_117_sensitivity_at_specificity: 0.9966 - activation_117_specificity_at_sensitivity: 0.9990 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9935 - activation_118_auc: 0.9827 - activation_118_sensitivity_at_specificity: 0.9926 - activation_118_specificity_at_sensitivity: 0.9915 - activation_118_mean_io_u: 0.4967
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 48: val_loss did not improve from 0.05605
# 396/396 [==============================] - 114s 289ms/step - loss: 0.0427 - activation_112_loss: 0.0020 - activation_113_loss: 0.0020 - activation_114_loss: 0.0022 - activation_115_loss: 0.0030 - activation_116_loss: 0.0051 - activation_117_loss: 0.0095 - activation_118_loss: 0.0189 - activation_112_accuracy: 0.9991 - activation_112_auc: 0.9997 - activation_112_sensitivity_at_specificity: 0.9995 - activation_112_specificity_at_sensitivity: 1.0000 - activation_112_mean_io_u: 0.5184 - activation_113_accuracy: 0.9991 - activation_113_auc: 0.9997 - activation_113_sensitivity_at_specificity: 0.9996 - activation_113_specificity_at_sensitivity: 1.0000 - activation_113_mean_io_u: 0.5183 - activation_114_accuracy: 0.9991 - activation_114_auc: 0.9996 - activation_114_sensitivity_at_specificity: 0.9995 - activation_114_specificity_at_sensitivity: 1.0000 - activation_114_mean_io_u: 0.4970 - activation_115_accuracy: 0.9987 - activation_115_auc: 0.9994 - activation_115_sensitivity_at_specificity: 0.9992 - activation_115_specificity_at_sensitivity: 1.0000 - activation_115_mean_io_u: 0.4968 - activation_116_accuracy: 0.9978 - activation_116_auc: 0.9986 - activation_116_sensitivity_at_specificity: 0.9984 - activation_116_specificity_at_sensitivity: 0.9999 - activation_116_mean_io_u: 0.4972 - activation_117_accuracy: 0.9958 - activation_117_auc: 0.9960 - activation_117_sensitivity_at_specificity: 0.9966 - activation_117_specificity_at_sensitivity: 0.9990 - activation_117_mean_io_u: 0.4967 - activation_118_accuracy: 0.9935 - activation_118_auc: 0.9827 - activation_118_sensitivity_at_specificity: 0.9926 - activation_118_specificity_at_sensitivity: 0.9915 - activation_118_mean_io_u: 0.4967 - val_loss: 0.0574 - val_activation_112_loss: 0.0052 - val_activation_113_loss: 0.0052 - val_activation_114_loss: 0.0050 - val_activation_115_loss: 0.0053 - val_activation_116_loss: 0.0068 - val_activation_117_loss: 0.0105 - val_activation_118_loss: 0.0194 - val_activation_112_accuracy: 0.9983 - val_activation_112_auc: 0.9916 - val_activation_112_sensitivity_at_specificity: 0.9839 - val_activation_112_specificity_at_sensitivity: 0.9999 - val_activation_112_mean_io_u: 0.5236 - val_activation_113_accuracy: 0.9983 - val_activation_113_auc: 0.9921 - val_activation_113_sensitivity_at_specificity: 0.9850 - val_activation_113_specificity_at_sensitivity: 0.9999 - val_activation_113_mean_io_u: 0.5233 - val_activation_114_accuracy: 0.9982 - val_activation_114_auc: 0.9931 - val_activation_114_sensitivity_at_specificity: 0.9871 - val_activation_114_specificity_at_sensitivity: 0.9999 - val_activation_114_mean_io_u: 0.4969 - val_activation_115_accuracy: 0.9979 - val_activation_115_auc: 0.9948 - val_activation_115_sensitivity_at_specificity: 0.9906 - val_activation_115_specificity_at_sensitivity: 0.9999 - val_activation_115_mean_io_u: 0.4968 - val_activation_116_accuracy: 0.9972 - val_activation_116_auc: 0.9950 - val_activation_116_sensitivity_at_specificity: 0.9920 - val_activation_116_specificity_at_sensitivity: 0.9997 - val_activation_116_mean_io_u: 0.4972 - val_activation_117_accuracy: 0.9955 - val_activation_117_auc: 0.9934 - val_activation_117_sensitivity_at_specificity: 0.9924 - val_activation_117_specificity_at_sensitivity: 0.9988 - val_activation_117_mean_io_u: 0.4967 - val_activation_118_accuracy: 0.9932 - val_activation_118_auc: 0.9811 - val_activation_118_sensitivity_at_specificity: 0.9906 - val_activation_118_specificity_at_sensitivity: 0.9920 - val_activation_118_mean_io_u: 0.4967 - lr: 1.0000e-05
# Epoch 48: early stopping

# %%
df_result = pd.DataFrame(results.history)
df_result.sort_values('val_loss', ascending=True, inplace = True)
df_result
# Out:
#         loss  activation_112_loss  activation_113_loss  activation_114_loss  \
# 37  0.044797             0.002426             0.002446             0.002583
# 38  0.044031             0.002291             0.002308             0.002451
# 39  0.043716             0.002233             0.002249             0.002394
# 41  0.043301             0.002156             0.002173             0.002318
# 31  0.048103             0.003026             0.003030             0.003172
# 40  0.043510             0.002196             0.002213             0.002356
# 29  0.049986             0.003350             0.003351             0.003494
# 35  0.047532             0.002919             0.002928             0.003074
# 43  0.042784             0.002048             0.002065             0.002217
# 42  0.043147             0.002126             0.002141             0.002288
# 44  0.042759             0.002045             0.002062             0.002212
# 46  0.042692             0.002031             0.002049             0.002200
# 45  0.042709             0.002035             0.002053             0.002202
# 47  0.042680             0.002028             0.002044             0.002195
# 33  0.048218             0.003035             0.003037             0.003184
# 25  0.051275             0.003575             0.003549             0.003698
# 26  0.051380             0.003586             0.003573             0.003717
# 27  0.051777             0.003606             0.003597             0.003748
# 32  0.048023             0.003024             0.003030             0.003173
# 34  0.047648             0.002959             0.002963             0.003116
# 30  0.048914             0.003173             0.003175             0.003312
# 22  0.052055             0.003742             0.003687             0.003816
# 28  0.056118             0.004258             0.004299             0.004427
# 36  0.047094             0.002841             0.002849             0.002993
# 17  0.054804             0.004258             0.004116             0.004243
# 21  0.052781             0.003881             0.003807             0.003939
# 20  0.053134             0.003961             0.003869             0.004001
# 13  0.056903             0.004611             0.004357             0.004522
# 18  0.053917             0.004111             0.003980             0.004109
# 19  0.054324             0.004113             0.004008             0.004129
# 11  0.057684             0.004778             0.004468             0.004640
# 16  0.057312             0.004661             0.004496             0.004619
# 24  0.051732             0.003669             0.003630             0.003773
# 23  0.052854             0.003826             0.003780             0.003930
# 15  0.074817             0.007329             0.007131             0.007298
# 12  0.057436             0.004710             0.004407             0.004591
# 10  0.060291             0.005166             0.004799             0.004994
# 9   0.061146             0.005302             0.004904             0.005123
# 8   0.061112             0.005341             0.004933             0.005120
# 14  0.056744             0.004585             0.004373             0.004501
# 6   0.062604             0.005606             0.005052             0.005335
# 7   0.062652             0.005593             0.005122             0.005334
# 5   0.064705             0.005886             0.005302             0.005609
# 4   0.067497             0.006382             0.005712             0.006062
# 3   0.071185             0.006874             0.006095             0.006521
# 2   0.079834             0.008065             0.007212             0.007689
# 1   0.091170             0.009683             0.008657             0.009244
# 0   0.241761             0.046093             0.024046             0.020602
#
#     activation_115_loss  activation_116_loss  activation_117_loss  \
# 37             0.003306             0.005399             0.009663
# 38             0.003185             0.005289             0.009581
# 39             0.003133             0.005242             0.009552
# 41             0.003066             0.005188             0.009513
# 31             0.003867             0.005828             0.010010
# 40             0.003101             0.005215             0.009532
# 29             0.004179             0.006105             0.010216
# 35             0.003762             0.005751             0.009951
# 43             0.002983             0.005129             0.009475
# 42             0.003042             0.005171             0.009497
# 44             0.002978             0.005124             0.009470
# 46             0.002968             0.005118             0.009463
# 45             0.002972             0.005120             0.009463
# 47             0.002967             0.005116             0.009464
# 33             0.003884             0.005855             0.010047
# 25             0.004393             0.006299             0.010356
# 26             0.004422             0.006314             0.010375
# 27             0.004461             0.006395             0.010468
# 32             0.003855             0.005813             0.009976
# 34             0.003806             0.005768             0.009929
# 30             0.003983             0.005939             0.010087
# 22             0.004500             0.006369             0.010454
# 28             0.005167             0.007072             0.011018
# 36             0.003689             0.005684             0.009901
# 17             0.004934             0.006805             0.010769
# 21             0.004620             0.006509             0.010536
# 20             0.004665             0.006542             0.010554
# 13             0.005247             0.007155             0.011074
# 18             0.004788             0.006653             0.010658
# 19             0.004828             0.006717             0.010778
# 11             0.005370             0.007261             0.011179
# 16             0.005338             0.007187             0.011089
# 24             0.004475             0.006354             0.010414
# 23             0.004635             0.006525             0.010573
# 15             0.008096             0.009876             0.013400
# 12             0.005357             0.007238             0.011151
# 10             0.005788             0.007692             0.011610
# 9              0.005982             0.007838             0.011661
# 8              0.005892             0.007793             0.011701
# 14             0.005223             0.007097             0.011032
# 6              0.006158             0.008054             0.011944
# 7              0.006157             0.008044             0.011915
# 5              0.006494             0.008432             0.012298
# 4              0.006943             0.008844             0.012667
# 3              0.007547             0.009505             0.013327
# 2              0.009029             0.010993             0.014561
# 1              0.010904             0.013002             0.016206
# 0              0.021210             0.039020             0.029032
#
#     activation_118_loss  activation_112_accuracy  activation_112_auc  ...  \
# 37             0.018976                 0.998960            0.999623  ...
# 38             0.018925                 0.999013            0.999597  ...
# 39             0.018912                 0.999042            0.999617  ...
# 41             0.018887                 0.999072            0.999620  ...
# 31             0.019171                 0.998704            0.999309  ...
# 40             0.018898                 0.999058            0.999619  ...
# 29             0.019291                 0.998574            0.999081  ...
# 35             0.019146                 0.998753            0.999373  ...
# 43             0.018869                 0.999123            0.999666  ...
# 42             0.018881                 0.999087            0.999648  ...
# 44             0.018867                 0.999125            0.999667  ...
# 46             0.018864                 0.999132            0.999663  ...
# 45             0.018865                 0.999128            0.999661  ...
# 47             0.018866                 0.999130            0.999652  ...
# 33             0.019176                 0.998695            0.999304  ...
# 25             0.019405                 0.998473            0.999012  ...
# 26             0.019393                 0.998475            0.998934  ...
# 27             0.019501                 0.998479            0.998779  ...
# 32             0.019153                 0.998703            0.999302  ...
# 34             0.019107                 0.998730            0.999317  ...
# 30             0.019246                 0.998638            0.999203  ...
# 22             0.019486                 0.998410            0.998875  ...
# 28             0.019875                 0.998239            0.997972  ...
# 36             0.019137                 0.998777            0.999352  ...
# 17             0.019680                 0.998202            0.998441  ...
# 21             0.019488                 0.998353            0.998714  ...
# 20             0.019542                 0.998325            0.998652  ...
# 13             0.019938                 0.998060            0.997887  ...
# 18             0.019617                 0.998262            0.998503  ...
# 19             0.019750                 0.998267            0.998461  ...
# 11             0.019988                 0.998012            0.997453  ...
# 16             0.019923                 0.998043            0.998015  ...
# 24             0.019418                 0.998441            0.998894  ...
# 23             0.019585                 0.998376            0.998833  ...
# 15             0.021687                 0.997205            0.991727  ...
# 12             0.019983                 0.998021            0.997797  ...
# 10             0.020242                 0.997874            0.996882  ...
# 9              0.020336                 0.997812            0.996896  ...
# 8              0.020332                 0.997797            0.996776  ...
# 14             0.019933                 0.998081            0.997843  ...
# 6              0.020455                 0.997708            0.996205  ...
# 7              0.020486                 0.997706            0.996338  ...
# 5              0.020683                 0.997590            0.996009  ...
# 4              0.020887                 0.997426            0.994827  ...
# 3              0.021316                 0.997255            0.993983  ...
# 2              0.022285                 0.996852            0.991748  ...
# 1              0.023473                 0.996283            0.989440  ...
# 0              0.061758                 0.983096            0.958019  ...
#
#     val_activation_117_auc  val_activation_117_sensitivity_at_specificity  \
# 37                0.994249                                       0.994202
# 38                0.993617                                       0.992902
# 39                0.993536                                       0.992694
# 41                0.993306                                       0.992226
# 31                0.994950                                       0.995892
# 40                0.993447                                       0.992538
# 29                0.991799                                       0.989731
# 35                0.992170                                       0.990355
# 43                0.993582                                       0.992746
# 42                0.993193                                       0.991993
# 44                0.993635                                       0.992850
# 46                0.993522                                       0.992616
# 45                0.993430                                       0.992435
# 47                0.993433                                       0.992435
# 33                0.993811                                       0.993656
# 25                0.992891                                       0.992070
# 26                0.994206                                       0.994774
# 27                0.994300                                       0.994852
# 32                0.994033                                       0.994410
# 34                0.991910                                       0.989835
# 30                0.990004                                       0.986117
# 22                0.993503                                       0.993474
# 28                0.992817                                       0.992226
# 36                0.990894                                       0.987807
# 17                0.994073                                       0.994774
# 21                0.989999                                       0.986481
# 20                0.992231                                       0.991239
# 13                0.993655                                       0.994514
# 18                0.995001                                       0.996854
# 19                0.994567                                       0.996022
# 11                0.993242                                       0.993812
# 16                0.991229                                       0.989393
# 24                0.994381                                       0.995944
# 23                0.988476                                       0.983699
# 15                0.991559                                       0.990797
# 12                0.992280                                       0.993032
# 10                0.992956                                       0.993708
# 9                 0.988165                                       0.984167
# 8                 0.991290                                       0.990667
# 14                0.991050                                       0.990641
# 6                 0.992593                                       0.994228
# 7                 0.989602                                       0.987833
# 5                 0.992264                                       0.993474
# 4                 0.988318                                       0.986897
# 3                 0.990502                                       0.992200
# 2                 0.979066                                       0.970284
# 1                 0.973146                                       0.960431
# 0                 0.735569                                       0.517003
#
#     val_activation_117_specificity_at_sensitivity  \
# 37                                       0.998825
# 38                                       0.998811
# 39                                       0.998820
# 41                                       0.998818
# 31                                       0.998651
# 40                                       0.998818
# 29                                       0.998745
# 35                                       0.998762
# 43                                       0.998828
# 42                                       0.998833
# 44                                       0.998840
# 46                                       0.998828
# 45                                       0.998840
# 47                                       0.998828
# 33                                       0.998683
# 25                                       0.998619
# 26                                       0.998692
# 27                                       0.998613
# 32                                       0.998734
# 34                                       0.998744
# 30                                       0.998721
# 22                                       0.998658
# 28                                       0.998642
# 36                                       0.998806
# 17                                       0.998543
# 21                                       0.998616
# 20                                       0.998521
# 13                                       0.998564
# 18                                       0.998571
# 19                                       0.998530
# 11                                       0.998452
# 16                                       0.998476
# 24                                       0.998513
# 23                                       0.998663
# 15                                       0.998387
# 12                                       0.998269
# 10                                       0.998278
# 9                                        0.998251
# 8                                        0.998219
# 14                                       0.998275
# 6                                        0.998086
# 7                                        0.998143
# 5                                        0.997919
# 4                                        0.997589
# 3                                        0.997608
# 2                                        0.997244
# 1                                        0.997065
# 0                                        0.947010
#
#     val_activation_117_mean_io_u  val_activation_118_accuracy  \
# 37                      0.496665                     0.993214
# 38                      0.496665                     0.993238
# 39                      0.496665                     0.993243
# 41                      0.496665                     0.993245
# 31                      0.496665                     0.993246
# 40                      0.496665                     0.993218
# 29                      0.496665                     0.993300
# 35                      0.496665                     0.993372
# 43                      0.496665                     0.993241
# 42                      0.496665                     0.993216
# 44                      0.496665                     0.993236
# 46                      0.496665                     0.993232
# 45                      0.496665                     0.993241
# 47                      0.496665                     0.993236
# 33                      0.496665                     0.993284
# 25                      0.496665                     0.993224
# 26                      0.496665                     0.993337
# 27                      0.496665                     0.993223
# 32                      0.496665                     0.993152
# 34                      0.496665                     0.993209
# 30                      0.496665                     0.993204
# 22                      0.496665                     0.993247
# 28                      0.496665                     0.993095
# 36                      0.496665                     0.993380
# 17                      0.496665                     0.993123
# 21                      0.496665                     0.993261
# 20                      0.496665                     0.993156
# 13                      0.496665                     0.993191
# 18                      0.496665                     0.993048
# 19                      0.496665                     0.993009
# 11                      0.496665                     0.993298
# 16                      0.496665                     0.993386
# 24                      0.496665                     0.993250
# 23                      0.496665                     0.993285
# 15                      0.496665                     0.993156
# 12                      0.496665                     0.993171
# 10                      0.496665                     0.993295
# 9                       0.496665                     0.993212
# 8                       0.496665                     0.993266
# 14                      0.496665                     0.993182
# 6                       0.496665                     0.993153
# 7                       0.496665                     0.993283
# 5                       0.496665                     0.993306
# 4                       0.496665                     0.993245
# 3                       0.496665                     0.993157
# 2                       0.496665                     0.993271
# 1                       0.496665                     0.993344
# 0                       0.496665                     0.993331
#
#     val_activation_118_auc  val_activation_118_sensitivity_at_specificity  \
# 37                0.981128                                       0.990745
# 38                0.980694                                       0.989861
# 39                0.980987                                       0.990381
# 41                0.981119                                       0.990693
# 31                0.980798                                       0.990771
# 40                0.980733                                       0.989887
# 29                0.977554                                       0.984115
# 35                0.975627                                       0.980319
# 43                0.981038                                       0.990433
# 42                0.980649                                       0.989601
# 44                0.981137                                       0.990615
# 46                0.981085                                       0.990485
# 45                0.981033                                       0.990381
# 47                0.981115                                       0.990563
# 33                0.979768                                       0.989263
# 25                0.979671                                       0.988977
# 26                0.981618                                       0.993292
# 27                0.980081                                       0.990823
# 32                0.981125                                       0.991759
# 34                0.979581                                       0.987989
# 30                0.979035                                       0.987183
# 22                0.979007                                       0.988015
# 28                0.973864                                       0.977329
# 36                0.977597                                       0.984531
# 17                0.979770                                       0.990147
# 21                0.976572                                       0.983075
# 20                0.976667                                       0.984011
# 13                0.980615                                       0.993318
# 18                0.980861                                       0.992356
# 19                0.981139                                       0.994072
# 11                0.971932                                       0.976939
# 16                0.973500                                       0.978291
# 24                0.979885                                       0.991291
# 23                0.974827                                       0.980163
# 15                0.976642                                       0.986637
# 12                0.976070                                       0.985571
# 10                0.974984                                       0.983413
# 9                 0.975456                                       0.984115
# 8                 0.974289                                       0.982581
# 14                0.967869                                       0.969452
# 6                 0.978065                                       0.993734
# 7                 0.973530                                       0.982399
# 5                 0.976095                                       0.988015
# 4                 0.973072                                       0.982711
# 3                 0.975081                                       0.988457
# 2                 0.956233                                       0.954737
# 1                 0.947077                                       0.936460
# 0                 0.785196                                       0.706479
#
#     val_activation_118_specificity_at_sensitivity  \
# 37                                       0.991708
# 38                                       0.991717
# 39                                       0.991899
# 41                                       0.991758
# 31                                       0.991421
# 40                                       0.992102
# 29                                       0.991355
# 35                                       0.991521
# 43                                       0.991706
# 42                                       0.991989
# 44                                       0.992054
# 46                                       0.991992
# 45                                       0.991774
# 47                                       0.992044
# 33                                       0.991773
# 25                                       0.990867
# 26                                       0.991216
# 27                                       0.990804
# 32                                       0.991046
# 34                                       0.991366
# 30                                       0.991791
# 22                                       0.991461
# 28                                       0.991325
# 36                                       0.991394
# 17                                       0.991101
# 21                                       0.991028
# 20                                       0.991204
# 13                                       0.990698
# 18                                       0.990976
# 19                                       0.990227
# 11                                       0.990207
# 16                                       0.990690
# 24                                       0.990141
# 23                                       0.990566
# 15                                       0.990730
# 12                                       0.989473
# 10                                       0.989736
# 9                                        0.990174
# 8                                        0.989389
# 14                                       0.990431
# 6                                        0.989170
# 7                                        0.989822
# 5                                        0.989045
# 4                                        0.990058
# 3                                        0.989462
# 2                                        0.988792
# 1                                        0.987957
# 0                                        0.843102
#
#     val_activation_118_mean_io_u       lr
# 37                      0.496665  0.00010
# 38                      0.496665  0.00010
# 39                      0.496665  0.00010
# 41                      0.496665  0.00010
# 31                      0.496665  0.00100
# 40                      0.496665  0.00010
# 29                      0.496665  0.00100
# 35                      0.496665  0.00100
# 43                      0.496665  0.00001
# 42                      0.496665  0.00010
# 44                      0.496665  0.00001
# 46                      0.496665  0.00001
# 45                      0.496665  0.00001
# 47                      0.496665  0.00001
# 33                      0.496665  0.00100
# 25                      0.496665  0.00100
# 26                      0.496665  0.00100
# 27                      0.496665  0.00100
# 32                      0.496665  0.00100
# 34                      0.496665  0.00100
# 30                      0.496665  0.00100
# 22                      0.496665  0.00100
# 28                      0.496665  0.00100
# 36                      0.496665  0.00100
# 17                      0.496665  0.00100
# 21                      0.496665  0.00100
# 20                      0.496665  0.00100
# 13                      0.496665  0.00100
# 18                      0.496665  0.00100
# 19                      0.496665  0.00100
# 11                      0.496665  0.00100
# 16                      0.496665  0.00100
# 24                      0.496665  0.00100
# 23                      0.496665  0.00100
# 15                      0.496665  0.00100
# 12                      0.496665  0.00100
# 10                      0.496665  0.00100
# 9                       0.496665  0.00100
# 8                       0.496665  0.00100
# 14                      0.496665  0.00100
# 6                       0.496665  0.00100
# 7                       0.496665  0.00100
# 5                       0.496665  0.00100
# 4                       0.496665  0.00100
# 3                       0.496665  0.00100
# 2                       0.496665  0.00100
# 1                       0.496665  0.00100
# 0                       0.496665  0.00100
#
# [48 rows x 87 columns]

# %%
plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

"""Modified"""
# plt.figure(figsize = (15,6))
# plt.title("Learning curve")
# plt.plot(results.history["accuracy"], label="Accuracy")
# plt.plot(results.history["val_accuracy"], label="val_Accuracy")
# plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
# plt.xlabel("Epochs")
# plt.ylabel("Accuracy")
# plt.legend();
# Out:
# 'Modified'

# %%
model.save("Usquared_JB_DA(1).h5")

# %%
model = tf.keras.models.load_model("Usquared_JB_DA(1).h5")

# %%
# Calculate metrics
predicted = model.predict(lung_test)

# Flatten the predicted and true masks
predicted_flat = np.round(np.array(predicted).flatten())
infect_test_flat = np.array(infect_test).flatten()

# %%
device = "CPU:0"

# %%
with tf.device(device):
    # Calculate metrics for training data
    train_predicted = model.predict(lung_train)

    # Calculate metrics for testing data
    test_predicted = model.predict(lung_test)

# %%
with tf.device(device):
    # Flatten the predicted and true masks
    train_predicted_flat = np.round(np.array(train_predicted)[0, :, :, :].flatten())
    infect_train_flat = np.array(infect_train)[:, :, :, 0].flatten()

    # Calculate precision and recall for training data
    train_precision = Precision()
    train_recall = Recall()
    train_precision.update_state(infect_train_flat, train_predicted_flat)
    train_recall.update_state(infect_train_flat, train_predicted_flat)

    # Calculate F1 score for training data
    train_f1_score = 2 * (train_precision.result() * train_recall.result()) / (train_precision.result() + train_recall.result())

    # Calculate accuracy for training data
    train_accuracy = np.mean(train_predicted_flat == infect_train_flat)


    # Flatten the predicted and true masks for testing data
    test_predicted_flat = np.round(np.array(test_predicted)[0, :, :, :].flatten())
    infect_test_flat = np.array(infect_test)[:, :, :, 0].flatten()

    # Calculate precision and recall for testing data
    test_precision = Precision()
    test_recall = Recall()
    test_precision.update_state(infect_test_flat, test_predicted_flat)
    test_recall.update_state(infect_test_flat, test_predicted_flat)

    # Calculate F1 score for testing data
    test_f1_score = 2 * (test_precision.result() * test_recall.result()) / (test_precision.result() + test_recall.result())

    # Calculate accuracy for testing data
    test_accuracy = np.mean(test_predicted_flat == infect_test_flat)

    # Calculate parameters
    total_parameters = np.sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])

    # Calculate FLOPs
    # flops = get_flops(model, batch_size=1)  # Assuming batch_size = 1

    # Print the metrics for training data
    print("Training Metrics:")
    print("Precision: ", train_precision.result().numpy())
    print("Recall: ", train_recall.result().numpy())
    print("F1 Score: ", train_f1_score.numpy())
    print("Accuracy: ", train_accuracy)

    # Print the metrics for testing data
    print("\nTesting Metrics:")
    print("Precision: ", test_precision.result().numpy())
    print("Recall: ", test_recall.result().numpy())
    print("F1 Score: ", test_f1_score.numpy())
    print("Accuracy: ", test_accuracy)

    # Print the other metrics
    print("\nTotal Parameters: ", total_parameters)
    # print("FLOPs: ", flops)
# Out:
# Training Metrics:
# Precision:  0.93794537
# Recall:  0.9324529
# F1 Score:  0.9351911
# Accuracy:  0.9991487445253314
#
# Testing Metrics:
# Precision:  0.8764589
# Recall:  0.8609869
# F1 Score:  0.86865395
# Accuracy:  0.9982634457674894
#
# Total Parameters:  1130077

# %%
with tf.device(device):
    # Calculate Jaccard Index (MeanIoU) for training data
    train_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    train_iou.update_state(infect_train_flat, train_predicted_flat)
    train_mean_iou = train_iou.result().numpy()

    # Calculate Jaccard Index (MeanIoU) for testing data
    test_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    test_iou.update_state(infect_test_flat, test_predicted_flat)
    test_mean_iou = test_iou.result().numpy()

    # Print the Jaccard Index (MeanIoU) for training and testing data
    print("Training Jaccard Index (MeanIoU): ", train_mean_iou)
    print("Testing Jaccard Index (MeanIoU): ", test_mean_iou)
# Out:
# Training Jaccard Index (MeanIoU):  0.93782234
# Testing Jaccard Index (MeanIoU):  0.8830296

# %%
# Plot accuracy
# plt.plot(results.history['accuracy'])
# plt.plot(results.history['val_accuracy'])
# plt.title('Accuracy vs Epochs')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend(['Train', 'Val'], loc='upper left')
# plt.show()

# Plot loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
with tf.device(device):
    # Make predictions
    predicted = model.predict(lung_test)

# %%
with tf.device(device):
    # Make predictions and visualize
    num = len(predicted)

    for img_num in range(num):
        # predicted = model.predict(lung_test)
        # Visualize results
        fig = plt.figure(figsize=(25, 75))
        plt.subplot(num, 3, 1)
        plt.imshow(lung_test[img_num], cmap='bone')
        plt.title('Original lung')

        plt.subplot(num, 3, 2)
        plt.imshow(lung_test[img_num], cmap='bone')
        plt.imshow(infect_test[img_num][..., 0], alpha=0.5, cmap="nipy_spectral")
        plt.title('Original infection mask')

        plt.subplot(num, 3, 3)
        plt.imshow(lung_test[img_num], cmap='bone')
        plt.imshow(predicted[img_num][img_num, ...], alpha=0.5, cmap="nipy_spectral")
        plt.title('Predicted infection mask')

# %%
# Plot Jaccard Index (MeanIoU)
plt.plot(results.history['mean_io_u'])
plt.plot(results.history['val_mean_io_u'])
plt.title('MeanIoU (Jaccard Index) vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('MeanIoU (Jaccard Index)')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Application\Programming\Research\Lung_Segmentation_task\UNet_Squared_DA(1).ipynb Cell 34 line 2
#       <a href='vscode-notebook-cell:/c%3A/Application/Programming/Research/Lung_Segmentation_task/UNet_Squared_DA%281%29.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> # Plot Jaccard Index (MeanIoU)
# ----> <a href='vscode-notebook-cell:/c%3A/Application/Programming/Research/Lung_Segmentation_task/UNet_Squared_DA%281%29.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> plt.plot(results.history['mean_io_u'])
#       <a href='vscode-notebook-cell:/c%3A/Application/Programming/Research/Lung_Segmentation_task/UNet_Squared_DA%281%29.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(results.history['val_mean_io_u'])
#       <a href='vscode-notebook-cell:/c%3A/Application/Programming/Research/Lung_Segmentation_task/UNet_Squared_DA%281%29.ipynb#X45sZmlsZQ%3D%3D?line=3'>4</a> plt.title('MeanIoU (Jaccard Index) vs Epochs')
#
# KeyError: 'mean_io_u'

# %%
model.save_weights("U_squared_Unet_DA(1)_wt.h5")
